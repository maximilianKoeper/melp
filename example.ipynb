# %%
import numpy as np
import matplotlib.pyplot as plt
import melp
# Out:
# Welcome to JupyROOT 6.24/04

# %%
test = melp.TileHitAngle("sorted_truth.root", "outtest_1")
#test = melp.TileHitAngle("mu3e_run_050000.root", "outtest_big")

# %%
_,_,_ = test.hitAngleRec(n = 1000, angle="phi")
# Out:
# Frames to analyze:  1000  of  4841
# 100%
# HID CHECK:  4885  of  15567 ok
# TID CHECK:  27981  of  38663 ok
# Total Events with matching Tile and Sensor Hit:  4457  of:  4885  primary Tile hits

# %%
binned, xedges, yedges = test.getBinned()

# %%
fig = plt.figure(figsize=(10, 8))
import matplotlib as mpl
ax = fig.add_subplot(111, title='phi distribution')
X, Y = np.meshgrid(xedges, yedges)
im = ax.pcolormesh(X, Y, binned.T, cmap="turbo", norm = mpl.colors.LogNorm())
plt.ylabel("phi")
plt.xlabel("z")
plt.colorbar(im)
plt.savefig("angle_theta_dist_from_rec_helix", dpi=600)
