# %%
# %cd ..
import ROOT
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from melp import Detector
import melp
import math
import random
from glob import glob

from melp.clustering.misc import*
import melp.clustering as clump
import melp.clustering.time_cluster as tclump
#from melp import TileAnalyzer
import melp.clustering.spatial_cluster as sclump
import melp.clustering.plots as clump_plt
import melp.clustering.three_frame_cluster as clump_3

plt.rcParams.update({'font.size': 16})
# Out:
# /home/erik/GitHub/melp
# Welcome to JupyROOT 6.24/06

# %% [markdown]
# # Global Functions

# %%
def print_eff_stats(fnames_efficiency_stats):
    for f in fnames_efficiency_stats:
        print("File: " + f)
        with open(f, "r", encoding="utf-8") as file:
            for line in file:
                print(line.strip())
        print("\n")

# %% [markdown]
# # Time then iterative spatial clustering

# %%
time_threshold_used = 1.2
threshold_cluster_width_used = [20,25,30,35,40,999999]

function_str = "mt_compare_to_tid"
src = "./testdata/sorted/root_files_fixed/mu3e_sorted_000*.root"

for threshold in threshold_cluster_width_used:
    args = (time_threshold_used, threshold, "big", None, "timetheniterativespatial")

    #clump.multithreading.run_mt(function_str, src, args)

# %% [markdown]
# ## Efficiency statistics

# %% [markdown]
# ### Threshold: 20mm

# %%
current_threshold = threshold_cluster_width_used[0] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_129_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 5536181
# Identified incorrectly: 666854
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511520 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 14468
# Number of clusters where tid already exists: 1705914 , Hits: 2999439
# Number of clusters where tid already exists, that are accounted for: 1705914
# Correctly associated out of all hits:  89.24955283985985 %
# Correctly associated out of all hits in clusters:  89.24955283985985 %
# Incorrectly associated out of all hits:  10.750447160140158 %
# Incorrectly associated out of all hits in clusters:  10.750447160140158 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 5542857
# Identified incorrectly: 669616
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516314 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1705268 , Hits: 3000543
# Number of clusters where tid already exists, that are accounted for: 1705268
# Correctly associated out of all hits:  89.22142599251538 %
# Correctly associated out of all hits in clusters:  89.22142599251538 %
# Incorrectly associated out of all hits:  10.77857400748462 %
# Incorrectly associated out of all hits in clusters:  10.77857400748462 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 5540526
# Identified incorrectly: 666901
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514376 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 14318
# Number of clusters where tid already exists: 1702092 , Hits: 2997962
# Number of clusters where tid already exists, that are accounted for: 1702092
# Correctly associated out of all hits:  89.25640204870714 %
# Correctly associated out of all hits in clusters:  89.25640204870714 %
# Incorrectly associated out of all hits:  10.743597951292863 %
# Incorrectly associated out of all hits in clusters:  10.743597951292863 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 5542138
# Identified incorrectly: 667167
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515272 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 14442
# Number of clusters where tid already exists: 1704266 , Hits: 2996260
# Number of clusters where tid already exists, that are accounted for: 1704266
# Correctly associated out of all hits:  89.25536754918626 %
# Correctly associated out of all hits in clusters:  89.25536754918626 %
# Incorrectly associated out of all hits:  10.744632450813738 %
# Incorrectly associated out of all hits in clusters:  10.744632450813738 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 5550460
# Identified incorrectly: 667132
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518266 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1714522 , Hits: 3022558
# Number of clusters where tid already exists, that are accounted for: 1714522
# Correctly associated out of all hits:  89.27025124839327 %
# Correctly associated out of all hits in clusters:  89.27025124839327 %
# Incorrectly associated out of all hits:  10.729748751606731 %
# Incorrectly associated out of all hits in clusters:  10.729748751606731 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 5538498
# Identified incorrectly: 667570
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515422 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 14256
# Number of clusters where tid already exists: 1703180 , Hits: 2994459
# Number of clusters where tid already exists, that are accounted for: 1703180
# Correctly associated out of all hits:  89.24326965157327 %
# Correctly associated out of all hits in clusters:  89.24326965157327 %
# Incorrectly associated out of all hits:  10.756730348426734 %
# Incorrectly associated out of all hits in clusters:  10.756730348426734 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 5541302
# Identified incorrectly: 668702
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514742 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 14417
# Number of clusters where tid already exists: 1703422 , Hits: 2996535
# Number of clusters where tid already exists, that are accounted for: 1703422
# Correctly associated out of all hits:  89.23185878785263 %
# Correctly associated out of all hits in clusters:  89.23185878785263 %
# Incorrectly associated out of all hits:  10.768141212147368 %
# Incorrectly associated out of all hits in clusters:  10.768141212147368 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 5532388
# Identified incorrectly: 667579
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510005 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1700076 , Hits: 2990466
# Number of clusters where tid already exists, that are accounted for: 1700076
# Correctly associated out of all hits:  89.2325394635165 %
# Correctly associated out of all hits in clusters:  89.2325394635165 %
# Incorrectly associated out of all hits:  10.767460536483501 %
# Incorrectly associated out of all hits in clusters:  10.767460536483501 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 5551101
# Identified incorrectly: 670249
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3521622 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 14371
# Number of clusters where tid already exists: 1709438 , Hits: 3007068
# Number of clusters where tid already exists, that are accounted for: 1709438
# Correctly associated out of all hits:  89.22663087593529 %
# Correctly associated out of all hits in clusters:  89.22663087593529 %
# Incorrectly associated out of all hits:  10.773369124064713 %
# Incorrectly associated out of all hits in clusters:  10.773369124064713 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 5537962
# Identified incorrectly: 666529
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513808 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 14410
# Number of clusters where tid already exists: 1700656 , Hits: 2989477
# Number of clusters where tid already exists, that are accounted for: 1700656
# Correctly associated out of all hits:  89.25731377481246 %
# Correctly associated out of all hits in clusters:  89.25731377481246 %
# Incorrectly associated out of all hits:  10.742686225187528 %
# Incorrectly associated out of all hits in clusters:  10.742686225187528 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 5536919
# Identified incorrectly: 668557
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512018 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 14411
# Number of clusters where tid already exists: 1699252 , Hits: 2989089
# Number of clusters where tid already exists, that are accounted for: 1699252
# Correctly associated out of all hits:  89.22633815681505 %
# Correctly associated out of all hits in clusters:  89.22633815681505 %
# Incorrectly associated out of all hits:  10.773661843184954 %
# Incorrectly associated out of all hits in clusters:  10.773661843184954 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 5536848
# Identified incorrectly: 666542
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511979 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 14478
# Number of clusters where tid already exists: 1703576 , Hits: 2998551
# Number of clusters where tid already exists, that are accounted for: 1703576
# Correctly associated out of all hits:  89.2551975613334 %
# Correctly associated out of all hits in clusters:  89.2551975613334 %
# Incorrectly associated out of all hits:  10.7448024386666 %
# Incorrectly associated out of all hits in clusters:  10.7448024386666 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 5529634
# Identified incorrectly: 667469
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510106 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 14347
# Number of clusters where tid already exists: 1699010 , Hits: 2982586
# Number of clusters where tid already exists, that are accounted for: 1699010
# Correctly associated out of all hits:  89.22933828919739 %
# Correctly associated out of all hits in clusters:  89.22933828919739 %
# Incorrectly associated out of all hits:  10.770661710802612 %
# Incorrectly associated out of all hits in clusters:  10.770661710802612 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 5542912
# Identified incorrectly: 668400
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515281 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 14436
# Number of clusters where tid already exists: 1703912 , Hits: 3000085
# Number of clusters where tid already exists, that are accounted for: 1703912
# Correctly associated out of all hits:  89.23898847779664 %
# Correctly associated out of all hits in clusters:  89.23898847779664 %
# Incorrectly associated out of all hits:  10.76101152220336 %
# Incorrectly associated out of all hits in clusters:  10.76101152220336 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 5535123
# Identified incorrectly: 666570
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513055 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 14427
# Number of clusters where tid already exists: 1704206 , Hits: 2997932
# Number of clusters where tid already exists, that are accounted for: 1704206
# Correctly associated out of all hits:  89.25180591815815 %
# Correctly associated out of all hits in clusters:  89.25180591815815 %
# Incorrectly associated out of all hits:  10.748194081841845 %
# Incorrectly associated out of all hits in clusters:  10.748194081841845 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 5547366
# Identified incorrectly: 668087
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518733 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 14483
# Number of clusters where tid already exists: 1712446 , Hits: 3010913
# Number of clusters where tid already exists, that are accounted for: 1712446
# Correctly associated out of all hits:  89.25119375852412 %
# Correctly associated out of all hits in clusters:  89.25119375852412 %
# Incorrectly associated out of all hits:  10.748806241475883 %
# Incorrectly associated out of all hits in clusters:  10.748806241475883 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 5543444
# Identified incorrectly: 668467
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516566 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 14438
# Number of clusters where tid already exists: 1706528 , Hits: 3001690
# Number of clusters where tid already exists, that are accounted for: 1706528
# Correctly associated out of all hits:  89.23894756380122 %
# Correctly associated out of all hits in clusters:  89.23894756380122 %
# Incorrectly associated out of all hits:  10.76105243619878 %
# Incorrectly associated out of all hits in clusters:  10.76105243619878 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 5536729
# Identified incorrectly: 668271
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514406 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 14437
# Number of clusters where tid already exists: 1703322 , Hits: 2989924
# Number of clusters where tid already exists, that are accounted for: 1703322
# Correctly associated out of all hits:  89.23012087026592 %
# Correctly associated out of all hits in clusters:  89.23012087026592 %
# Incorrectly associated out of all hits:  10.769879129734086 %
# Incorrectly associated out of all hits in clusters:  10.769879129734086 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 5539785
# Identified incorrectly: 669028
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514156 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 14472
# Number of clusters where tid already exists: 1706152 , Hits: 2999927
# Number of clusters where tid already exists, that are accounted for: 1706152
# Correctly associated out of all hits:  89.2245425977558 %
# Correctly associated out of all hits in clusters:  89.2245425977558 %
# Incorrectly associated out of all hits:  10.775457402244198 %
# Incorrectly associated out of all hits in clusters:  10.775457402244198 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 5541104
# Identified incorrectly: 669192
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515507 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 14460
# Number of clusters where tid already exists: 1704180 , Hits: 2995314
# Number of clusters where tid already exists, that are accounted for: 1704180
# Correctly associated out of all hits:  89.22447496866494 %
# Correctly associated out of all hits in clusters:  89.22447496866494 %
# Incorrectly associated out of all hits:  10.77552503133506 %
# Incorrectly associated out of all hits in clusters:  10.77552503133506 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 5535758
# Identified incorrectly: 665269
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512203 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 14367
# Number of clusters where tid already exists: 1701994 , Hits: 2992668
# Number of clusters where tid already exists, that are accounted for: 1701994
# Correctly associated out of all hits:  89.2716319409672 %
# Correctly associated out of all hits in clusters:  89.2716319409672 %
# Incorrectly associated out of all hits:  10.728368059032803 %
# Incorrectly associated out of all hits in clusters:  10.728368059032803 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 5540397
# Identified incorrectly: 667580
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513596 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 14522
# Number of clusters where tid already exists: 1701886 , Hits: 2998250
# Number of clusters where tid already exists, that are accounted for: 1701886
# Correctly associated out of all hits:  89.24641634464818 %
# Correctly associated out of all hits in clusters:  89.24641634464818 %
# Incorrectly associated out of all hits:  10.753583655351816 %
# Incorrectly associated out of all hits in clusters:  10.753583655351816 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 5535651
# Identified incorrectly: 667765
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514327 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 14638
# Number of clusters where tid already exists: 1705524 , Hits: 2997352
# Number of clusters where tid already exists, that are accounted for: 1705524
# Correctly associated out of all hits:  89.23552765121669 %
# Correctly associated out of all hits in clusters:  89.23552765121669 %
# Incorrectly associated out of all hits:  10.764472348783315 %
# Incorrectly associated out of all hits in clusters:  10.764472348783315 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 5538077
# Identified incorrectly: 667069
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514150 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 14502
# Number of clusters where tid already exists: 1706694 , Hits: 3001730
# Number of clusters where tid already exists, that are accounted for: 1706694
# Correctly associated out of all hits:  89.24974529205276 %
# Correctly associated out of all hits in clusters:  89.24974529205276 %
# Incorrectly associated out of all hits:  10.750254707947242 %
# Incorrectly associated out of all hits in clusters:  10.750254707947242 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 5537223
# Identified incorrectly: 668433
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513507 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 14202
# Number of clusters where tid already exists: 1704188 , Hits: 2994306
# Number of clusters where tid already exists, that are accounted for: 1704188
# Correctly associated out of all hits:  89.22864883261335 %
# Correctly associated out of all hits in clusters:  89.22864883261335 %
# Incorrectly associated out of all hits:  10.771351167386655 %
# Incorrectly associated out of all hits in clusters:  10.771351167386655 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 5529164
# Identified incorrectly: 666026
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3508815 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 14453
# Number of clusters where tid already exists: 1701666 , Hits: 2991879
# Number of clusters where tid already exists, that are accounted for: 1701666
# Correctly associated out of all hits:  89.24930470251921 %
# Correctly associated out of all hits in clusters:  89.24930470251921 %
# Incorrectly associated out of all hits:  10.750695297480787 %
# Incorrectly associated out of all hits in clusters:  10.750695297480787 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 5542450
# Identified incorrectly: 669281
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516617 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 14382
# Number of clusters where tid already exists: 1701978 , Hits: 2995592
# Number of clusters where tid already exists, that are accounted for: 1701978
# Correctly associated out of all hits:  89.22553149838588 %
# Correctly associated out of all hits in clusters:  89.22553149838588 %
# Incorrectly associated out of all hits:  10.774468501614123 %
# Incorrectly associated out of all hits in clusters:  10.774468501614123 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 5533502
# Identified incorrectly: 667159
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510888 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 14507
# Number of clusters where tid already exists: 1703214 , Hits: 2996023
# Number of clusters where tid already exists, that are accounted for: 1703214
# Correctly associated out of all hits:  89.24051806734798 %
# Correctly associated out of all hits in clusters:  89.24051806734798 %
# Incorrectly associated out of all hits:  10.759481932652019 %
# Incorrectly associated out of all hits in clusters:  10.759481932652019 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_timetheniterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 5539417
# Identified incorrectly: 668424
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513755 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1701736 , Hits: 2990977
# Number of clusters where tid already exists, that are accounted for: 1701736
# Correctly associated out of all hits:  89.23258504848948 %
# Correctly associated out of all hits in clusters:  89.23258504848948 %
# Incorrectly associated out of all hits:  10.767414951510517 %
# Incorrectly associated out of all hits in clusters:  10.767414951510517 %

# %% [markdown]
# ### Threshold: 25mm

# %%
current_threshold = threshold_cluster_width_used[1] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_160_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 5478030
# Identified incorrectly: 731974
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514742 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 14417
# Number of clusters where tid already exists: 1703422 , Hits: 2996535
# Number of clusters where tid already exists, that are accounted for: 1703422
# Correctly associated out of all hits:  88.21298665830167 %
# Correctly associated out of all hits in clusters:  88.21298665830167 %
# Incorrectly associated out of all hits:  11.78701334169833 %
# Incorrectly associated out of all hits in clusters:  11.78701334169833 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 5471745
# Identified incorrectly: 729282
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512203 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 14367
# Number of clusters where tid already exists: 1701994 , Hits: 2992668
# Number of clusters where tid already exists, that are accounted for: 1701994
# Correctly associated out of all hits:  88.23933519399287 %
# Correctly associated out of all hits in clusters:  88.23933519399287 %
# Incorrectly associated out of all hits:  11.760664806007135 %
# Incorrectly associated out of all hits in clusters:  11.760664806007135 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 5475275
# Identified incorrectly: 730381
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513507 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 14202
# Number of clusters where tid already exists: 1704188 , Hits: 2994306
# Number of clusters where tid already exists, that are accounted for: 1704188
# Correctly associated out of all hits:  88.2303982044767 %
# Correctly associated out of all hits in clusters:  88.2303982044767 %
# Incorrectly associated out of all hits:  11.769601795523311 %
# Incorrectly associated out of all hits in clusters:  11.769601795523311 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 5477696
# Identified incorrectly: 730145
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513755 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1701736 , Hits: 2990977
# Number of clusters where tid already exists, that are accounted for: 1701736
# Correctly associated out of all hits:  88.2383424446599 %
# Correctly associated out of all hits in clusters:  88.2383424446599 %
# Incorrectly associated out of all hits:  11.761657555340093 %
# Incorrectly associated out of all hits in clusters:  11.761657555340093 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 5466425
# Identified incorrectly: 728765
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3508815 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 14453
# Number of clusters where tid already exists: 1701666 , Hits: 2991879
# Number of clusters where tid already exists, that are accounted for: 1701666
# Correctly associated out of all hits:  88.23659968459401 %
# Correctly associated out of all hits in clusters:  88.23659968459401 %
# Incorrectly associated out of all hits:  11.763400315405985 %
# Incorrectly associated out of all hits in clusters:  11.763400315405985 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 5479951
# Identified incorrectly: 731960
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516566 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 14438
# Number of clusters where tid already exists: 1706528 , Hits: 3001690
# Number of clusters where tid already exists, that are accounted for: 1706528
# Correctly associated out of all hits:  88.21683053733383 %
# Correctly associated out of all hits in clusters:  88.21683053733383 %
# Incorrectly associated out of all hits:  11.783169462666159 %
# Incorrectly associated out of all hits in clusters:  11.783169462666159 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 5477608
# Identified incorrectly: 729819
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514376 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 14318
# Number of clusters where tid already exists: 1702092 , Hits: 2997962
# Number of clusters where tid already exists, that are accounted for: 1702092
# Correctly associated out of all hits:  88.24280978253954 %
# Correctly associated out of all hits in clusters:  88.24280978253954 %
# Incorrectly associated out of all hits:  11.757190217460472 %
# Incorrectly associated out of all hits in clusters:  11.757190217460472 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 5480201
# Identified incorrectly: 732272
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516314 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1705268 , Hits: 3000543
# Number of clusters where tid already exists, that are accounted for: 1705268
# Correctly associated out of all hits:  88.21287432557051 %
# Correctly associated out of all hits in clusters:  88.21287432557051 %
# Incorrectly associated out of all hits:  11.78712567442949 %
# Incorrectly associated out of all hits in clusters:  11.78712567442949 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 5484065
# Identified incorrectly: 731388
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518733 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 14483
# Number of clusters where tid already exists: 1712446 , Hits: 3010913
# Number of clusters where tid already exists, that are accounted for: 1712446
# Correctly associated out of all hits:  88.23274828077696 %
# Correctly associated out of all hits in clusters:  88.23274828077696 %
# Incorrectly associated out of all hits:  11.76725171922304 %
# Incorrectly associated out of all hits in clusters:  11.76725171922304 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 5480259
# Identified incorrectly: 731472
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516617 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 14382
# Number of clusters where tid already exists: 1701978 , Hits: 2995592
# Number of clusters where tid already exists, that are accounted for: 1701978
# Correctly associated out of all hits:  88.22434519460035 %
# Correctly associated out of all hits in clusters:  88.22434519460035 %
# Incorrectly associated out of all hits:  11.775654805399654 %
# Incorrectly associated out of all hits in clusters:  11.775654805399654 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 5472751
# Identified incorrectly: 728942
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513055 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 14427
# Number of clusters where tid already exists: 1704206 , Hits: 2997932
# Number of clusters where tid already exists, that are accounted for: 1704206
# Correctly associated out of all hits:  88.24608054607025 %
# Correctly associated out of all hits in clusters:  88.24608054607025 %
# Incorrectly associated out of all hits:  11.753919453929758 %
# Incorrectly associated out of all hits in clusters:  11.753919453929758 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 5476467
# Identified incorrectly: 729601
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515422 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 14256
# Number of clusters where tid already exists: 1703180 , Hits: 2994459
# Number of clusters where tid already exists, that are accounted for: 1703180
# Correctly associated out of all hits:  88.24374789319099 %
# Correctly associated out of all hits in clusters:  88.24374789319099 %
# Incorrectly associated out of all hits:  11.756252106809013 %
# Incorrectly associated out of all hits in clusters:  11.756252106809013 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 5479492
# Identified incorrectly: 729813
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515272 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 14442
# Number of clusters where tid already exists: 1704266 , Hits: 2996260
# Number of clusters where tid already exists, that are accounted for: 1704266
# Correctly associated out of all hits:  88.2464623657559 %
# Correctly associated out of all hits in clusters:  88.2464623657559 %
# Incorrectly associated out of all hits:  11.75353763424409 %
# Incorrectly associated out of all hits in clusters:  11.75353763424409 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 5477937
# Identified incorrectly: 730040
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513596 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 14522
# Number of clusters where tid already exists: 1701886 , Hits: 2998250
# Number of clusters where tid already exists, that are accounted for: 1701886
# Correctly associated out of all hits:  88.24029148303869 %
# Correctly associated out of all hits in clusters:  88.24029148303869 %
# Incorrectly associated out of all hits:  11.759708516961323 %
# Incorrectly associated out of all hits in clusters:  11.759708516961323 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 5476605
# Identified incorrectly: 732208
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514156 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 14472
# Number of clusters where tid already exists: 1706152 , Hits: 2999927
# Number of clusters where tid already exists, that are accounted for: 1706152
# Correctly associated out of all hits:  88.20695678868087 %
# Correctly associated out of all hits in clusters:  88.20695678868087 %
# Incorrectly associated out of all hits:  11.793043211319137 %
# Incorrectly associated out of all hits in clusters:  11.793043211319137 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 5474187
# Identified incorrectly: 729203
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511979 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 14478
# Number of clusters where tid already exists: 1703576 , Hits: 2998551
# Number of clusters where tid already exists, that are accounted for: 1703576
# Correctly associated out of all hits:  88.24508857253856 %
# Correctly associated out of all hits in clusters:  88.24508857253856 %
# Incorrectly associated out of all hits:  11.754911427461437 %
# Incorrectly associated out of all hits in clusters:  11.754911427461437 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 5470450
# Identified incorrectly: 730211
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510888 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 14507
# Number of clusters where tid already exists: 1703214 , Hits: 2996023
# Number of clusters where tid already exists, that are accounted for: 1703214
# Correctly associated out of all hits:  88.22365873573801 %
# Correctly associated out of all hits in clusters:  88.22365873573801 %
# Incorrectly associated out of all hits:  11.776341264261987 %
# Incorrectly associated out of all hits in clusters:  11.776341264261987 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 5475117
# Identified incorrectly: 729374
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513808 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 14410
# Number of clusters where tid already exists: 1700656 , Hits: 2989477
# Number of clusters where tid already exists, that are accounted for: 1700656
# Correctly associated out of all hits:  88.24441843819258 %
# Correctly associated out of all hits in clusters:  88.24441843819258 %
# Incorrectly associated out of all hits:  11.755581561807407 %
# Incorrectly associated out of all hits in clusters:  11.755581561807407 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 5467130
# Identified incorrectly: 729973
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510106 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 14347
# Number of clusters where tid already exists: 1699010 , Hits: 2982586
# Number of clusters where tid already exists, that are accounted for: 1699010
# Correctly associated out of all hits:  88.22073798031113 %
# Correctly associated out of all hits in clusters:  88.22073798031113 %
# Incorrectly associated out of all hits:  11.779262019688877 %
# Incorrectly associated out of all hits in clusters:  11.779262019688877 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 5480173
# Identified incorrectly: 731139
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515281 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 14436
# Number of clusters where tid already exists: 1703912 , Hits: 3000085
# Number of clusters where tid already exists, that are accounted for: 1703912
# Correctly associated out of all hits:  88.22891202373991 %
# Correctly associated out of all hits in clusters:  88.22891202373991 %
# Incorrectly associated out of all hits:  11.771087976260088 %
# Incorrectly associated out of all hits in clusters:  11.771087976260088 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 5473325
# Identified incorrectly: 730091
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514327 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 14638
# Number of clusters where tid already exists: 1705524 , Hits: 2997352
# Number of clusters where tid already exists, that are accounted for: 1705524
# Correctly associated out of all hits:  88.23082314647284 %
# Correctly associated out of all hits in clusters:  88.23082314647284 %
# Incorrectly associated out of all hits:  11.769176853527153 %
# Incorrectly associated out of all hits in clusters:  11.769176853527153 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 5469485
# Identified incorrectly: 730482
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510005 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1700076 , Hits: 2990466
# Number of clusters where tid already exists, that are accounted for: 1700076
# Correctly associated out of all hits:  88.21796954725727 %
# Correctly associated out of all hits in clusters:  88.21796954725727 %
# Incorrectly associated out of all hits:  11.782030452742733 %
# Incorrectly associated out of all hits in clusters:  11.782030452742733 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 5473165
# Identified incorrectly: 729870
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511520 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 14468
# Number of clusters where tid already exists: 1705914 , Hits: 2999439
# Number of clusters where tid already exists, that are accounted for: 1705914
# Correctly associated out of all hits:  88.23366303752921 %
# Correctly associated out of all hits in clusters:  88.23366303752921 %
# Incorrectly associated out of all hits:  11.76633696247079 %
# Incorrectly associated out of all hits in clusters:  11.76633696247079 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 5474617
# Identified incorrectly: 730529
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514150 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 14502
# Number of clusters where tid already exists: 1706694 , Hits: 3001730
# Number of clusters where tid already exists, that are accounted for: 1706694
# Correctly associated out of all hits:  88.22704574557956 %
# Correctly associated out of all hits in clusters:  88.22704574557956 %
# Incorrectly associated out of all hits:  11.772954254420444 %
# Incorrectly associated out of all hits in clusters:  11.772954254420444 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 5473129
# Identified incorrectly: 731871
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514406 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 14437
# Number of clusters where tid already exists: 1703322 , Hits: 2989924
# Number of clusters where tid already exists, that are accounted for: 1703322
# Correctly associated out of all hits:  88.20514101531023 %
# Correctly associated out of all hits in clusters:  88.20514101531023 %
# Incorrectly associated out of all hits:  11.794858984689766 %
# Incorrectly associated out of all hits in clusters:  11.794858984689766 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 5487437
# Identified incorrectly: 733913
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3521622 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 14371
# Number of clusters where tid already exists: 1709438 , Hits: 3007068
# Number of clusters where tid already exists, that are accounted for: 1709438
# Correctly associated out of all hits:  88.20331600054651 %
# Correctly associated out of all hits in clusters:  88.20331600054651 %
# Incorrectly associated out of all hits:  11.796683999453494 %
# Incorrectly associated out of all hits in clusters:  11.796683999453494 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 5474164
# Identified incorrectly: 731312
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512018 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 14411
# Number of clusters where tid already exists: 1699252 , Hits: 2989089
# Number of clusters where tid already exists, that are accounted for: 1699252
# Correctly associated out of all hits:  88.21505392978717 %
# Correctly associated out of all hits in clusters:  88.21505392978717 %
# Incorrectly associated out of all hits:  11.784946070212824 %
# Incorrectly associated out of all hits in clusters:  11.784946070212824 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 5487473
# Identified incorrectly: 730119
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518266 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1714522 , Hits: 3022558
# Number of clusters where tid already exists, that are accounted for: 1714522
# Correctly associated out of all hits:  88.25720632682234 %
# Correctly associated out of all hits in clusters:  88.25720632682234 %
# Incorrectly associated out of all hits:  11.742793673177655 %
# Incorrectly associated out of all hits in clusters:  11.742793673177655 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_timetheniterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 5478230
# Identified incorrectly: 732066
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515507 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 14460
# Number of clusters where tid already exists: 1704180 , Hits: 2995314
# Number of clusters where tid already exists, that are accounted for: 1704180
# Correctly associated out of all hits:  88.2120594573914 %
# Correctly associated out of all hits in clusters:  88.2120594573914 %
# Incorrectly associated out of all hits:  11.787940542608597 %
# Incorrectly associated out of all hits in clusters:  11.787940542608597 %

# %% [markdown]
# ### Threshold: 30mm

# %%
current_threshold = threshold_cluster_width_used[2] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_138_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 5388786
# Identified incorrectly: 823125
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516566 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 14438
# Number of clusters where tid already exists: 1706528 , Hits: 3001690
# Number of clusters where tid already exists, that are accounted for: 1706528
# Correctly associated out of all hits:  86.7492467293881 %
# Correctly associated out of all hits in clusters:  86.7492467293881 %
# Incorrectly associated out of all hits:  13.250753270611893 %
# Incorrectly associated out of all hits in clusters:  13.250753270611893 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 5384801
# Identified incorrectly: 825203
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514742 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 14417
# Number of clusters where tid already exists: 1703422 , Hits: 2996535
# Number of clusters where tid already exists, that are accounted for: 1703422
# Correctly associated out of all hits:  86.71171548359712 %
# Correctly associated out of all hits in clusters:  86.71171548359712 %
# Incorrectly associated out of all hits:  13.288284516402888 %
# Incorrectly associated out of all hits in clusters:  13.288284516402888 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 5381618
# Identified incorrectly: 821417
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511520 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 14468
# Number of clusters where tid already exists: 1705914 , Hits: 2999439
# Number of clusters where tid already exists, that are accounted for: 1705914
# Correctly associated out of all hits:  86.75782096989619 %
# Correctly associated out of all hits in clusters:  86.75782096989619 %
# Incorrectly associated out of all hits:  13.242179030103813 %
# Incorrectly associated out of all hits in clusters:  13.242179030103813 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 5384729
# Identified incorrectly: 822698
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514376 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 14318
# Number of clusters where tid already exists: 1702092 , Hits: 2997962
# Number of clusters where tid already exists, that are accounted for: 1702092
# Correctly associated out of all hits:  86.74655376535237 %
# Correctly associated out of all hits in clusters:  86.74655376535237 %
# Incorrectly associated out of all hits:  13.253446234647626 %
# Incorrectly associated out of all hits in clusters:  13.253446234647626 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 5394117
# Identified incorrectly: 827233
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3521622 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 14371
# Number of clusters where tid already exists: 1709438 , Hits: 3007068
# Number of clusters where tid already exists, that are accounted for: 1709438
# Correctly associated out of all hits:  86.70332001896695 %
# Correctly associated out of all hits in clusters:  86.70332001896695 %
# Incorrectly associated out of all hits:  13.296679981033055 %
# Incorrectly associated out of all hits in clusters:  13.296679981033055 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 5391931
# Identified incorrectly: 823522
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518733 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 14483
# Number of clusters where tid already exists: 1712446 , Hits: 3010913
# Number of clusters where tid already exists, that are accounted for: 1712446
# Correctly associated out of all hits:  86.75041062976423 %
# Correctly associated out of all hits in clusters:  86.75041062976423 %
# Incorrectly associated out of all hits:  13.249589370235766 %
# Incorrectly associated out of all hits in clusters:  13.249589370235766 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 5380962
# Identified incorrectly: 824694
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513507 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 14202
# Number of clusters where tid already exists: 1704188 , Hits: 2994306
# Number of clusters where tid already exists, that are accounted for: 1704188
# Correctly associated out of all hits:  86.71060722669772 %
# Correctly associated out of all hits in clusters:  86.71060722669772 %
# Incorrectly associated out of all hits:  13.289392773302291 %
# Incorrectly associated out of all hits in clusters:  13.289392773302291 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 5382946
# Identified incorrectly: 820444
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511979 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 14478
# Number of clusters where tid already exists: 1703576 , Hits: 2998551
# Number of clusters where tid already exists, that are accounted for: 1703576
# Correctly associated out of all hits:  86.77426374933705 %
# Correctly associated out of all hits in clusters:  86.77426374933705 %
# Incorrectly associated out of all hits:  13.225736250662944 %
# Incorrectly associated out of all hits in clusters:  13.225736250662944 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 5376374
# Identified incorrectly: 820729
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510106 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 14347
# Number of clusters where tid already exists: 1699010 , Hits: 2982586
# Number of clusters where tid already exists, that are accounted for: 1699010
# Correctly associated out of all hits:  86.75624723358641 %
# Correctly associated out of all hits in clusters:  86.75624723358641 %
# Incorrectly associated out of all hits:  13.243752766413596 %
# Incorrectly associated out of all hits in clusters:  13.243752766413596 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 5380985
# Identified incorrectly: 822431
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514327 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 14638
# Number of clusters where tid already exists: 1705524 , Hits: 2997352
# Number of clusters where tid already exists, that are accounted for: 1705524
# Correctly associated out of all hits:  86.74228844236788 %
# Correctly associated out of all hits in clusters:  86.74228844236788 %
# Incorrectly associated out of all hits:  13.257711557632117 %
# Incorrectly associated out of all hits in clusters:  13.257711557632117 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 5375100
# Identified incorrectly: 820090
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3508815 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 14453
# Number of clusters where tid already exists: 1701666 , Hits: 2991879
# Number of clusters where tid already exists, that are accounted for: 1701666
# Correctly associated out of all hits:  86.7624721759946 %
# Correctly associated out of all hits in clusters:  86.7624721759946 %
# Incorrectly associated out of all hits:  13.237527824005397 %
# Incorrectly associated out of all hits in clusters:  13.237527824005397 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 5385716
# Identified incorrectly: 823589
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515272 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 14442
# Number of clusters where tid already exists: 1704266 , Hits: 2996260
# Number of clusters where tid already exists, that are accounted for: 1704266
# Correctly associated out of all hits:  86.736212828972 %
# Correctly associated out of all hits in clusters:  86.736212828972 %
# Incorrectly associated out of all hits:  13.263787171027998 %
# Incorrectly associated out of all hits in clusters:  13.263787171027998 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 5386481
# Identified incorrectly: 821496
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513596 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 14522
# Number of clusters where tid already exists: 1701886 , Hits: 2998250
# Number of clusters where tid already exists, that are accounted for: 1701886
# Correctly associated out of all hits:  86.76709014869095 %
# Correctly associated out of all hits in clusters:  86.76709014869095 %
# Incorrectly associated out of all hits:  13.232909851309051 %
# Incorrectly associated out of all hits in clusters:  13.232909851309051 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 5379143
# Identified incorrectly: 822550
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513055 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 14427
# Number of clusters where tid already exists: 1704206 , Hits: 2997932
# Number of clusters where tid already exists, that are accounted for: 1704206
# Correctly associated out of all hits:  86.73668625647868 %
# Correctly associated out of all hits in clusters:  86.73668625647868 %
# Incorrectly associated out of all hits:  13.263313743521325 %
# Incorrectly associated out of all hits in clusters:  13.263313743521325 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 5381924
# Identified incorrectly: 823552
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512018 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 14411
# Number of clusters where tid already exists: 1699252 , Hits: 2989089
# Number of clusters where tid already exists, that are accounted for: 1699252
# Correctly associated out of all hits:  86.72862484682884 %
# Correctly associated out of all hits in clusters:  86.72862484682884 %
# Incorrectly associated out of all hits:  13.271375153171167 %
# Incorrectly associated out of all hits in clusters:  13.271375153171167 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 5381366
# Identified incorrectly: 823634
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514406 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 14437
# Number of clusters where tid already exists: 1703322 , Hits: 2989924
# Number of clusters where tid already exists, that are accounted for: 1703322
# Correctly associated out of all hits:  86.72628525382756 %
# Correctly associated out of all hits in clusters:  86.72628525382756 %
# Incorrectly associated out of all hits:  13.273714746172441 %
# Incorrectly associated out of all hits in clusters:  13.273714746172441 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 5393093
# Identified incorrectly: 824499
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518266 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1714522 , Hits: 3022558
# Number of clusters where tid already exists, that are accounted for: 1714522
# Correctly associated out of all hits:  86.73925532585606 %
# Correctly associated out of all hits in clusters:  86.73925532585606 %
# Incorrectly associated out of all hits:  13.260744674143945 %
# Incorrectly associated out of all hits in clusters:  13.260744674143945 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 5385132
# Identified incorrectly: 820936
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515422 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 14256
# Number of clusters where tid already exists: 1703180 , Hits: 2994459
# Number of clusters where tid already exists, that are accounted for: 1703180
# Correctly associated out of all hits:  86.77204310362052 %
# Correctly associated out of all hits in clusters:  86.77204310362052 %
# Incorrectly associated out of all hits:  13.227956896379478 %
# Incorrectly associated out of all hits in clusters:  13.227956896379478 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 5384451
# Identified incorrectly: 824362
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514156 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 14472
# Number of clusters where tid already exists: 1706152 , Hits: 2999927
# Number of clusters where tid already exists, that are accounted for: 1706152
# Correctly associated out of all hits:  86.72271173250024 %
# Correctly associated out of all hits in clusters:  86.72271173250024 %
# Incorrectly associated out of all hits:  13.277288267499763 %
# Incorrectly associated out of all hits in clusters:  13.277288267499763 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 5385402
# Identified incorrectly: 824894
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515507 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 14460
# Number of clusters where tid already exists: 1704180 , Hits: 2995314
# Number of clusters where tid already exists, that are accounted for: 1704180
# Correctly associated out of all hits:  86.71731588961299 %
# Correctly associated out of all hits in clusters:  86.71731588961299 %
# Incorrectly associated out of all hits:  13.28268411038701 %
# Incorrectly associated out of all hits in clusters:  13.28268411038701 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 5378759
# Identified incorrectly: 822268
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512203 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 14367
# Number of clusters where tid already exists: 1701994 , Hits: 2992668
# Number of clusters where tid already exists, that are accounted for: 1701994
# Correctly associated out of all hits:  86.73980938963821 %
# Correctly associated out of all hits in clusters:  86.73980938963821 %
# Incorrectly associated out of all hits:  13.2601906103618 %
# Incorrectly associated out of all hits in clusters:  13.2601906103618 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 5384903
# Identified incorrectly: 822938
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513755 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1701736 , Hits: 2990977
# Number of clusters where tid already exists, that are accounted for: 1701736
# Correctly associated out of all hits:  86.74357155732564 %
# Correctly associated out of all hits in clusters:  86.74357155732564 %
# Incorrectly associated out of all hits:  13.256428442674352 %
# Incorrectly associated out of all hits in clusters:  13.256428442674352 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 5377757
# Identified incorrectly: 822904
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510888 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 14507
# Number of clusters where tid already exists: 1703214 , Hits: 2996023
# Number of clusters where tid already exists, that are accounted for: 1703214
# Correctly associated out of all hits:  86.72876972309888 %
# Correctly associated out of all hits in clusters:  86.72876972309888 %
# Incorrectly associated out of all hits:  13.271230276901123 %
# Incorrectly associated out of all hits in clusters:  13.271230276901123 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 5387427
# Identified incorrectly: 825046
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516314 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1705268 , Hits: 3000543
# Number of clusters where tid already exists, that are accounted for: 1705268
# Correctly associated out of all hits:  86.7195237709685 %
# Correctly associated out of all hits in clusters:  86.7195237709685 %
# Incorrectly associated out of all hits:  13.280476229031498 %
# Incorrectly associated out of all hits in clusters:  13.280476229031498 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 5387391
# Identified incorrectly: 823921
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515281 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 14436
# Number of clusters where tid already exists: 1703912 , Hits: 3000085
# Number of clusters where tid already exists, that are accounted for: 1703912
# Correctly associated out of all hits:  86.73515353922005 %
# Correctly associated out of all hits in clusters:  86.73515353922005 %
# Incorrectly associated out of all hits:  13.264846460779944 %
# Incorrectly associated out of all hits in clusters:  13.264846460779944 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 5382400
# Identified incorrectly: 822746
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514150 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 14502
# Number of clusters where tid already exists: 1706694 , Hits: 3001730
# Number of clusters where tid already exists, that are accounted for: 1706694
# Correctly associated out of all hits:  86.74090827194074 %
# Correctly associated out of all hits in clusters:  86.74090827194074 %
# Incorrectly associated out of all hits:  13.259091728059259 %
# Incorrectly associated out of all hits in clusters:  13.259091728059259 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 5387491
# Identified incorrectly: 824240
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516617 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 14382
# Number of clusters where tid already exists: 1701978 , Hits: 2995592
# Number of clusters where tid already exists, that are accounted for: 1701978
# Correctly associated out of all hits:  86.73091284860855 %
# Correctly associated out of all hits in clusters:  86.73091284860855 %
# Incorrectly associated out of all hits:  13.269087151391457 %
# Incorrectly associated out of all hits in clusters:  13.269087151391457 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 5382625
# Identified incorrectly: 821866
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513808 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 14410
# Number of clusters where tid already exists: 1700656 , Hits: 2989477
# Number of clusters where tid already exists, that are accounted for: 1700656
# Correctly associated out of all hits:  86.75369180163207 %
# Correctly associated out of all hits in clusters:  86.75369180163207 %
# Incorrectly associated out of all hits:  13.246308198367924 %
# Incorrectly associated out of all hits in clusters:  13.246308198367924 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_timetheniterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 5376103
# Identified incorrectly: 823864
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510005 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1700076 , Hits: 2990466
# Number of clusters where tid already exists, that are accounted for: 1700076
# Correctly associated out of all hits:  86.71180024022709 %
# Correctly associated out of all hits in clusters:  86.71180024022709 %
# Incorrectly associated out of all hits:  13.288199759772915 %
# Incorrectly associated out of all hits in clusters:  13.288199759772915 %

# %% [markdown]
# ### Threshold: 35mm

# %%
current_threshold = threshold_cluster_width_used[3] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_135_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 5304614
# Identified incorrectly: 901454
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515422 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 14256
# Number of clusters where tid already exists: 1703180 , Hits: 2994459
# Number of clusters where tid already exists, that are accounted for: 1703180
# Correctly associated out of all hits:  85.47463546967259 %
# Correctly associated out of all hits in clusters:  85.47463546967259 %
# Incorrectly associated out of all hits:  14.525364530327415 %
# Incorrectly associated out of all hits in clusters:  14.525364530327415 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 5300879
# Identified incorrectly: 904267
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514150 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 14502
# Number of clusters where tid already exists: 1706694 , Hits: 3001730
# Number of clusters where tid already exists, that are accounted for: 1706694
# Correctly associated out of all hits:  85.42714385769489 %
# Correctly associated out of all hits in clusters:  85.42714385769489 %
# Incorrectly associated out of all hits:  14.572856142305113 %
# Incorrectly associated out of all hits in clusters:  14.572856142305113 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 5304330
# Identified incorrectly: 903511
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513755 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1701736 , Hits: 2990977
# Number of clusters where tid already exists, that are accounted for: 1701736
# Correctly associated out of all hits:  85.44564849518535 %
# Correctly associated out of all hits in clusters:  85.44564849518535 %
# Incorrectly associated out of all hits:  14.554351504814637 %
# Incorrectly associated out of all hits in clusters:  14.554351504814637 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 5302416
# Identified incorrectly: 903060
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512018 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 14411
# Number of clusters where tid already exists: 1699252 , Hits: 2989089
# Number of clusters where tid already exists, that are accounted for: 1699252
# Correctly associated out of all hits:  85.44736938794058 %
# Correctly associated out of all hits in clusters:  85.44736938794058 %
# Incorrectly associated out of all hits:  14.552630612059414 %
# Incorrectly associated out of all hits in clusters:  14.552630612059414 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 5306300
# Identified incorrectly: 901677
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513596 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 14522
# Number of clusters where tid already exists: 1701886 , Hits: 2998250
# Number of clusters where tid already exists, that are accounted for: 1701886
# Correctly associated out of all hits:  85.47550997692163 %
# Correctly associated out of all hits in clusters:  85.47550997692163 %
# Incorrectly associated out of all hits:  14.524490023078373 %
# Incorrectly associated out of all hits in clusters:  14.524490023078373 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 5312387
# Identified incorrectly: 903066
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518733 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 14483
# Number of clusters where tid already exists: 1712446 , Hits: 3010913
# Number of clusters where tid already exists, that are accounted for: 1712446
# Correctly associated out of all hits:  85.47063263128207 %
# Correctly associated out of all hits in clusters:  85.47063263128207 %
# Incorrectly associated out of all hits:  14.529367368717937 %
# Incorrectly associated out of all hits in clusters:  14.529367368717937 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 5309277
# Identified incorrectly: 902634
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516566 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 14438
# Number of clusters where tid already exists: 1706528 , Hits: 3001690
# Number of clusters where tid already exists, that are accounted for: 1706528
# Correctly associated out of all hits:  85.46930244171239 %
# Correctly associated out of all hits in clusters:  85.46930244171239 %
# Incorrectly associated out of all hits:  14.530697558287619 %
# Incorrectly associated out of all hits in clusters:  14.530697558287619 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 5299298
# Identified incorrectly: 901729
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512203 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 14367
# Number of clusters where tid already exists: 1701994 , Hits: 2992668
# Number of clusters where tid already exists, that are accounted for: 1701994
# Correctly associated out of all hits:  85.45839261786799 %
# Correctly associated out of all hits in clusters:  85.45839261786799 %
# Incorrectly associated out of all hits:  14.541607382132025 %
# Incorrectly associated out of all hits in clusters:  14.541607382132025 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 5301444
# Identified incorrectly: 904212
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513507 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 14202
# Number of clusters where tid already exists: 1704188 , Hits: 2994306
# Number of clusters where tid already exists, that are accounted for: 1704188
# Correctly associated out of all hits:  85.4292277883273 %
# Correctly associated out of all hits in clusters:  85.4292277883273 %
# Incorrectly associated out of all hits:  14.570772211672708 %
# Incorrectly associated out of all hits in clusters:  14.570772211672708 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 5312504
# Identified incorrectly: 905088
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518266 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1714522 , Hits: 3022558
# Number of clusters where tid already exists, that are accounted for: 1714522
# Correctly associated out of all hits:  85.44311045176332 %
# Correctly associated out of all hits in clusters:  85.44311045176332 %
# Incorrectly associated out of all hits:  14.556889548236681 %
# Incorrectly associated out of all hits in clusters:  14.556889548236681 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 5303900
# Identified incorrectly: 904913
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514156 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 14472
# Number of clusters where tid already exists: 1706152 , Hits: 2999927
# Number of clusters where tid already exists, that are accounted for: 1706152
# Correctly associated out of all hits:  85.42534619741326 %
# Correctly associated out of all hits in clusters:  85.42534619741326 %
# Incorrectly associated out of all hits:  14.574653802586743 %
# Incorrectly associated out of all hits in clusters:  14.574653802586743 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 5301136
# Identified incorrectly: 901899
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511520 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 14468
# Number of clusters where tid already exists: 1705914 , Hits: 2999439
# Number of clusters where tid already exists, that are accounted for: 1705914
# Correctly associated out of all hits:  85.46035932410506 %
# Correctly associated out of all hits in clusters:  85.46035932410506 %
# Incorrectly associated out of all hits:  14.539640675894946 %
# Incorrectly associated out of all hits in clusters:  14.539640675894946 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 5297801
# Identified incorrectly: 902860
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510888 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 14507
# Number of clusters where tid already exists: 1703214 , Hits: 2996023
# Number of clusters where tid already exists, that are accounted for: 1703214
# Correctly associated out of all hits:  85.43929429459214 %
# Correctly associated out of all hits in clusters:  85.43929429459214 %
# Incorrectly associated out of all hits:  14.560705705407859 %
# Incorrectly associated out of all hits in clusters:  14.560705705407859 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 5314546
# Identified incorrectly: 906804
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3521622 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 14371
# Number of clusters where tid already exists: 1709438 , Hits: 3007068
# Number of clusters where tid already exists, that are accounted for: 1709438
# Correctly associated out of all hits:  85.42432108786679 %
# Correctly associated out of all hits in clusters:  85.42432108786679 %
# Incorrectly associated out of all hits:  14.575678912133219 %
# Incorrectly associated out of all hits in clusters:  14.575678912133219 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 5301599
# Identified incorrectly: 903401
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514406 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 14437
# Number of clusters where tid already exists: 1703322 , Hits: 2989924
# Number of clusters where tid already exists, that are accounted for: 1703322
# Correctly associated out of all hits:  85.4407574536664 %
# Correctly associated out of all hits in clusters:  85.4407574536664 %
# Incorrectly associated out of all hits:  14.559242546333602 %
# Incorrectly associated out of all hits in clusters:  14.559242546333602 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 5306858
# Identified incorrectly: 904873
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516617 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 14382
# Number of clusters where tid already exists: 1701978 , Hits: 2995592
# Number of clusters where tid already exists, that are accounted for: 1701978
# Correctly associated out of all hits:  85.43283667628235 %
# Correctly associated out of all hits in clusters:  85.43283667628235 %
# Incorrectly associated out of all hits:  14.567163323717656 %
# Incorrectly associated out of all hits in clusters:  14.567163323717656 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 5305999
# Identified incorrectly: 903306
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515272 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 14442
# Number of clusters where tid already exists: 1704266 , Hits: 2996260
# Number of clusters where tid already exists, that are accounted for: 1704266
# Correctly associated out of all hits:  85.45238154672704 %
# Correctly associated out of all hits in clusters:  85.45238154672704 %
# Incorrectly associated out of all hits:  14.54761845327295 %
# Incorrectly associated out of all hits in clusters:  14.54761845327295 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 5305358
# Identified incorrectly: 904938
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515507 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 14460
# Number of clusters where tid already exists: 1704180 , Hits: 2995314
# Number of clusters where tid already exists, that are accounted for: 1704180
# Correctly associated out of all hits:  85.42842402358922 %
# Correctly associated out of all hits in clusters:  85.42842402358922 %
# Incorrectly associated out of all hits:  14.571575976410786 %
# Incorrectly associated out of all hits in clusters:  14.571575976410786 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 5303616
# Identified incorrectly: 900875
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513808 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 14410
# Number of clusters where tid already exists: 1700656 , Hits: 2989477
# Number of clusters where tid already exists, that are accounted for: 1700656
# Correctly associated out of all hits:  85.48027549721645 %
# Correctly associated out of all hits in clusters:  85.48027549721645 %
# Incorrectly associated out of all hits:  14.519724502783548 %
# Incorrectly associated out of all hits in clusters:  14.519724502783548 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 5308231
# Identified incorrectly: 904242
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516314 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1705268 , Hits: 3000543
# Number of clusters where tid already exists, that are accounted for: 1705268
# Correctly associated out of all hits:  85.44473352238312 %
# Correctly associated out of all hits in clusters:  85.44473352238312 %
# Incorrectly associated out of all hits:  14.555266477616884 %
# Incorrectly associated out of all hits in clusters:  14.555266477616884 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 5296444
# Identified incorrectly: 900659
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510106 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 14347
# Number of clusters where tid already exists: 1699010 , Hits: 2982586
# Number of clusters where tid already exists, that are accounted for: 1699010
# Correctly associated out of all hits:  85.46645101751577 %
# Correctly associated out of all hits in clusters:  85.46645101751577 %
# Incorrectly associated out of all hits:  14.533548982484236 %
# Incorrectly associated out of all hits in clusters:  14.533548982484236 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 5308049
# Identified incorrectly: 903263
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515281 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 14436
# Number of clusters where tid already exists: 1703912 , Hits: 3000085
# Number of clusters where tid already exists, that are accounted for: 1703912
# Correctly associated out of all hits:  85.45777446053265 %
# Correctly associated out of all hits in clusters:  85.45777446053265 %
# Incorrectly associated out of all hits:  14.542225539467346 %
# Incorrectly associated out of all hits in clusters:  14.542225539467346 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 5303711
# Identified incorrectly: 899679
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511979 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 14478
# Number of clusters where tid already exists: 1703576 , Hits: 2998551
# Number of clusters where tid already exists, that are accounted for: 1703576
# Correctly associated out of all hits:  85.49697826510989 %
# Correctly associated out of all hits in clusters:  85.49697826510989 %
# Incorrectly associated out of all hits:  14.503021734890115 %
# Incorrectly associated out of all hits in clusters:  14.503021734890115 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 5300933
# Identified incorrectly: 902483
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514327 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 14638
# Number of clusters where tid already exists: 1705524 , Hits: 2997352
# Number of clusters where tid already exists, that are accounted for: 1705524
# Correctly associated out of all hits:  85.45183814852977 %
# Correctly associated out of all hits in clusters:  85.45183814852977 %
# Incorrectly associated out of all hits:  14.548161851470221 %
# Incorrectly associated out of all hits in clusters:  14.548161851470221 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 5304830
# Identified incorrectly: 905174
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514742 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 14417
# Number of clusters where tid already exists: 1703422 , Hits: 2996535
# Number of clusters where tid already exists, that are accounted for: 1703422
# Correctly associated out of all hits:  85.4239385353053 %
# Correctly associated out of all hits in clusters:  85.4239385353053 %
# Incorrectly associated out of all hits:  14.576061464694709 %
# Incorrectly associated out of all hits in clusters:  14.576061464694709 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 5296957
# Identified incorrectly: 903010
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510005 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1700076 , Hits: 2990466
# Number of clusters where tid already exists, that are accounted for: 1700076
# Correctly associated out of all hits:  85.43524505856242 %
# Correctly associated out of all hits in clusters:  85.43524505856242 %
# Incorrectly associated out of all hits:  14.564754941437592 %
# Incorrectly associated out of all hits in clusters:  14.564754941437592 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 5294839
# Identified incorrectly: 900351
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3508815 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 14453
# Number of clusters where tid already exists: 1701666 , Hits: 2991879
# Number of clusters where tid already exists, that are accounted for: 1701666
# Correctly associated out of all hits:  85.46693483170007 %
# Correctly associated out of all hits in clusters:  85.46693483170007 %
# Incorrectly associated out of all hits:  14.533065168299922 %
# Incorrectly associated out of all hits in clusters:  14.533065168299922 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 5299242
# Identified incorrectly: 902451
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513055 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 14427
# Number of clusters where tid already exists: 1704206 , Hits: 2997932
# Number of clusters where tid already exists, that are accounted for: 1704206
# Correctly associated out of all hits:  85.4483122592492 %
# Correctly associated out of all hits in clusters:  85.4483122592492 %
# Incorrectly associated out of all hits:  14.551687740750792 %
# Incorrectly associated out of all hits in clusters:  14.551687740750792 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_timetheniterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 5304660
# Identified incorrectly: 902767
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514376 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 14318
# Number of clusters where tid already exists: 1702092 , Hits: 2997962
# Number of clusters where tid already exists, that are accounted for: 1702092
# Correctly associated out of all hits:  85.4566634452568 %
# Correctly associated out of all hits in clusters:  85.4566634452568 %
# Incorrectly associated out of all hits:  14.543336554743213 %
# Incorrectly associated out of all hits in clusters:  14.543336554743213 %

# %% [markdown]
# ### Threshold: 40mm

# %%
current_threshold = threshold_cluster_width_used[4] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_158_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 5217995
# Identified incorrectly: 987005
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514406 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 14437
# Number of clusters where tid already exists: 1703322 , Hits: 2989924
# Number of clusters where tid already exists, that are accounted for: 1703322
# Correctly associated out of all hits:  84.09339242546334 %
# Correctly associated out of all hits in clusters:  84.09339242546334 %
# Incorrectly associated out of all hits:  15.906607574536665 %
# Incorrectly associated out of all hits in clusters:  15.906607574536665 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 5210969
# Identified incorrectly: 984221
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3508815 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 14453
# Number of clusters where tid already exists: 1701666 , Hits: 2991879
# Number of clusters where tid already exists, that are accounted for: 1701666
# Correctly associated out of all hits:  84.11314261548071 %
# Correctly associated out of all hits in clusters:  84.11314261548071 %
# Incorrectly associated out of all hits:  15.88685738451928 %
# Incorrectly associated out of all hits in clusters:  15.88685738451928 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 5217360
# Identified incorrectly: 988296
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513507 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 14202
# Number of clusters where tid already exists: 1704188 , Hits: 2994306
# Number of clusters where tid already exists, that are accounted for: 1704188
# Correctly associated out of all hits:  84.07427031082612 %
# Correctly associated out of all hits in clusters:  84.07427031082612 %
# Incorrectly associated out of all hits:  15.925729689173878 %
# Incorrectly associated out of all hits in clusters:  15.925729689173878 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 5221347
# Identified incorrectly: 986630
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513596 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 14522
# Number of clusters where tid already exists: 1701886 , Hits: 2998250
# Number of clusters where tid already exists, that are accounted for: 1701886
# Correctly associated out of all hits:  84.10706096366015 %
# Correctly associated out of all hits in clusters:  84.10706096366015 %
# Incorrectly associated out of all hits:  15.89293903633986 %
# Incorrectly associated out of all hits in clusters:  15.89293903633986 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 5220499
# Identified incorrectly: 988314
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514156 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 14472
# Number of clusters where tid already exists: 1706152 , Hits: 2999927
# Number of clusters where tid already exists, that are accounted for: 1706152
# Correctly associated out of all hits:  84.08207816856459 %
# Correctly associated out of all hits in clusters:  84.08207816856459 %
# Incorrectly associated out of all hits:  15.917921831435413 %
# Incorrectly associated out of all hits in clusters:  15.917921831435413 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 5223228
# Identified incorrectly: 989245
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516314 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1705268 , Hits: 3000543
# Number of clusters where tid already exists, that are accounted for: 1705268
# Correctly associated out of all hits:  84.07647003053373 %
# Correctly associated out of all hits in clusters:  84.07647003053373 %
# Incorrectly associated out of all hits:  15.923529969466266 %
# Incorrectly associated out of all hits in clusters:  15.923529969466266 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 5216847
# Identified incorrectly: 988299
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514150 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 14502
# Number of clusters where tid already exists: 1706694 , Hits: 3001730
# Number of clusters where tid already exists, that are accounted for: 1706694
# Correctly associated out of all hits:  84.07291303057173 %
# Correctly associated out of all hits in clusters:  84.07291303057173 %
# Incorrectly associated out of all hits:  15.927086969428277 %
# Incorrectly associated out of all hits in clusters:  15.927086969428277 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 5228549
# Identified incorrectly: 986904
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518733 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 14483
# Number of clusters where tid already exists: 1712446 , Hits: 3010913
# Number of clusters where tid already exists, that are accounted for: 1712446
# Correctly associated out of all hits:  84.12176875925215 %
# Correctly associated out of all hits in clusters:  84.12176875925215 %
# Incorrectly associated out of all hits:  15.878231240747859 %
# Incorrectly associated out of all hits in clusters:  15.878231240747859 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 5215921
# Identified incorrectly: 987495
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514327 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 14638
# Number of clusters where tid already exists: 1705524 , Hits: 2997352
# Number of clusters where tid already exists, that are accounted for: 1705524
# Correctly associated out of all hits:  84.08143190783916 %
# Correctly associated out of all hits in clusters:  84.08143190783916 %
# Incorrectly associated out of all hits:  15.918568092160834 %
# Incorrectly associated out of all hits in clusters:  15.918568092160834 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 5231043
# Identified incorrectly: 990307
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3521622 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 14371
# Number of clusters where tid already exists: 1709438 , Hits: 3007068
# Number of clusters where tid already exists, that are accounted for: 1709438
# Correctly associated out of all hits:  84.08212044009741 %
# Correctly associated out of all hits in clusters:  84.08212044009741 %
# Incorrectly associated out of all hits:  15.917879559902593 %
# Incorrectly associated out of all hits in clusters:  15.917879559902593 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 5216745
# Identified incorrectly: 986290
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511520 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 14468
# Number of clusters where tid already exists: 1705914 , Hits: 2999439
# Number of clusters where tid already exists, that are accounted for: 1705914
# Correctly associated out of all hits:  84.0998801393189 %
# Correctly associated out of all hits in clusters:  84.0998801393189 %
# Incorrectly associated out of all hits:  15.900119860681102 %
# Incorrectly associated out of all hits in clusters:  15.900119860681102 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 5216644
# Identified incorrectly: 984383
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512203 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 14367
# Number of clusters where tid already exists: 1701994 , Hits: 2992668
# Number of clusters where tid already exists, that are accounted for: 1701994
# Correctly associated out of all hits:  84.12548437541072 %
# Correctly associated out of all hits in clusters:  84.12548437541072 %
# Incorrectly associated out of all hits:  15.874515624589282 %
# Incorrectly associated out of all hits in clusters:  15.874515624589282 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 5219693
# Identified incorrectly: 984798
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513808 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 14410
# Number of clusters where tid already exists: 1700656 , Hits: 2989477
# Number of clusters where tid already exists, that are accounted for: 1700656
# Correctly associated out of all hits:  84.12765849769143 %
# Correctly associated out of all hits in clusters:  84.12765849769143 %
# Incorrectly associated out of all hits:  15.872341502308569 %
# Incorrectly associated out of all hits in clusters:  15.872341502308569 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 5212917
# Identified incorrectly: 987050
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510005 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1700076 , Hits: 2990466
# Number of clusters where tid already exists, that are accounted for: 1700076
# Correctly associated out of all hits:  84.07975397288405 %
# Correctly associated out of all hits in clusters:  84.07975397288405 %
# Incorrectly associated out of all hits:  15.920246027115951 %
# Incorrectly associated out of all hits in clusters:  15.920246027115951 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 5220919
# Identified incorrectly: 985149
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515422 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 14256
# Number of clusters where tid already exists: 1703180 , Hits: 2994459
# Number of clusters where tid already exists, that are accounted for: 1703180
# Correctly associated out of all hits:  84.12603600218367 %
# Correctly associated out of all hits in clusters:  84.12603600218367 %
# Incorrectly associated out of all hits:  15.87396399781633 %
# Incorrectly associated out of all hits in clusters:  15.87396399781633 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 5215015
# Identified incorrectly: 986678
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513055 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 14427
# Number of clusters where tid already exists: 1704206 , Hits: 2997932
# Number of clusters where tid already exists, that are accounted for: 1704206
# Correctly associated out of all hits:  84.09018311612651 %
# Correctly associated out of all hits in clusters:  84.09018311612651 %
# Incorrectly associated out of all hits:  15.909816883873484 %
# Incorrectly associated out of all hits in clusters:  15.909816883873484 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 5214039
# Identified incorrectly: 986622
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510888 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 14507
# Number of clusters where tid already exists: 1703214 , Hits: 2996023
# Number of clusters where tid already exists, that are accounted for: 1703214
# Correctly associated out of all hits:  84.08843831327015 %
# Correctly associated out of all hits in clusters:  84.08843831327015 %
# Incorrectly associated out of all hits:  15.91156168672985 %
# Incorrectly associated out of all hits in clusters:  15.91156168672985 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 5221178
# Identified incorrectly: 986249
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514376 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 14318
# Number of clusters where tid already exists: 1702092 , Hits: 2997962
# Number of clusters where tid already exists, that are accounted for: 1702092
# Correctly associated out of all hits:  84.11179060180652 %
# Correctly associated out of all hits in clusters:  84.11179060180652 %
# Incorrectly associated out of all hits:  15.888209398193487 %
# Incorrectly associated out of all hits in clusters:  15.888209398193487 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 5222642
# Identified incorrectly: 986663
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515272 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 14442
# Number of clusters where tid already exists: 1704266 , Hits: 2996260
# Number of clusters where tid already exists, that are accounted for: 1704266
# Correctly associated out of all hits:  84.10992856688469 %
# Correctly associated out of all hits in clusters:  84.10992856688469 %
# Incorrectly associated out of all hits:  15.890071433115299 %
# Incorrectly associated out of all hits in clusters:  15.890071433115299 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 5220301
# Identified incorrectly: 983089
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511979 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 14478
# Number of clusters where tid already exists: 1703576 , Hits: 2998551
# Number of clusters where tid already exists, that are accounted for: 1703576
# Correctly associated out of all hits:  84.15239087015325 %
# Correctly associated out of all hits in clusters:  84.15239087015325 %
# Incorrectly associated out of all hits:  15.847609129846745 %
# Incorrectly associated out of all hits in clusters:  15.847609129846745 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 5221052
# Identified incorrectly: 988952
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514742 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 14417
# Number of clusters where tid already exists: 1703422 , Hits: 2996535
# Number of clusters where tid already exists, that are accounted for: 1703422
# Correctly associated out of all hits:  84.07485727867486 %
# Correctly associated out of all hits in clusters:  84.07485727867486 %
# Incorrectly associated out of all hits:  15.92514272132514 %
# Incorrectly associated out of all hits in clusters:  15.92514272132514 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 5218329
# Identified incorrectly: 987147
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512018 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 14411
# Number of clusters where tid already exists: 1699252 , Hits: 2989089
# Number of clusters where tid already exists, that are accounted for: 1699252
# Correctly associated out of all hits:  84.09232426327972 %
# Correctly associated out of all hits in clusters:  84.09232426327972 %
# Incorrectly associated out of all hits:  15.907675736720277 %
# Incorrectly associated out of all hits in clusters:  15.907675736720277 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 5223620
# Identified incorrectly: 988291
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516566 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 14438
# Number of clusters where tid already exists: 1706528 , Hits: 3001690
# Number of clusters where tid already exists, that are accounted for: 1706528
# Correctly associated out of all hits:  84.09038700007132 %
# Correctly associated out of all hits in clusters:  84.09038700007132 %
# Incorrectly associated out of all hits:  15.909612999928685 %
# Incorrectly associated out of all hits in clusters:  15.909612999928685 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 5220007
# Identified incorrectly: 987834
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513755 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1701736 , Hits: 2990977
# Number of clusters where tid already exists, that are accounted for: 1701736
# Correctly associated out of all hits:  84.08731795804692 %
# Correctly associated out of all hits in clusters:  84.08731795804692 %
# Incorrectly associated out of all hits:  15.91268204195307 %
# Incorrectly associated out of all hits in clusters:  15.91268204195307 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 5220061
# Identified incorrectly: 990235
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515507 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 14460
# Number of clusters where tid already exists: 1704180 , Hits: 2995314
# Number of clusters where tid already exists, that are accounted for: 1704180
# Correctly associated out of all hits:  84.05494681734977 %
# Correctly associated out of all hits in clusters:  84.05494681734977 %
# Incorrectly associated out of all hits:  15.94505318265023 %
# Incorrectly associated out of all hits in clusters:  15.94505318265023 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 5223729
# Identified incorrectly: 988002
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516617 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 14382
# Number of clusters where tid already exists: 1701978 , Hits: 2995592
# Number of clusters where tid already exists, that are accounted for: 1701978
# Correctly associated out of all hits:  84.09457846774112 %
# Correctly associated out of all hits in clusters:  84.09457846774112 %
# Incorrectly associated out of all hits:  15.905421532258883 %
# Incorrectly associated out of all hits in clusters:  15.905421532258883 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 5212243
# Identified incorrectly: 984860
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510106 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 14347
# Number of clusters where tid already exists: 1699010 , Hits: 2982586
# Number of clusters where tid already exists, that are accounted for: 1699010
# Correctly associated out of all hits:  84.10773550157226 %
# Correctly associated out of all hits in clusters:  84.10773550157226 %
# Incorrectly associated out of all hits:  15.892264498427734 %
# Incorrectly associated out of all hits in clusters:  15.892264498427734 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 5228808
# Identified incorrectly: 988784
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518266 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1714522 , Hits: 3022558
# Number of clusters where tid already exists, that are accounted for: 1714522
# Correctly associated out of all hits:  84.09699446345145 %
# Correctly associated out of all hits in clusters:  84.09699446345145 %
# Incorrectly associated out of all hits:  15.903005536548555 %
# Incorrectly associated out of all hits in clusters:  15.903005536548555 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_timetheniterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 5224986
# Identified incorrectly: 986326
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515281 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 14436
# Number of clusters where tid already exists: 1703912 , Hits: 3000085
# Number of clusters where tid already exists, that are accounted for: 1703912
# Correctly associated out of all hits:  84.12048855378703 %
# Correctly associated out of all hits in clusters:  84.12048855378703 %
# Incorrectly associated out of all hits:  15.879511446212973 %
# Incorrectly associated out of all hits in clusters:  15.879511446212973 %

# %% [markdown]
# ### No Threshold

# %%
current_threshold = threshold_cluster_width_used[5] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_timetheniterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_162_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 2683960
# Identified incorrectly: 3520531
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513808 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 14410
# Number of clusters where tid already exists: 1700656 , Hits: 2989477
# Number of clusters where tid already exists, that are accounted for: 1700656
# Correctly associated out of all hits:  43.258343029267024 %
# Correctly associated out of all hits in clusters:  43.258343029267024 %
# Incorrectly associated out of all hits:  56.74165697073297 %
# Incorrectly associated out of all hits in clusters:  56.74165697073297 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 2671953
# Identified incorrectly: 3529740
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513055 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 14427
# Number of clusters where tid already exists: 1704206 , Hits: 2997932
# Number of clusters where tid already exists, that are accounted for: 1704206
# Correctly associated out of all hits:  43.08425134878492 %
# Correctly associated out of all hits in clusters:  43.08425134878492 %
# Incorrectly associated out of all hits:  56.91574865121508 %
# Incorrectly associated out of all hits in clusters:  56.91574865121508 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 2673661
# Identified incorrectly: 3529755
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514327 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 14638
# Number of clusters where tid already exists: 1705524 , Hits: 2997352
# Number of clusters where tid already exists, that are accounted for: 1705524
# Correctly associated out of all hits:  43.0998179067791 %
# Correctly associated out of all hits in clusters:  43.0998179067791 %
# Incorrectly associated out of all hits:  56.90018209322089 %
# Incorrectly associated out of all hits in clusters:  56.90018209322089 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 2672915
# Identified incorrectly: 3522275
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3508815 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 14453
# Number of clusters where tid already exists: 1701666 , Hits: 2991879
# Number of clusters where tid already exists, that are accounted for: 1701666
# Correctly associated out of all hits:  43.145004430856844 %
# Correctly associated out of all hits in clusters:  43.145004430856844 %
# Incorrectly associated out of all hits:  56.854995569143156 %
# Incorrectly associated out of all hits in clusters:  56.854995569143156 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 2669236
# Identified incorrectly: 3533799
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511520 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 14468
# Number of clusters where tid already exists: 1705914 , Hits: 2999439
# Number of clusters where tid already exists, that are accounted for: 1705914
# Correctly associated out of all hits:  43.031129116634034 %
# Correctly associated out of all hits in clusters:  43.031129116634034 %
# Incorrectly associated out of all hits:  56.968870883365966 %
# Incorrectly associated out of all hits in clusters:  56.968870883365966 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 2661808
# Identified incorrectly: 3555784
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518266 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1714522 , Hits: 3022558
# Number of clusters where tid already exists, that are accounted for: 1714522
# Correctly associated out of all hits:  42.81091457914897 %
# Correctly associated out of all hits in clusters:  42.81091457914897 %
# Incorrectly associated out of all hits:  57.18908542085103 %
# Incorrectly associated out of all hits in clusters:  57.18908542085103 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 2676969
# Identified incorrectly: 3524058
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512203 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 14367
# Number of clusters where tid already exists: 1701994 , Hits: 2992668
# Number of clusters where tid already exists, that are accounted for: 1701994
# Correctly associated out of all hits:  43.16976849157406 %
# Correctly associated out of all hits in clusters:  43.16976849157406 %
# Incorrectly associated out of all hits:  56.830231508425946 %
# Incorrectly associated out of all hits in clusters:  56.830231508425946 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 2678871
# Identified incorrectly: 3533040
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516566 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 14438
# Number of clusters where tid already exists: 1706528 , Hits: 3001690
# Number of clusters where tid already exists, that are accounted for: 1706528
# Correctly associated out of all hits:  43.124748567711286 %
# Correctly associated out of all hits in clusters:  43.124748567711286 %
# Incorrectly associated out of all hits:  56.875251432288714 %
# Incorrectly associated out of all hits in clusters:  56.875251432288714 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 2681351
# Identified incorrectly: 3527954
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515272 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 14442
# Number of clusters where tid already exists: 1704266 , Hits: 2996260
# Number of clusters where tid already exists, that are accounted for: 1704266
# Correctly associated out of all hits:  43.18278776771313 %
# Correctly associated out of all hits in clusters:  43.18278776771313 %
# Incorrectly associated out of all hits:  56.81721223228686 %
# Incorrectly associated out of all hits in clusters:  56.81721223228686 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 2674166
# Identified incorrectly: 3529224
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3511979 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 14478
# Number of clusters where tid already exists: 1703576 , Hits: 2998551
# Number of clusters where tid already exists, that are accounted for: 1703576
# Correctly associated out of all hits:  43.108139259340454 %
# Correctly associated out of all hits in clusters:  43.108139259340454 %
# Incorrectly associated out of all hits:  56.89186074065954 %
# Incorrectly associated out of all hits in clusters:  56.89186074065954 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 2682931
# Identified incorrectly: 3524910
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513755 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1701736 , Hits: 2990977
# Number of clusters where tid already exists, that are accounted for: 1701736
# Correctly associated out of all hits:  43.21842328113751 %
# Correctly associated out of all hits in clusters:  43.21842328113751 %
# Incorrectly associated out of all hits:  56.78157671886248 %
# Incorrectly associated out of all hits in clusters:  56.78157671886248 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 2678714
# Identified incorrectly: 3533759
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516314 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 14422
# Number of clusters where tid already exists: 1705268 , Hits: 3000543
# Number of clusters where tid already exists, that are accounted for: 1705268
# Correctly associated out of all hits:  43.11832019229701 %
# Correctly associated out of all hits in clusters:  43.11832019229701 %
# Incorrectly associated out of all hits:  56.88167980770299 %
# Incorrectly associated out of all hits in clusters:  56.88167980770299 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 2679061
# Identified incorrectly: 3526595
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513507 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 14202
# Number of clusters where tid already exists: 1704188 , Hits: 2994306
# Number of clusters where tid already exists, that are accounted for: 1704188
# Correctly associated out of all hits:  43.171277943862826 %
# Correctly associated out of all hits in clusters:  43.171277943862826 %
# Incorrectly associated out of all hits:  56.82872205613718 %
# Incorrectly associated out of all hits in clusters:  56.82872205613718 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 2679675
# Identified incorrectly: 3527752
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514376 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 14318
# Number of clusters where tid already exists: 1702092 , Hits: 2997962
# Number of clusters where tid already exists, that are accounted for: 1702092
# Correctly associated out of all hits:  43.16885240857444 %
# Correctly associated out of all hits in clusters:  43.16885240857444 %
# Incorrectly associated out of all hits:  56.83114759142556 %
# Incorrectly associated out of all hits in clusters:  56.83114759142556 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 2672644
# Identified incorrectly: 3542809
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3518733 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 14483
# Number of clusters where tid already exists: 1712446 , Hits: 3010913
# Number of clusters where tid already exists, that are accounted for: 1712446
# Correctly associated out of all hits:  42.99998728974381 %
# Correctly associated out of all hits in clusters:  42.99998728974381 %
# Incorrectly associated out of all hits:  57.00001271025619 %
# Incorrectly associated out of all hits in clusters:  57.00001271025619 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 2679226
# Identified incorrectly: 3530778
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514742 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 14417
# Number of clusters where tid already exists: 1703422 , Hits: 2996535
# Number of clusters where tid already exists, that are accounted for: 1703422
# Correctly associated out of all hits:  43.14370811999477 %
# Correctly associated out of all hits in clusters:  43.14370811999477 %
# Incorrectly associated out of all hits:  56.85629188000523 %
# Incorrectly associated out of all hits in clusters:  56.85629188000523 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 2681828
# Identified incorrectly: 3529903
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3516617 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 14382
# Number of clusters where tid already exists: 1701978 , Hits: 2995592
# Number of clusters where tid already exists, that are accounted for: 1701978
# Correctly associated out of all hits:  43.173601690092504 %
# Correctly associated out of all hits in clusters:  43.173601690092504 %
# Incorrectly associated out of all hits:  56.826398309907496 %
# Incorrectly associated out of all hits in clusters:  56.826398309907496 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 2680783
# Identified incorrectly: 3540567
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3521622 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 14371
# Number of clusters where tid already exists: 1709438 , Hits: 3007068
# Number of clusters where tid already exists, that are accounted for: 1709438
# Correctly associated out of all hits:  43.090052802044575 %
# Correctly associated out of all hits in clusters:  43.090052802044575 %
# Incorrectly associated out of all hits:  56.909947197955425 %
# Incorrectly associated out of all hits in clusters:  56.909947197955425 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 2675090
# Identified incorrectly: 3533723
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514156 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 14472
# Number of clusters where tid already exists: 1706152 , Hits: 2999927
# Number of clusters where tid already exists, that are accounted for: 1706152
# Correctly associated out of all hits:  43.08536913577523 %
# Correctly associated out of all hits in clusters:  43.08536913577523 %
# Incorrectly associated out of all hits:  56.914630864224776 %
# Incorrectly associated out of all hits in clusters:  56.914630864224776 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 2681987
# Identified incorrectly: 3523489
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3512018 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 14411
# Number of clusters where tid already exists: 1699252 , Hits: 2989089
# Number of clusters where tid already exists, that are accounted for: 1699252
# Correctly associated out of all hits:  43.219682100132204 %
# Correctly associated out of all hits in clusters:  43.219682100132204 %
# Incorrectly associated out of all hits:  56.78031789986779 %
# Incorrectly associated out of all hits in clusters:  56.78031789986779 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 2677291
# Identified incorrectly: 3522676
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510005 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 14564
# Number of clusters where tid already exists: 1700076 , Hits: 2990466
# Number of clusters where tid already exists, that are accounted for: 1700076
# Correctly associated out of all hits:  43.182342744727514 %
# Correctly associated out of all hits in clusters:  43.182342744727514 %
# Incorrectly associated out of all hits:  56.817657255272486 %
# Incorrectly associated out of all hits in clusters:  56.817657255272486 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 2677598
# Identified incorrectly: 3533714
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515281 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 14436
# Number of clusters where tid already exists: 1703912 , Hits: 3000085
# Number of clusters where tid already exists, that are accounted for: 1703912
# Correctly associated out of all hits:  43.108412522185326 %
# Correctly associated out of all hits in clusters:  43.108412522185326 %
# Incorrectly associated out of all hits:  56.89158747781467 %
# Incorrectly associated out of all hits in clusters:  56.89158747781467 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 2670533
# Identified incorrectly: 3530128
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510888 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 14507
# Number of clusters where tid already exists: 1703214 , Hits: 2996023
# Number of clusters where tid already exists, that are accounted for: 1703214
# Correctly associated out of all hits:  43.068521243138434 %
# Correctly associated out of all hits in clusters:  43.068521243138434 %
# Incorrectly associated out of all hits:  56.931478756861566 %
# Incorrectly associated out of all hits in clusters:  56.931478756861566 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 2673999
# Identified incorrectly: 3531147
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514150 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 14502
# Number of clusters where tid already exists: 1706694 , Hits: 3001730
# Number of clusters where tid already exists, that are accounted for: 1706694
# Correctly associated out of all hits:  43.093248732584215 %
# Correctly associated out of all hits in clusters:  43.093248732584215 %
# Incorrectly associated out of all hits:  56.906751267415785 %
# Incorrectly associated out of all hits in clusters:  56.906751267415785 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 2682545
# Identified incorrectly: 3527751
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515507 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 14460
# Number of clusters where tid already exists: 1704180 , Hits: 2995314
# Number of clusters where tid already exists, that are accounted for: 1704180
# Correctly associated out of all hits:  43.195123066597795 %
# Correctly associated out of all hits in clusters:  43.195123066597795 %
# Incorrectly associated out of all hits:  56.804876933402205 %
# Incorrectly associated out of all hits in clusters:  56.804876933402205 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 2678950
# Identified incorrectly: 3527118
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3515422 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 14256
# Number of clusters where tid already exists: 1703180 , Hits: 2994459
# Number of clusters where tid already exists, that are accounted for: 1703180
# Correctly associated out of all hits:  43.16662337570262 %
# Correctly associated out of all hits in clusters:  43.16662337570262 %
# Incorrectly associated out of all hits:  56.83337662429738 %
# Incorrectly associated out of all hits in clusters:  56.83337662429738 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 2683214
# Identified incorrectly: 3521786
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3514406 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 14437
# Number of clusters where tid already exists: 1703322 , Hits: 2989924
# Number of clusters where tid already exists, that are accounted for: 1703322
# Correctly associated out of all hits:  43.24277195809831 %
# Correctly associated out of all hits in clusters:  43.24277195809831 %
# Incorrectly associated out of all hits:  56.75722804190169 %
# Incorrectly associated out of all hits in clusters:  56.75722804190169 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 2677774
# Identified incorrectly: 3530203
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3513596 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 14522
# Number of clusters where tid already exists: 1701886 , Hits: 2998250
# Number of clusters where tid already exists, that are accounted for: 1701886
# Correctly associated out of all hits:  43.134405942547794 %
# Correctly associated out of all hits in clusters:  43.134405942547794 %
# Incorrectly associated out of all hits:  56.86559405745221 %
# Incorrectly associated out of all hits in clusters:  56.86559405745221 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_timetheniterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 2682804
# Identified incorrectly: 3514299
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 3510106 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 14347
# Number of clusters where tid already exists: 1699010 , Hits: 2982586
# Number of clusters where tid already exists, that are accounted for: 1699010
# Correctly associated out of all hits:  43.29126044863221 %
# Correctly associated out of all hits in clusters:  43.29126044863221 %
# Incorrectly associated out of all hits:  56.70873955136779 %
# Incorrectly associated out of all hits in clusters:  56.70873955136779 %

# %% [markdown]
# # Pure spatial clustering

# %%
time_threshold_used = 1.2
threshold_cluster_width_used = [20,25,30,35,40,999999]

function_str = "mt_compare_to_tid"
src = "./testdata/sorted/root_files_fixed/mu3e_sorted_000*.root"

for threshold in threshold_cluster_width_used:
    args = (time_threshold_used, threshold, "big", None, "iterativespatial")

    #clump.multithreading.run_mt(function_str, src, args)

# %% [markdown]
# ## Efficiency statistics

# %% [markdown]
# ### Threshold: 20mm

# %%
current_threshold = threshold_cluster_width_used[0] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_iterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_164_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203396
# Identified correctly: 5307319
# Identified incorrectly: 896077
# Total #hits in frames/#hits in clusters =  1.0000032240405095
# Total number of clusters: 3293416 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 167983
# Number of clusters where tid already exists: 1400670 , Hits: 2659624
# Number of clusters where tid already exists, that are accounted for: 1400670
# Correctly associated out of all hits:  85.55478143010238 %
# Correctly associated out of all hits in clusters:  85.5550572621835 %
# Incorrectly associated out of all hits:  14.444896166886116 %
# Incorrectly associated out of all hits in clusters:  14.444942737816513 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210264
# Identified correctly: 5310178
# Identified incorrectly: 900086
# Total #hits in frames/#hits in clusters =  1.0000051527600116
# Total number of clusters: 3293758 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 168300
# Number of clusters where tid already exists: 1398956 , Hits: 2657985
# Number of clusters where tid already exists, that are accounted for: 1398956
# Correctly associated out of all hits:  85.50603707134088 %
# Correctly associated out of all hits in clusters:  85.50647766342945 %
# Incorrectly associated out of all hits:  14.493447655313048 %
# Incorrectly associated out of all hits in clusters:  14.493522336570555 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211690
# Identified correctly: 5313168
# Identified incorrectly: 898522
# Total #hits in frames/#hits in clusters =  1.0000066004581685
# Total number of clusters: 3295657 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 167744
# Number of clusters where tid already exists: 1398008 , Hits: 2660278
# Number of clusters where tid already exists, that are accounted for: 1398008
# Correctly associated out of all hits:  85.53441866687402 %
# Correctly associated out of all hits in clusters:  85.53498323322638 %
# Incorrectly associated out of all hits:  14.464921291665721 %
# Incorrectly associated out of all hits in clusters:  14.465016766773616 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221325
# Identified correctly: 5319251
# Identified incorrectly: 902074
# Total #hits in frames/#hits in clusters =  1.000004018436587
# Total number of clusters: 3299568 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 168570
# Number of clusters where tid already exists: 1403252 , Hits: 2665503
# Number of clusters where tid already exists, that are accounted for: 1403252
# Correctly associated out of all hits:  85.49994776053428 %
# Correctly associated out of all hits in clusters:  85.50029133665257 %
# Incorrectly associated out of all hits:  14.499650397421782 %
# Incorrectly associated out of all hits in clusters:  14.499708663347437 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211875
# Identified correctly: 5313710
# Identified incorrectly: 898165
# Total #hits in frames/#hits in clusters =  1.000005795351645
# Total number of clusters: 3295597 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 168174
# Number of clusters where tid already exists: 1402074 , Hits: 2662308
# Number of clusters where tid already exists, that are accounted for: 1402074
# Correctly associated out of all hits:  85.54066534436826 %
# Correctly associated out of all hits in clusters:  85.54116108260388 %
# Incorrectly associated out of all hits:  14.458755123825824 %
# Incorrectly associated out of all hits in clusters:  14.458838917396116 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199929
# Identified correctly: 5300133
# Identified incorrectly: 899796
# Total #hits in frames/#hits in clusters =  1.0000061291024462
# Total number of clusters: 3288345 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 168706
# Number of clusters where tid already exists: 1397006 , Hits: 2656445
# Number of clusters where tid already exists, that are accounted for: 1397006
# Correctly associated out of all hits:  85.48647113766896 %
# Correctly associated out of all hits in clusters:  85.48699509300832 %
# Incorrectly associated out of all hits:  14.512915955842992 %
# Incorrectly associated out of all hits in clusters:  14.513004906991677 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217555
# Identified correctly: 5317945
# Identified incorrectly: 899610
# Total #hits in frames/#hits in clusters =  1.000005950892272
# Total number of clusters: 3296930 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 168405
# Number of clusters where tid already exists: 1407466 , Hits: 2680026
# Number of clusters where tid already exists, that are accounted for: 1407466
# Correctly associated out of all hits:  85.53062021438525 %
# Correctly associated out of all hits in clusters:  85.5311291978921 %
# Incorrectly associated out of all hits:  14.468784699928847 %
# Incorrectly associated out of all hits in clusters:  14.468870802107903 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203362
# Identified correctly: 5307762
# Identified incorrectly: 895600
# Total #hits in frames/#hits in clusters =  1.0000045136814522
# Total number of clusters: 3291451 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 167872
# Number of clusters where tid already exists: 1398272 , Hits: 2659927
# Number of clusters where tid already exists, that are accounted for: 1398272
# Correctly associated out of all hits:  85.56228126879013 %
# Correctly associated out of all hits in clusters:  85.56266746967209 %
# Incorrectly associated out of all hits:  14.437267365101984 %
# Incorrectly associated out of all hits in clusters:  14.43733253032791 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209283
# Identified correctly: 5311432
# Identified incorrectly: 897851
# Total #hits in frames/#hits in clusters =  1.0000035430821883
# Total number of clusters: 3293370 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 168211
# Number of clusters where tid already exists: 1398610 , Hits: 2658319
# Number of clusters where tid already exists, that are accounted for: 1398610
# Correctly associated out of all hits:  85.53987926184975 %
# Correctly associated out of all hits in clusters:  85.54018233667236 %
# Incorrectly associated out of all hits:  14.459766431186743 %
# Incorrectly associated out of all hits in clusters:  14.459817663327634 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208784
# Identified correctly: 5310688
# Identified incorrectly: 898096
# Total #hits in frames/#hits in clusters =  1.0000046708018833
# Total number of clusters: 3292499 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 168422
# Number of clusters where tid already exists: 1399700 , Hits: 2659833
# Number of clusters where tid already exists, that are accounted for: 1399700
# Correctly associated out of all hits:  85.5346746632569 %
# Correctly associated out of all hits in clusters:  85.5350741787764 %
# Incorrectly associated out of all hits:  14.464858258736413 %
# Incorrectly associated out of all hits in clusters:  14.46492582122361 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6209983
# Identified correctly: 5311338
# Identified incorrectly: 898645
# Total #hits in frames/#hits in clusters =  1.0000033816517695
# Total number of clusters: 3293180 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 168593
# Number of clusters where tid already exists: 1398394 , Hits: 2658187
# Number of clusters where tid already exists, that are accounted for: 1398394
# Correctly associated out of all hits:  85.52873717955737 %
# Correctly associated out of all hits in clusters:  85.52902640796279 %
# Incorrectly associated out of all hits:  14.470924656409238 %
# Incorrectly associated out of all hits in clusters:  14.470973592037208 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195156
# Identified correctly: 5299264
# Identified incorrectly: 895892
# Total #hits in frames/#hits in clusters =  1.0000054881588132
# Total number of clusters: 3287357 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 168151
# Number of clusters where tid already exists: 1395260 , Hits: 2653484
# Number of clusters where tid already exists, that are accounted for: 1395260
# Correctly associated out of all hits:  85.53836121248904 %
# Correctly associated out of all hits in clusters:  85.5388306606 %
# Incorrectly associated out of all hits:  14.461089974641617 %
# Incorrectly associated out of all hits in clusters:  14.461169339400008 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212430
# Identified correctly: 5313274
# Identified incorrectly: 899156
# Total #hits in frames/#hits in clusters =  1.000006921607165
# Total number of clusters: 3294403 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 168492
# Number of clusters where tid already exists: 1399866 , Hits: 2662309
# Number of clusters where tid already exists, that are accounted for: 1399866
# Correctly associated out of all hits:  85.52590892547943 %
# Correctly associated out of all hits in clusters:  85.52650090222345 %
# Incorrectly associated out of all hits:  14.473398918594897 %
# Incorrectly associated out of all hits in clusters:  14.473499097776553 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211271
# Identified correctly: 5311772
# Identified incorrectly: 899499
# Total #hits in frames/#hits in clusters =  1.000006600903422
# Total number of clusters: 3293223 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 168818
# Number of clusters where tid already exists: 1397400 , Hits: 2659748
# Number of clusters where tid already exists, that are accounted for: 1397400
# Correctly associated out of all hits:  85.51771348790722 %
# Correctly associated out of all hits in clusters:  85.51827798207485 %
# Incorrectly associated out of all hits:  14.48162642610772 %
# Incorrectly associated out of all hits in clusters:  14.481722017925156 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197072
# Identified correctly: 5299519
# Identified incorrectly: 897553
# Total #hits in frames/#hits in clusters =  1.000005002362406
# Total number of clusters: 3289079 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 167738
# Number of clusters where tid already exists: 1394930 , Hits: 2645941
# Number of clusters where tid already exists, that are accounted for: 1394930
# Correctly associated out of all hits:  85.51607097703557 %
# Correctly associated out of all hits in clusters:  85.51649875941412 %
# Incorrectly associated out of all hits:  14.483428789226192 %
# Incorrectly associated out of all hits in clusters:  14.483501240585877 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205447
# Identified correctly: 5308086
# Identified incorrectly: 897361
# Total #hits in frames/#hits in clusters =  1.0000046733136227
# Total number of clusters: 3291159 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 167651
# Number of clusters where tid already exists: 1396400 , Hits: 2652089
# Number of clusters where tid already exists, that are accounted for: 1396400
# Correctly associated out of all hits:  85.53874029969658 %
# Correctly associated out of all hits in clusters:  85.5391400490569 %
# Incorrectly associated out of all hits:  14.460792371125116 %
# Incorrectly associated out of all hits in clusters:  14.460859950943098 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205108
# Identified correctly: 5307572
# Identified incorrectly: 897536
# Total #hits in frames/#hits in clusters =  1.0000061239868832
# Total number of clusters: 3292066 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 168629
# Number of clusters where tid already exists: 1399912 , Hits: 2661967
# Number of clusters where tid already exists, that are accounted for: 1399912
# Correctly associated out of all hits:  85.53500594506559 %
# Correctly associated out of all hits in clusters:  85.53552976032005 %
# Incorrectly associated out of all hits:  14.464381659996397 %
# Incorrectly associated out of all hits in clusters:  14.464470239679953 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200620
# Identified correctly: 5305622
# Identified incorrectly: 894998
# Total #hits in frames/#hits in clusters =  1.0000066122420017
# Total number of clusters: 3290465 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 167426
# Number of clusters where tid already exists: 1398172 , Hits: 2656606
# Number of clusters where tid already exists, that are accounted for: 1398172
# Correctly associated out of all hits:  85.56542600861424 %
# Correctly associated out of all hits in clusters:  85.56599178791798 %
# Incorrectly associated out of all hits:  14.433912771557742 %
# Incorrectly associated out of all hits in clusters:  14.434008212082018 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203009
# Identified correctly: 5306650
# Identified incorrectly: 896359
# Total #hits in frames/#hits in clusters =  1.0000041915141507
# Total number of clusters: 3290643 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 167854
# Number of clusters where tid already exists: 1400708 , Hits: 2661698
# Number of clusters where tid already exists, that are accounted for: 1400708
# Correctly associated out of all hits:  85.54925129392306 %
# Correctly associated out of all hits in clusters:  85.54960987482043 %
# Incorrectly associated out of all hits:  14.450329556418753 %
# Incorrectly associated out of all hits in clusters:  14.45039012517957 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6200986
# Identified correctly: 5304893
# Identified incorrectly: 896093
# Total #hits in frames/#hits in clusters =  1.0000066118517281
# Total number of clusters: 3291392 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 167799
# Number of clusters where tid already exists: 1397614 , Hits: 2655174
# Number of clusters where tid already exists, that are accounted for: 1397614
# Correctly associated out of all hits:  85.54861960768757 %
# Correctly associated out of all hits in clusters:  85.54918524247596 %
# Incorrectly associated out of all hits:  14.450719211511256 %
# Incorrectly associated out of all hits in clusters:  14.450814757524045 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201661
# Identified correctly: 5303428
# Identified incorrectly: 898233
# Total #hits in frames/#hits in clusters =  1.0000051599079667
# Total number of clusters: 3291672 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 168486
# Number of clusters where tid already exists: 1400700 , Hits: 2661462
# Number of clusters where tid already exists, that are accounted for: 1400700
# Correctly associated out of all hits:  85.51580995705527 %
# Correctly associated out of all hits in clusters:  85.51625121076434 %
# Incorrectly associated out of all hits:  14.483674054810518 %
# Incorrectly associated out of all hits in clusters:  14.483748789235658 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204459
# Identified correctly: 5305949
# Identified incorrectly: 898510
# Total #hits in frames/#hits in clusters =  1.0000051575810236
# Total number of clusters: 3292016 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 168398
# Number of clusters where tid already exists: 1397188 , Hits: 2653421
# Number of clusters where tid already exists, that are accounted for: 1397188
# Correctly associated out of all hits:  85.5178772924322 %
# Correctly associated out of all hits in clusters:  85.51831835781331 %
# Incorrectly associated out of all hits:  14.481606952125484 %
# Incorrectly associated out of all hits in clusters:  14.481681642186693 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207806
# Identified correctly: 5309551
# Identified incorrectly: 898255
# Total #hits in frames/#hits in clusters =  1.0000056380627873
# Total number of clusters: 3292286 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 168205
# Number of clusters where tid already exists: 1397286 , Hits: 2653095
# Number of clusters where tid already exists, that are accounted for: 1397286
# Correctly associated out of all hits:  85.52975180904278 %
# Correctly associated out of all hits in clusters:  85.53023403115368 %
# Incorrectly associated out of all hits:  14.469684387857226 %
# Incorrectly associated out of all hits in clusters:  14.469765968846321 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205622
# Identified correctly: 5306097
# Identified incorrectly: 899525
# Total #hits in frames/#hits in clusters =  1.00000547890284
# Total number of clusters: 3292144 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 168399
# Number of clusters where tid already exists: 1400386 , Hits: 2658853
# Number of clusters where tid already exists, that are accounted for: 1400386
# Correctly associated out of all hits:  85.50420777432717 %
# Correctly associated out of all hits in clusters:  85.50467624357397 %
# Incorrectly associated out of all hits:  14.495244338390656 %
# Incorrectly associated out of all hits in clusters:  14.495323756426028 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6204978
# Identified correctly: 5307213
# Identified incorrectly: 897765
# Total #hits in frames/#hits in clusters =  1.000003545540371
# Total number of clusters: 3292825 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 168266
# Number of clusters where tid already exists: 1398004 , Hits: 2653009
# Number of clusters where tid already exists, that are accounted for: 1398004
# Correctly associated out of all hits:  85.53123287671232 %
# Correctly associated out of all hits in clusters:  85.53153613115147 %
# Incorrectly associated out of all hits:  14.468412570507654 %
# Incorrectly associated out of all hits in clusters:  14.468463868848527 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207940
# Identified correctly: 5312063
# Identified incorrectly: 895877
# Total #hits in frames/#hits in clusters =  1.0000059601091504
# Total number of clusters: 3292619 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 168391
# Number of clusters where tid already exists: 1397762 , Hits: 2660635
# Number of clusters where tid already exists, that are accounted for: 1397762
# Correctly associated out of all hits:  85.56834215075217 %
# Correctly associated out of all hits in clusters:  85.56885214741122 %
# Incorrectly associated out of all hits:  14.431061841885047 %
# Incorrectly associated out of all hits in clusters:  14.431147852588781 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207383
# Identified correctly: 5309050
# Identified incorrectly: 898333
# Total #hits in frames/#hits in clusters =  1.0000070883333605
# Total number of clusters: 3292708 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 168534
# Number of clusters where tid already exists: 1397556 , Hits: 2658135
# Number of clusters where tid already exists, that are accounted for: 1397556
# Correctly associated out of all hits:  85.52738517907662 %
# Correctly associated out of all hits in clusters:  85.52799142569421 %
# Incorrectly associated out of all hits:  14.471905992611754 %
# Incorrectly associated out of all hits in clusters:  14.47200857430579 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215423
# Identified correctly: 5316339
# Identified incorrectly: 899084
# Total #hits in frames/#hits in clusters =  1.0000048267028647
# Total number of clusters: 3297152 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 168343
# Number of clusters where tid already exists: 1406848 , Hits: 2673495
# Number of clusters where tid already exists, that are accounted for: 1406848
# Correctly associated out of all hits:  85.53421609012247 %
# Correctly associated out of all hits in clusters:  85.53462893836831 %
# Incorrectly associated out of all hits:  14.465301241920741 %
# Incorrectly associated out of all hits in clusters:  14.465371061631686 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_iterativespatial_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206045
# Identified correctly: 5308669
# Identified incorrectly: 897376
# Total #hits in frames/#hits in clusters =  1.000003706064007
# Total number of clusters: 3293755 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 168141
# Number of clusters where tid already exists: 1397456 , Hits: 2653446
# Number of clusters where tid already exists, that are accounted for: 1397456
# Correctly associated out of all hits:  85.53997474729572 %
# Correctly associated out of all hits in clusters:  85.54029176391728 %
# Incorrectly associated out of all hits:  14.45965464767708 %
# Incorrectly associated out of all hits in clusters:  14.459708236082724 %

# %% [markdown]
# ### Threshold: 25mm

# %%
current_threshold = threshold_cluster_width_used[1] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_iterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_158_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6204978
# Identified correctly: 5253135
# Identified incorrectly: 951843
# Total #hits in frames/#hits in clusters =  1.000003545540371
# Total number of clusters: 3292825 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 168266
# Number of clusters where tid already exists: 1398004 , Hits: 2653009
# Number of clusters where tid already exists, that are accounted for: 1398004
# Correctly associated out of all hits:  84.6597099113618 %
# Correctly associated out of all hits in clusters:  84.66001007578109 %
# Incorrectly associated out of all hits:  15.33993553585818 %
# Incorrectly associated out of all hits in clusters:  15.33998992421891 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204459
# Identified correctly: 5252477
# Identified incorrectly: 951982
# Total #hits in frames/#hits in clusters =  1.0000051575810236
# Total number of clusters: 3292016 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 168398
# Number of clusters where tid already exists: 1397188 , Hits: 2653421
# Number of clusters where tid already exists, that are accounted for: 1397188
# Correctly associated out of all hits:  84.6560499483358 %
# Correctly associated out of all hits in clusters:  84.65648656877256 %
# Incorrectly associated out of all hits:  15.343434296221881 %
# Incorrectly associated out of all hits in clusters:  15.343513431227446 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217555
# Identified correctly: 5263334
# Identified incorrectly: 954221
# Total #hits in frames/#hits in clusters =  1.000005950892272
# Total number of clusters: 3296930 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 168405
# Number of clusters where tid already exists: 1407466 , Hits: 2680026
# Number of clusters where tid already exists, that are accounted for: 1407466
# Correctly associated out of all hits:  84.65228982538578 %
# Correctly associated out of all hits in clusters:  84.6527935820431 %
# Incorrectly associated out of all hits:  15.34711508892832 %
# Incorrectly associated out of all hits in clusters:  15.347206417956897 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199929
# Identified correctly: 5246794
# Identified incorrectly: 953135
# Total #hits in frames/#hits in clusters =  1.0000061291024462
# Total number of clusters: 3288345 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 168706
# Number of clusters where tid already exists: 1397006 , Hits: 2656445
# Number of clusters where tid already exists, that are accounted for: 1397006
# Correctly associated out of all hits:  84.62616010698122 %
# Correctly associated out of all hits in clusters:  84.62667878938613 %
# Incorrectly associated out of all hits:  15.373226986530735 %
# Incorrectly associated out of all hits in clusters:  15.373321210613863 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210264
# Identified correctly: 5256070
# Identified incorrectly: 954194
# Total #hits in frames/#hits in clusters =  1.0000051527600116
# Total number of clusters: 3293758 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 168300
# Number of clusters where tid already exists: 1398956 , Hits: 2657985
# Number of clusters where tid already exists, that are accounted for: 1398956
# Correctly associated out of all hits:  84.63477425230617 %
# Correctly associated out of all hits in clusters:  84.63521035498653 %
# Incorrectly associated out of all hits:  15.364710474347762 %
# Incorrectly associated out of all hits in clusters:  15.36478964501348 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205447
# Identified correctly: 5254745
# Identified incorrectly: 950702
# Total #hits in frames/#hits in clusters =  1.0000046733136227
# Total number of clusters: 3291159 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 167651
# Number of clusters where tid already exists: 1396400 , Hits: 2652089
# Number of clusters where tid already exists, that are accounted for: 1396400
# Correctly associated out of all hits:  84.67916079282233 %
# Correctly associated out of all hits in clusters:  84.67955652509804 %
# Incorrectly associated out of all hits:  15.320371877999367 %
# Incorrectly associated out of all hits in clusters:  15.32044347490197 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207940
# Identified correctly: 5259105
# Identified incorrectly: 948835
# Total #hits in frames/#hits in clusters =  1.0000059601091504
# Total number of clusters: 3292619 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 168391
# Number of clusters where tid already exists: 1397762 , Hits: 2660635
# Number of clusters where tid already exists, that are accounted for: 1397762
# Correctly associated out of all hits:  84.7152784232287 %
# Correctly associated out of all hits in clusters:  84.71578333553481 %
# Incorrectly associated out of all hits:  15.284125569408522 %
# Incorrectly associated out of all hits in clusters:  15.284216664465184 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6200986
# Identified correctly: 5250312
# Identified incorrectly: 950674
# Total #hits in frames/#hits in clusters =  1.0000066118517281
# Total number of clusters: 3291392 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 167799
# Number of clusters where tid already exists: 1397614 , Hits: 2655174
# Number of clusters where tid already exists, that are accounted for: 1397614
# Correctly associated out of all hits:  84.66842669770669 %
# Correctly associated out of all hits in clusters:  84.66898651279006 %
# Incorrectly associated out of all hits:  15.330912121492135 %
# Incorrectly associated out of all hits in clusters:  15.331013487209937 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221325
# Identified correctly: 5265170
# Identified incorrectly: 956155
# Total #hits in frames/#hits in clusters =  1.000004018436587
# Total number of clusters: 3299568 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 168570
# Number of clusters where tid already exists: 1403252 , Hits: 2665503
# Number of clusters where tid already exists, that are accounted for: 1403252
# Correctly associated out of all hits:  84.63066697742451 %
# Correctly associated out of all hits in clusters:  84.63100706039309 %
# Incorrectly associated out of all hits:  15.368931180531556 %
# Incorrectly associated out of all hits in clusters:  15.368992939606917 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209283
# Identified correctly: 5258373
# Identified incorrectly: 950910
# Total #hits in frames/#hits in clusters =  1.0000035430821883
# Total number of clusters: 3293370 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 168211
# Number of clusters where tid already exists: 1398610 , Hits: 2658319
# Number of clusters where tid already exists, that are accounted for: 1398610
# Correctly associated out of all hits:  84.68537139019584 %
# Correctly associated out of all hits in clusters:  84.68567143742683 %
# Incorrectly associated out of all hits:  15.314274302840655 %
# Incorrectly associated out of all hits in clusters:  15.314328562573166 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195156
# Identified correctly: 5245723
# Identified incorrectly: 949433
# Total #hits in frames/#hits in clusters =  1.0000054881588132
# Total number of clusters: 3287357 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 168151
# Number of clusters where tid already exists: 1395260 , Hits: 2653484
# Number of clusters where tid already exists, that are accounted for: 1395260
# Correctly associated out of all hits:  84.67412621727502 %
# Correctly associated out of all hits in clusters:  84.67459092232706 %
# Incorrectly associated out of all hits:  15.325324969855645 %
# Incorrectly associated out of all hits in clusters:  15.325409077672944 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208784
# Identified correctly: 5256580
# Identified incorrectly: 952204
# Total #hits in frames/#hits in clusters =  1.0000046708018833
# Total number of clusters: 3292499 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 168422
# Number of clusters where tid already exists: 1399700 , Hits: 2659833
# Number of clusters where tid already exists, that are accounted for: 1399700
# Correctly associated out of all hits:  84.66320373958759 %
# Correctly associated out of all hits in clusters:  84.66359918463905 %
# Incorrectly associated out of all hits:  15.33632918240572 %
# Incorrectly associated out of all hits in clusters:  15.336400815360948 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203009
# Identified correctly: 5253136
# Identified incorrectly: 949873
# Total #hits in frames/#hits in clusters =  1.0000041915141507
# Total number of clusters: 3290643 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 167854
# Number of clusters where tid already exists: 1400708 , Hits: 2661698
# Number of clusters where tid already exists, that are accounted for: 1400708
# Correctly associated out of all hits:  84.68654457052072 %
# Correctly associated out of all hits in clusters:  84.68689953537066 %
# Incorrectly associated out of all hits:  15.313036279821088 %
# Incorrectly associated out of all hits in clusters:  15.313100464629345 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203362
# Identified correctly: 5255032
# Identified incorrectly: 948330
# Total #hits in frames/#hits in clusters =  1.0000045136814522
# Total number of clusters: 3291451 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 167872
# Number of clusters where tid already exists: 1398272 , Hits: 2659927
# Number of clusters where tid already exists, that are accounted for: 1398272
# Correctly associated out of all hits:  84.71226216633163 %
# Correctly associated out of all hits in clusters:  84.71264453049814 %
# Incorrectly associated out of all hits:  15.28728646756048 %
# Incorrectly associated out of all hits in clusters:  15.28735546950186 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211690
# Identified correctly: 5259385
# Identified incorrectly: 952305
# Total #hits in frames/#hits in clusters =  1.0000066004581685
# Total number of clusters: 3295657 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 167744
# Number of clusters where tid already exists: 1398008 , Hits: 2660278
# Number of clusters where tid already exists, that are accounted for: 1398008
# Correctly associated out of all hits:  84.66858915815898 %
# Correctly associated out of all hits in clusters:  84.66914800963988 %
# Incorrectly associated out of all hits:  15.330750800380764 %
# Incorrectly associated out of all hits in clusters:  15.330851990360111 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207383
# Identified correctly: 5255837
# Identified incorrectly: 951546
# Total #hits in frames/#hits in clusters =  1.0000070883333605
# Total number of clusters: 3292708 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 168534
# Number of clusters where tid already exists: 1397556 , Hits: 2658135
# Number of clusters where tid already exists, that are accounted for: 1397556
# Correctly associated out of all hits:  84.67013788482733 %
# Correctly associated out of all hits in clusters:  84.67073805499032 %
# Incorrectly associated out of all hits:  15.329153286861047 %
# Incorrectly associated out of all hits in clusters:  15.329261945009677 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206045
# Identified correctly: 5255554
# Identified incorrectly: 950491
# Total #hits in frames/#hits in clusters =  1.000003706064007
# Total number of clusters: 3293755 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 168141
# Number of clusters where tid already exists: 1397456 , Hits: 2653446
# Number of clusters where tid already exists, that are accounted for: 1397456
# Correctly associated out of all hits:  84.68411883337404 %
# Correctly associated out of all hits in clusters:  84.68443267813882 %
# Incorrectly associated out of all hits:  15.315510561598744 %
# Incorrectly associated out of all hits in clusters:  15.315567321861186 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207806
# Identified correctly: 5255835
# Identified incorrectly: 951971
# Total #hits in frames/#hits in clusters =  1.0000056380627873
# Total number of clusters: 3292286 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 168205
# Number of clusters where tid already exists: 1397286 , Hits: 2653095
# Number of clusters where tid already exists, that are accounted for: 1397286
# Correctly associated out of all hits:  84.66445902850926 %
# Correctly associated out of all hits in clusters:  84.66493637204513 %
# Incorrectly associated out of all hits:  15.334977168390749 %
# Incorrectly associated out of all hits in clusters:  15.335063627954868 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6209983
# Identified correctly: 5257692
# Identified incorrectly: 952291
# Total #hits in frames/#hits in clusters =  1.0000033816517695
# Total number of clusters: 3293180 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 168593
# Number of clusters where tid already exists: 1398394 , Hits: 2658187
# Number of clusters where tid already exists, that are accounted for: 1398394
# Correctly associated out of all hits:  84.6648730016921 %
# Correctly associated out of all hits in clusters:  84.6651593088097 %
# Incorrectly associated out of all hits:  15.334788834274503 %
# Incorrectly associated out of all hits in clusters:  15.334840691190298 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203396
# Identified correctly: 5253057
# Identified incorrectly: 950339
# Total #hits in frames/#hits in clusters =  1.0000032240405095
# Total number of clusters: 3293416 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 167983
# Number of clusters where tid already exists: 1400670 , Hits: 2659624
# Number of clusters where tid already exists, that are accounted for: 1400670
# Correctly associated out of all hits:  84.68006981959617 %
# Correctly associated out of all hits in clusters:  84.68034283157161 %
# Incorrectly associated out of all hits:  15.319607777392326 %
# Incorrectly associated out of all hits in clusters:  15.31965716842839 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211875
# Identified correctly: 5259974
# Identified incorrectly: 951901
# Total #hits in frames/#hits in clusters =  1.000005795351645
# Total number of clusters: 3295597 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 168174
# Number of clusters where tid already exists: 1402074 , Hits: 2662308
# Number of clusters where tid already exists, that are accounted for: 1402074
# Correctly associated out of all hits:  84.67561753540899 %
# Correctly associated out of all hits in clusters:  84.67610826038838 %
# Incorrectly associated out of all hits:  15.323802932785096 %
# Incorrectly associated out of all hits in clusters:  15.32389173961163 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211271
# Identified correctly: 5258478
# Identified incorrectly: 952793
# Total #hits in frames/#hits in clusters =  1.000006600903422
# Total number of clusters: 3293223 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 168818
# Number of clusters where tid already exists: 1397400 , Hits: 2659748
# Number of clusters where tid already exists, that are accounted for: 1397400
# Correctly associated out of all hits:  84.65969830528557 %
# Correctly associated out of all hits in clusters:  84.66025713577785 %
# Incorrectly associated out of all hits:  15.339641608729362 %
# Incorrectly associated out of all hits in clusters:  15.339742864222154 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201661
# Identified correctly: 5250786
# Identified incorrectly: 950875
# Total #hits in frames/#hits in clusters =  1.0000051599079667
# Total number of clusters: 3291672 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 168486
# Number of clusters where tid already exists: 1400700 , Hits: 2661462
# Number of clusters where tid already exists, that are accounted for: 1400700
# Correctly associated out of all hits:  84.66697722702494 %
# Correctly associated out of all hits in clusters:  84.66741410083524 %
# Incorrectly associated out of all hits:  15.332506784840849 %
# Incorrectly associated out of all hits in clusters:  15.332585899164755 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205108
# Identified correctly: 5253646
# Identified incorrectly: 951462
# Total #hits in frames/#hits in clusters =  1.0000061239868832
# Total number of clusters: 3292066 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 168629
# Number of clusters where tid already exists: 1399912 , Hits: 2661967
# Number of clusters where tid already exists, that are accounted for: 1399912
# Correctly associated out of all hits:  84.66595306540732 %
# Correctly associated out of all hits in clusters:  84.66647155859334 %
# Incorrectly associated out of all hits:  15.333434539654668 %
# Incorrectly associated out of all hits in clusters:  15.33352844140666 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197072
# Identified correctly: 5246471
# Identified incorrectly: 950601
# Total #hits in frames/#hits in clusters =  1.000005002362406
# Total number of clusters: 3289079 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 167738
# Number of clusters where tid already exists: 1394930 , Hits: 2645941
# Number of clusters where tid already exists, that are accounted for: 1394930
# Correctly associated out of all hits:  84.66005809488725 %
# Correctly associated out of all hits in clusters:  84.66048159517914 %
# Incorrectly associated out of all hits:  15.339441671374512 %
# Incorrectly associated out of all hits in clusters:  15.339518404820858 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200620
# Identified correctly: 5252432
# Identified incorrectly: 948188
# Total #hits in frames/#hits in clusters =  1.0000066122420017
# Total number of clusters: 3290465 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 167426
# Number of clusters where tid already exists: 1398172 , Hits: 2656606
# Number of clusters where tid already exists, that are accounted for: 1398172
# Correctly associated out of all hits:  84.70761423661122 %
# Correctly associated out of all hits in clusters:  84.70817434385594 %
# Incorrectly associated out of all hits:  15.29172454356076 %
# Incorrectly associated out of all hits in clusters:  15.291825656144063 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215423
# Identified correctly: 5261988
# Identified incorrectly: 953435
# Total #hits in frames/#hits in clusters =  1.0000048267028647
# Total number of clusters: 3297152 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 168343
# Number of clusters where tid already exists: 1406848 , Hits: 2673495
# Number of clusters where tid already exists, that are accounted for: 1406848
# Correctly associated out of all hits:  84.65976655281602 %
# Correctly associated out of all hits in clusters:  84.66017518035378 %
# Incorrectly associated out of all hits:  15.339750779227193 %
# Incorrectly associated out of all hits in clusters:  15.339824819646225 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205622
# Identified correctly: 5252758
# Identified incorrectly: 952864
# Total #hits in frames/#hits in clusters =  1.00000547890284
# Total number of clusters: 3292144 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 168399
# Number of clusters where tid already exists: 1400386 , Hits: 2658853
# Number of clusters where tid already exists, that are accounted for: 1400386
# Correctly associated out of all hits:  84.6446854289055 %
# Correctly associated out of all hits in clusters:  84.6451491889129 %
# Incorrectly associated out of all hits:  15.354766683812317 %
# Incorrectly associated out of all hits in clusters:  15.354850811087108 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_iterativespatial_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212430
# Identified correctly: 5259227
# Identified incorrectly: 953203
# Total #hits in frames/#hits in clusters =  1.000006921607165
# Total number of clusters: 3294403 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 168492
# Number of clusters where tid already exists: 1399866 , Hits: 2662309
# Number of clusters where tid already exists, that are accounted for: 1399866
# Correctly associated out of all hits:  84.65593331351299 %
# Correctly associated out of all hits in clusters:  84.65651926862758 %
# Incorrectly associated out of all hits:  15.34337453056134 %
# Incorrectly associated out of all hits in clusters:  15.343480731372425 %

# %% [markdown]
# ### Threshold: 30mm

# %%
current_threshold = threshold_cluster_width_used[2] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_iterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_141_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200620
# Identified correctly: 5172515
# Identified incorrectly: 1028105
# Total #hits in frames/#hits in clusters =  1.0000066122420017
# Total number of clusters: 3290465 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 167426
# Number of clusters where tid already exists: 1398172 , Hits: 2656606
# Number of clusters where tid already exists, that are accounted for: 1398172
# Correctly associated out of all hits:  83.41876777330675 %
# Correctly associated out of all hits in clusters:  83.41931935838674 %
# Incorrectly associated out of all hits:  16.580571006865235 %
# Incorrectly associated out of all hits in clusters:  16.58068064161326 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208784
# Identified correctly: 5176712
# Identified incorrectly: 1032072
# Total #hits in frames/#hits in clusters =  1.0000046708018833
# Total number of clusters: 3292499 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 168422
# Number of clusters where tid already exists: 1399700 , Hits: 2659833
# Number of clusters where tid already exists, that are accounted for: 1399700
# Correctly associated out of all hits:  83.37683869686525 %
# Correctly associated out of all hits in clusters:  83.37722813356045 %
# Incorrectly associated out of all hits:  16.622694225128058 %
# Incorrectly associated out of all hits in clusters:  16.62277186643955 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203009
# Identified correctly: 5174109
# Identified incorrectly: 1028900
# Total #hits in frames/#hits in clusters =  1.0000041915141507
# Total number of clusters: 3290643 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 167854
# Number of clusters where tid already exists: 1400708 , Hits: 2661698
# Number of clusters where tid already exists, that are accounted for: 1400708
# Correctly associated out of all hits:  83.41253918444761 %
# Correctly associated out of all hits in clusters:  83.41288880928595 %
# Incorrectly associated out of all hits:  16.587041665894194 %
# Incorrectly associated out of all hits in clusters:  16.587111190714054 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211271
# Identified correctly: 5179755
# Identified incorrectly: 1031516
# Total #hits in frames/#hits in clusters =  1.000006600903422
# Total number of clusters: 3293223 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 168818
# Number of clusters where tid already exists: 1397400 , Hits: 2659748
# Number of clusters where tid already exists, that are accounted for: 1397400
# Correctly associated out of all hits:  83.39228491500668 %
# Correctly associated out of all hits in clusters:  83.39283537942556 %
# Incorrectly associated out of all hits:  16.60705499900826 %
# Incorrectly associated out of all hits in clusters:  16.607164620574437 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207383
# Identified correctly: 5175739
# Identified incorrectly: 1031644
# Total #hits in frames/#hits in clusters =  1.0000070883333605
# Total number of clusters: 3292708 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 168534
# Number of clusters where tid already exists: 1397556 , Hits: 2658135
# Number of clusters where tid already exists, that are accounted for: 1397556
# Correctly associated out of all hits:  83.37978038243543 %
# Correctly associated out of all hits in clusters:  83.38037140611429 %
# Incorrectly associated out of all hits:  16.61951078925294 %
# Incorrectly associated out of all hits in clusters:  16.6196285938857 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203396
# Identified correctly: 5172978
# Identified incorrectly: 1030418
# Total #hits in frames/#hits in clusters =  1.0000032240405095
# Total number of clusters: 3293416 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 167983
# Number of clusters where tid already exists: 1400670 , Hits: 2659624
# Number of clusters where tid already exists, that are accounted for: 1400670
# Correctly associated out of all hits:  83.38918428169254 %
# Correctly associated out of all hits in clusters:  83.3894531318007 %
# Incorrectly associated out of all hits:  16.610493315295958 %
# Incorrectly associated out of all hits in clusters:  16.61054686819929 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197072
# Identified correctly: 5167420
# Identified incorrectly: 1029652
# Total #hits in frames/#hits in clusters =  1.000005002362406
# Total number of clusters: 3289079 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 167738
# Number of clusters where tid already exists: 1394930 , Hits: 2645941
# Number of clusters where tid already exists, that are accounted for: 1394930
# Correctly associated out of all hits:  83.38444592578178 %
# Correctly associated out of all hits in clusters:  83.38486304499932 %
# Incorrectly associated out of all hits:  16.61505384047998 %
# Incorrectly associated out of all hits in clusters:  16.615136955000683 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217555
# Identified correctly: 5182554
# Identified incorrectly: 1035001
# Total #hits in frames/#hits in clusters =  1.000005950892272
# Total number of clusters: 3296930 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 168405
# Number of clusters where tid already exists: 1407466 , Hits: 2680026
# Number of clusters where tid already exists, that are accounted for: 1407466
# Correctly associated out of all hits:  83.35307302248202 %
# Correctly associated out of all hits in clusters:  83.35356904764011 %
# Incorrectly associated out of all hits:  16.64633189183208 %
# Incorrectly associated out of all hits in clusters:  16.64643095235989 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205447
# Identified correctly: 5174759
# Identified incorrectly: 1030688
# Total #hits in frames/#hits in clusters =  1.0000046733136227
# Total number of clusters: 3291159 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 167651
# Number of clusters where tid already exists: 1396400 , Hits: 2652089
# Number of clusters where tid already exists, that are accounted for: 1396400
# Correctly associated out of all hits:  83.39020245989187 %
# Correctly associated out of all hits in clusters:  83.39059216846103 %
# Incorrectly associated out of all hits:  16.60933021092983 %
# Incorrectly associated out of all hits in clusters:  16.60940783153897 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6200986
# Identified correctly: 5171223
# Identified incorrectly: 1029763
# Total #hits in frames/#hits in clusters =  1.0000066118517281
# Total number of clusters: 3291392 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 167799
# Number of clusters where tid already exists: 1397614 , Hits: 2655174
# Number of clusters where tid already exists, that are accounted for: 1397614
# Correctly associated out of all hits:  83.3930089322301 %
# Correctly associated out of all hits in clusters:  83.39356031444032 %
# Incorrectly associated out of all hits:  16.606329886968723 %
# Incorrectly associated out of all hits in clusters:  16.606439685559682 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215423
# Identified correctly: 5183649
# Identified incorrectly: 1031774
# Total #hits in frames/#hits in clusters =  1.0000048267028647
# Total number of clusters: 3297152 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 168343
# Number of clusters where tid already exists: 1406848 , Hits: 2673495
# Number of clusters where tid already exists, that are accounted for: 1406848
# Correctly associated out of all hits:  83.39937571726469 %
# Correctly associated out of all hits in clusters:  83.39977826127038 %
# Incorrectly associated out of all hits:  16.600141614778522 %
# Incorrectly associated out of all hits in clusters:  16.60022173872961 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203362
# Identified correctly: 5175198
# Identified incorrectly: 1028164
# Total #hits in frames/#hits in clusters =  1.0000045136814522
# Total number of clusters: 3291451 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 167872
# Number of clusters where tid already exists: 1398272 , Hits: 2659927
# Number of clusters where tid already exists, that are accounted for: 1398272
# Correctly associated out of all hits:  83.42532067143932 %
# Correctly associated out of all hits in clusters:  83.42569722676187 %
# Incorrectly associated out of all hits:  16.574227962452788 %
# Incorrectly associated out of all hits in clusters:  16.574302773238124 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206045
# Identified correctly: 5175339
# Identified incorrectly: 1030706
# Total #hits in frames/#hits in clusters =  1.000003706064007
# Total number of clusters: 3293755 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 168141
# Number of clusters where tid already exists: 1397456 , Hits: 2653446
# Number of clusters where tid already exists, that are accounted for: 1397456
# Correctly associated out of all hits:  83.39159351782804 %
# Correctly associated out of all hits in clusters:  83.39190257241125 %
# Incorrectly associated out of all hits:  16.608035877144754 %
# Incorrectly associated out of all hits in clusters:  16.608097427588746 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221325
# Identified correctly: 5185647
# Identified incorrectly: 1035678
# Total #hits in frames/#hits in clusters =  1.000004018436587
# Total number of clusters: 3299568 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 168570
# Number of clusters where tid already exists: 1403252 , Hits: 2665503
# Number of clusters where tid already exists, that are accounted for: 1403252
# Correctly associated out of all hits:  83.35243958304869 %
# Correctly associated out of all hits in clusters:  83.35277452954153 %
# Incorrectly associated out of all hits:  16.647158574907376 %
# Incorrectly associated out of all hits in clusters:  16.647225470458462 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209283
# Identified correctly: 5178393
# Identified incorrectly: 1030890
# Total #hits in frames/#hits in clusters =  1.0000035430821883
# Total number of clusters: 3293370 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 168211
# Number of clusters where tid already exists: 1398610 , Hits: 2658319
# Number of clusters where tid already exists, that are accounted for: 1398610
# Correctly associated out of all hits:  83.39730452925086 %
# Correctly associated out of all hits in clusters:  83.39760001275509 %
# Incorrectly associated out of all hits:  16.602341163785642 %
# Incorrectly associated out of all hits in clusters:  16.602399987244905 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199929
# Identified correctly: 5166929
# Identified incorrectly: 1033000
# Total #hits in frames/#hits in clusters =  1.0000061291024462
# Total number of clusters: 3288345 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 168706
# Number of clusters where tid already exists: 1397006 , Hits: 2656445
# Number of clusters where tid already exists, that are accounted for: 1397006
# Correctly associated out of all hits:  83.3380080893979 %
# Correctly associated out of all hits in clusters:  83.33851887658713 %
# Incorrectly associated out of all hits:  16.661379004114053 %
# Incorrectly associated out of all hits in clusters:  16.661481123412866 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6209983
# Identified correctly: 5177160
# Identified incorrectly: 1032823
# Total #hits in frames/#hits in clusters =  1.0000033816517695
# Total number of clusters: 3293180 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 168593
# Number of clusters where tid already exists: 1398394 , Hits: 2658187
# Number of clusters where tid already exists, that are accounted for: 1398394
# Correctly associated out of all hits:  83.36806224279404 %
# Correctly associated out of all hits in clusters:  83.36834416454924 %
# Incorrectly associated out of all hits:  16.631599593172563 %
# Incorrectly associated out of all hits in clusters:  16.631655835450758 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207806
# Identified correctly: 5176271
# Identified incorrectly: 1031535
# Total #hits in frames/#hits in clusters =  1.0000056380627873
# Total number of clusters: 3292286 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 168205
# Number of clusters where tid already exists: 1397286 , Hits: 2653095
# Number of clusters where tid already exists, that are accounted for: 1397286
# Correctly associated out of all hits:  83.38278960430848 %
# Correctly associated out of all hits in clusters:  83.38325972171167 %
# Incorrectly associated out of all hits:  16.61664659259153 %
# Incorrectly associated out of all hits in clusters:  16.616740278288336 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207940
# Identified correctly: 5178974
# Identified incorrectly: 1028966
# Total #hits in frames/#hits in clusters =  1.0000059601091504
# Total number of clusters: 3292619 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 168391
# Number of clusters where tid already exists: 1397762 , Hits: 2660635
# Number of clusters where tid already exists, that are accounted for: 1397762
# Correctly associated out of all hits:  83.42450366681449 %
# Correctly associated out of all hits in clusters:  83.42500088596216 %
# Incorrectly associated out of all hits:  16.57490032582273 %
# Incorrectly associated out of all hits in clusters:  16.57499911403783 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195156
# Identified correctly: 5166303
# Identified incorrectly: 1028853
# Total #hits in frames/#hits in clusters =  1.0000054881588132
# Total number of clusters: 3287357 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 168151
# Number of clusters where tid already exists: 1395260 , Hits: 2653484
# Number of clusters where tid already exists, that are accounted for: 1395260
# Correctly associated out of all hits:  83.39216392071914 %
# Correctly associated out of all hits in clusters:  83.39262159015851 %
# Incorrectly associated out of all hits:  16.60728726641152 %
# Incorrectly associated out of all hits in clusters:  16.607378409841495 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211690
# Identified correctly: 5179693
# Identified incorrectly: 1031997
# Total #hits in frames/#hits in clusters =  1.0000066004581685
# Total number of clusters: 3295657 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 167744
# Number of clusters where tid already exists: 1398008 , Hits: 2660278
# Number of clusters where tid already exists, that are accounted for: 1398008
# Correctly associated out of all hits:  83.38566174227442 %
# Correctly associated out of all hits in clusters:  83.38621212584658 %
# Incorrectly associated out of all hits:  16.61367821626532 %
# Incorrectly associated out of all hits in clusters:  16.61378787415341 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212430
# Identified correctly: 5179603
# Identified incorrectly: 1032827
# Total #hits in frames/#hits in clusters =  1.000006921607165
# Total number of clusters: 3294403 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 168492
# Number of clusters where tid already exists: 1399866 , Hits: 2662309
# Number of clusters where tid already exists, that are accounted for: 1399866
# Correctly associated out of all hits:  83.3742536989698 %
# Correctly associated out of all hits in clusters:  83.37483078280157 %
# Incorrectly associated out of all hits:  16.62505414510453 %
# Incorrectly associated out of all hits in clusters:  16.625169217198422 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205108
# Identified correctly: 5174062
# Identified incorrectly: 1031046
# Total #hits in frames/#hits in clusters =  1.0000061239868832
# Total number of clusters: 3292066 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 168629
# Number of clusters where tid already exists: 1399912 , Hits: 2661967
# Number of clusters where tid already exists, that are accounted for: 1399912
# Correctly associated out of all hits:  83.3834046773436 %
# Correctly associated out of all hits in clusters:  83.38391531622011 %
# Incorrectly associated out of all hits:  16.61598292771838 %
# Incorrectly associated out of all hits in clusters:  16.616084683779878 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6204978
# Identified correctly: 5173891
# Identified incorrectly: 1031087
# Total #hits in frames/#hits in clusters =  1.000003545540371
# Total number of clusters: 3292825 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 168266
# Number of clusters where tid already exists: 1398004 , Hits: 2653009
# Number of clusters where tid already exists, that are accounted for: 1398004
# Correctly associated out of all hits:  83.38261079774375 %
# Correctly associated out of all hits in clusters:  83.38290643415658 %
# Incorrectly associated out of all hits:  16.617034649476228 %
# Incorrectly associated out of all hits in clusters:  16.617093565843426 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204459
# Identified correctly: 5172565
# Identified incorrectly: 1031894
# Total #hits in frames/#hits in clusters =  1.0000051575810236
# Total number of clusters: 3292016 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 168398
# Number of clusters where tid already exists: 1397188 , Hits: 2653421
# Number of clusters where tid already exists, that are accounted for: 1397188
# Correctly associated out of all hits:  83.36807967003256 %
# Correctly associated out of all hits in clusters:  83.36850964765824 %
# Incorrectly associated out of all hits:  16.631404574525128 %
# Incorrectly associated out of all hits in clusters:  16.63149035234176 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211875
# Identified correctly: 5180639
# Identified incorrectly: 1031236
# Total #hits in frames/#hits in clusters =  1.000005795351645
# Total number of clusters: 3295597 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 168174
# Number of clusters where tid already exists: 1402074 , Hits: 2662308
# Number of clusters where tid already exists, that are accounted for: 1402074
# Correctly associated out of all hits:  83.3984743181285 %
# Correctly associated out of all hits in clusters:  83.39895764161385 %
# Incorrectly associated out of all hits:  16.600946150065575 %
# Incorrectly associated out of all hits in clusters:  16.601042358386156 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201661
# Identified correctly: 5170356
# Identified incorrectly: 1031305
# Total #hits in frames/#hits in clusters =  1.0000051599079667
# Total number of clusters: 3291672 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 168486
# Number of clusters where tid already exists: 1400700 , Hits: 2661462
# Number of clusters where tid already exists, that are accounted for: 1400700
# Correctly associated out of all hits:  83.37007330095186 %
# Correctly associated out of all hits in clusters:  83.37050348285726 %
# Incorrectly associated out of all hits:  16.629410710913938 %
# Incorrectly associated out of all hits in clusters:  16.629496517142744 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205622
# Identified correctly: 5172073
# Identified incorrectly: 1033549
# Total #hits in frames/#hits in clusters =  1.00000547890284
# Total number of clusters: 3292144 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 168399
# Number of clusters where tid already exists: 1400386 , Hits: 2658853
# Number of clusters where tid already exists, that are accounted for: 1400386
# Correctly associated out of all hits:  83.34450056529076 %
# Correctly associated out of all hits in clusters:  83.34495720171161 %
# Incorrectly associated out of all hits:  16.654951547427057 %
# Incorrectly associated out of all hits in clusters:  16.65504279828839 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_iterativespatial_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210264
# Identified correctly: 5176871
# Identified incorrectly: 1033393
# Total #hits in frames/#hits in clusters =  1.0000051527600116
# Total number of clusters: 3293758 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 168300
# Number of clusters where tid already exists: 1398956 , Hits: 2657985
# Number of clusters where tid already exists, that are accounted for: 1398956
# Correctly associated out of all hits:  83.35948882307703 %
# Correctly associated out of all hits in clusters:  83.35991835451762 %
# Incorrectly associated out of all hits:  16.6399959035769 %
# Incorrectly associated out of all hits in clusters:  16.640081645482383 %

# %% [markdown]
# ### Threshold: 35mm

# %%
current_threshold = threshold_cluster_width_used[3] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_iterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_130_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215423
# Identified correctly: 5114627
# Identified incorrectly: 1100796
# Total #hits in frames/#hits in clusters =  1.0000048267028647
# Total number of clusters: 3297152 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 168343
# Number of clusters where tid already exists: 1406848 , Hits: 2673495
# Number of clusters where tid already exists, that are accounted for: 1406848
# Correctly associated out of all hits:  82.28888546015874 %
# Correctly associated out of all hits in clusters:  82.28928264415792 %
# Incorrectly associated out of all hits:  17.71063187188448 %
# Incorrectly associated out of all hits in clusters:  17.71071735584207 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201661
# Identified correctly: 5102089
# Identified incorrectly: 1099572
# Total #hits in frames/#hits in clusters =  1.0000051599079667
# Total number of clusters: 3291672 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 168486
# Number of clusters where tid already exists: 1400700 , Hits: 2661462
# Number of clusters where tid already exists, that are accounted for: 1400700
# Correctly associated out of all hits:  82.26929323976533 %
# Correctly associated out of all hits in clusters:  82.26971774174693 %
# Incorrectly associated out of all hits:  17.730190772100457 %
# Incorrectly associated out of all hits in clusters:  17.73028225825307 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203009
# Identified correctly: 5104785
# Identified incorrectly: 1098224
# Total #hits in frames/#hits in clusters =  1.0000041915141507
# Total number of clusters: 3290643 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 167854
# Number of clusters where tid already exists: 1400708 , Hits: 2661698
# Number of clusters where tid already exists, that are accounted for: 1400708
# Correctly associated out of all hits:  82.29495722658343 %
# Correctly associated out of all hits in clusters:  82.29530216706118 %
# Incorrectly associated out of all hits:  17.70462362375837 %
# Incorrectly associated out of all hits in clusters:  17.704697832938823 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195156
# Identified correctly: 5096943
# Identified incorrectly: 1098213
# Total #hits in frames/#hits in clusters =  1.0000054881588132
# Total number of clusters: 3287357 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 168151
# Number of clusters where tid already exists: 1395260 , Hits: 2653484
# Number of clusters where tid already exists, that are accounted for: 1395260
# Correctly associated out of all hits:  82.27258566726766 %
# Correctly associated out of all hits in clusters:  82.27303719228378 %
# Incorrectly associated out of all hits:  17.72686551986299 %
# Incorrectly associated out of all hits in clusters:  17.726962807716223 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206045
# Identified correctly: 5107073
# Identified incorrectly: 1098972
# Total #hits in frames/#hits in clusters =  1.000003706064007
# Total number of clusters: 3293755 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 168141
# Number of clusters where tid already exists: 1397456 , Hits: 2653446
# Number of clusters where tid already exists, that are accounted for: 1397456
# Correctly associated out of all hits:  82.29160557054806 %
# Correctly associated out of all hits in clusters:  82.29191054850553 %
# Incorrectly associated out of all hits:  17.70802382442474 %
# Incorrectly associated out of all hits in clusters:  17.70808945149447 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205622
# Identified correctly: 5103271
# Identified incorrectly: 1102351
# Total #hits in frames/#hits in clusters =  1.00000547890284
# Total number of clusters: 3292144 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 168399
# Number of clusters where tid already exists: 1400386 , Hits: 2658853
# Number of clusters where tid already exists, that are accounted for: 1400386
# Correctly associated out of all hits:  82.23580230679883 %
# Correctly associated out of all hits in clusters:  82.23625286876964 %
# Incorrectly associated out of all hits:  17.763649805918988 %
# Incorrectly associated out of all hits in clusters:  17.763747131230357 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211271
# Identified correctly: 5110513
# Identified incorrectly: 1100758
# Total #hits in frames/#hits in clusters =  1.000006600903422
# Total number of clusters: 3293223 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 168818
# Number of clusters where tid already exists: 1397400 , Hits: 2659748
# Number of clusters where tid already exists, that are accounted for: 1397400
# Correctly associated out of all hits:  82.27751238385706 %
# Correctly associated out of all hits in clusters:  82.27805548977013 %
# Incorrectly associated out of all hits:  17.721827530157878 %
# Incorrectly associated out of all hits in clusters:  17.72194451022987 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209283
# Identified correctly: 5110529
# Identified incorrectly: 1098754
# Total #hits in frames/#hits in clusters =  1.0000035430821883
# Total number of clusters: 3293370 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 168211
# Number of clusters where tid already exists: 1398610 , Hits: 2658319
# Number of clusters where tid already exists, that are accounted for: 1398610
# Correctly associated out of all hits:  82.30436417602291 %
# Correctly associated out of all hits in clusters:  82.30465578714966 %
# Incorrectly associated out of all hits:  17.695281517013576 %
# Incorrectly associated out of all hits in clusters:  17.69534421285034 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207940
# Identified correctly: 5109368
# Identified incorrectly: 1098572
# Total #hits in frames/#hits in clusters =  1.0000059601091504
# Total number of clusters: 3292619 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 168391
# Number of clusters where tid already exists: 1397762 , Hits: 2660635
# Number of clusters where tid already exists, that are accounted for: 1397762
# Correctly associated out of all hits:  82.30326884265196 %
# Correctly associated out of all hits in clusters:  82.30375937911771 %
# Incorrectly associated out of all hits:  17.696135149985253 %
# Incorrectly associated out of all hits in clusters:  17.69624062088229 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204459
# Identified correctly: 5103972
# Identified incorrectly: 1100487
# Total #hits in frames/#hits in clusters =  1.0000051575810236
# Total number of clusters: 3292016 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 168398
# Number of clusters where tid already exists: 1397188 , Hits: 2653421
# Number of clusters where tid already exists, that are accounted for: 1397188
# Correctly associated out of all hits:  82.26254176208813 %
# Correctly associated out of all hits in clusters:  82.26296603781249 %
# Incorrectly associated out of all hits:  17.73694248246955 %
# Incorrectly associated out of all hits in clusters:  17.737033962187517 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210264
# Identified correctly: 5108080
# Identified incorrectly: 1102184
# Total #hits in frames/#hits in clusters =  1.0000051527600116
# Total number of clusters: 3293758 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 168300
# Number of clusters where tid already exists: 1398956 , Hits: 2657985
# Number of clusters where tid already exists, that are accounted for: 1398956
# Correctly associated out of all hits:  82.25179604965689 %
# Correctly associated out of all hits in clusters:  82.25221987342245 %
# Incorrectly associated out of all hits:  17.74768867699704 %
# Incorrectly associated out of all hits in clusters:  17.74778012657755 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199929
# Identified correctly: 5097657
# Identified incorrectly: 1102272
# Total #hits in frames/#hits in clusters =  1.0000061291024462
# Total number of clusters: 3288345 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 168706
# Number of clusters where tid already exists: 1397006 , Hits: 2656445
# Number of clusters where tid already exists, that are accounted for: 1397006
# Correctly associated out of all hits:  82.22071181991775 %
# Correctly associated out of all hits in clusters:  82.22121575908369 %
# Incorrectly associated out of all hits:  17.7786752735942 %
# Incorrectly associated out of all hits in clusters:  17.778784240916305 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6200986
# Identified correctly: 5102140
# Identified incorrectly: 1098846
# Total #hits in frames/#hits in clusters =  1.0000066118517281
# Total number of clusters: 3291392 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 167799
# Number of clusters where tid already exists: 1397614 , Hits: 2655174
# Number of clusters where tid already exists, that are accounted for: 1397614
# Correctly associated out of all hits:  82.27895153496348 %
# Correctly associated out of all hits in clusters:  82.27949555119137 %
# Incorrectly associated out of all hits:  17.72038728423534 %
# Incorrectly associated out of all hits in clusters:  17.720504448808626 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205447
# Identified correctly: 5106023
# Identified incorrectly: 1099424
# Total #hits in frames/#hits in clusters =  1.0000046733136227
# Total number of clusters: 3291159 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 167651
# Number of clusters where tid already exists: 1396400 , Hits: 2652089
# Number of clusters where tid already exists, that are accounted for: 1396400
# Correctly associated out of all hits:  82.28253561854078 %
# Correctly associated out of all hits in clusters:  82.2829201506354 %
# Incorrectly associated out of all hits:  17.71699705228092 %
# Incorrectly associated out of all hits in clusters:  17.7170798493646 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208784
# Identified correctly: 5108902
# Identified incorrectly: 1099882
# Total #hits in frames/#hits in clusters =  1.0000046708018833
# Total number of clusters: 3292499 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 168422
# Number of clusters where tid already exists: 1399700 , Hits: 2659833
# Number of clusters where tid already exists, that are accounted for: 1399700
# Correctly associated out of all hits:  82.28468146810026 %
# Correctly associated out of all hits in clusters:  82.28506580354544 %
# Incorrectly associated out of all hits:  17.71485145389304 %
# Incorrectly associated out of all hits in clusters:  17.71493419645457 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211690
# Identified correctly: 5111525
# Identified incorrectly: 1100165
# Total #hits in frames/#hits in clusters =  1.0000066004581685
# Total number of clusters: 3295657 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 167744
# Number of clusters where tid already exists: 1398008 , Hits: 2660278
# Number of clusters where tid already exists, that are accounted for: 1398008
# Correctly associated out of all hits:  82.28825427244033 %
# Correctly associated out of all hits in clusters:  82.2887974126204 %
# Incorrectly associated out of all hits:  17.711085686099416 %
# Incorrectly associated out of all hits in clusters:  17.711202587379603 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207806
# Identified correctly: 5108042
# Identified incorrectly: 1099764
# Total #hits in frames/#hits in clusters =  1.0000056380627873
# Total number of clusters: 3292286 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 168205
# Number of clusters where tid already exists: 1397286 , Hits: 2653095
# Number of clusters where tid already exists, that are accounted for: 1397286
# Correctly associated out of all hits:  82.28371184120212 %
# Correctly associated out of all hits in clusters:  82.28417576193586 %
# Incorrectly associated out of all hits:  17.715724355697898 %
# Incorrectly associated out of all hits in clusters:  17.71582423806414 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211875
# Identified correctly: 5111194
# Identified incorrectly: 1100681
# Total #hits in frames/#hits in clusters =  1.000005795351645
# Total number of clusters: 3295597 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 168174
# Number of clusters where tid already exists: 1402074 , Hits: 2662308
# Number of clusters where tid already exists, that are accounted for: 1402074
# Correctly associated out of all hits:  82.28054136641687 %
# Correctly associated out of all hits in clusters:  82.28101821108764 %
# Incorrectly associated out of all hits:  17.718879101777215 %
# Incorrectly associated out of all hits in clusters:  17.718981788912366 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207383
# Identified correctly: 5108019
# Identified incorrectly: 1099364
# Total #hits in frames/#hits in clusters =  1.0000070883333605
# Total number of clusters: 3292708 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 168534
# Number of clusters where tid already exists: 1397556 , Hits: 2658135
# Number of clusters where tid already exists, that are accounted for: 1397556
# Correctly associated out of all hits:  82.28882917189361 %
# Correctly associated out of all hits in clusters:  82.28941246254661 %
# Incorrectly associated out of all hits:  17.710461999794763 %
# Incorrectly associated out of all hits in clusters:  17.710587537453385 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212430
# Identified correctly: 5111332
# Identified incorrectly: 1101098
# Total #hits in frames/#hits in clusters =  1.000006921607165
# Total number of clusters: 3294403 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 168492
# Number of clusters where tid already exists: 1399866 , Hits: 2662309
# Number of clusters where tid already exists, that are accounted for: 1399866
# Correctly associated out of all hits:  82.27531934545229 %
# Correctly associated out of all hits in clusters:  82.27588882289217 %
# Incorrectly associated out of all hits:  17.723988498622045 %
# Incorrectly associated out of all hits in clusters:  17.72411117710783 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203396
# Identified correctly: 5104365
# Identified incorrectly: 1099031
# Total #hits in frames/#hits in clusters =  1.0000032240405095
# Total number of clusters: 3293416 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 167983
# Number of clusters where tid already exists: 1400670 , Hits: 2659624
# Number of clusters where tid already exists, that are accounted for: 1400670
# Correctly associated out of all hits:  82.28313239028303 %
# Correctly associated out of all hits in clusters:  82.28339767443511 %
# Incorrectly associated out of all hits:  17.716545206705465 %
# Incorrectly associated out of all hits in clusters:  17.7166023255649 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217555
# Identified correctly: 5113089
# Identified incorrectly: 1104466
# Total #hits in frames/#hits in clusters =  1.000005950892272
# Total number of clusters: 3296930 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 168405
# Number of clusters where tid already exists: 1407466 , Hits: 2680026
# Number of clusters where tid already exists, that are accounted for: 1407466
# Correctly associated out of all hits:  82.2358398556869 %
# Correctly associated out of all hits in clusters:  82.23632923231077 %
# Incorrectly associated out of all hits:  17.7635650586272 %
# Incorrectly associated out of all hits in clusters:  17.763670767689227 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200620
# Identified correctly: 5104256
# Identified incorrectly: 1096364
# Total #hits in frames/#hits in clusters =  1.0000066122420017
# Total number of clusters: 3290465 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 167426
# Number of clusters where tid already exists: 1398172 , Hits: 2656606
# Number of clusters where tid already exists, that are accounted for: 1398172
# Correctly associated out of all hits:  82.31793352353885 %
# Correctly associated out of all hits in clusters:  82.3184778296364 %
# Incorrectly associated out of all hits:  17.681405256633123 %
# Incorrectly associated out of all hits in clusters:  17.68152217036361 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6204978
# Identified correctly: 5105614
# Identified incorrectly: 1099364
# Total #hits in frames/#hits in clusters =  1.000003545540371
# Total number of clusters: 3292825 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 168266
# Number of clusters where tid already exists: 1398004 , Hits: 2653009
# Number of clusters where tid already exists, that are accounted for: 1398004
# Correctly associated out of all hits:  82.28225624496373 %
# Correctly associated out of all hits in clusters:  82.28254798002507 %
# Incorrectly associated out of all hits:  17.717389202256246 %
# Incorrectly associated out of all hits in clusters:  17.71745201997493 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205108
# Identified correctly: 5104802
# Identified incorrectly: 1100306
# Total #hits in frames/#hits in clusters =  1.0000061239868832
# Total number of clusters: 3292066 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 168629
# Number of clusters where tid already exists: 1399912 , Hits: 2661967
# Number of clusters where tid already exists, that are accounted for: 1399912
# Correctly associated out of all hits:  82.26723432454288 %
# Correctly associated out of all hits in clusters:  82.2677381280068 %
# Incorrectly associated out of all hits:  17.732153280519103 %
# Incorrectly associated out of all hits in clusters:  17.732261871993202 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6209983
# Identified correctly: 5108204
# Identified incorrectly: 1101779
# Total #hits in frames/#hits in clusters =  1.0000033816517695
# Total number of clusters: 3293180 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 168593
# Number of clusters where tid already exists: 1398394 , Hits: 2658187
# Number of clusters where tid already exists, that are accounted for: 1398394
# Correctly associated out of all hits:  82.25766038153921 %
# Correctly associated out of all hits in clusters:  82.25793854830198 %
# Incorrectly associated out of all hits:  17.742001454427406 %
# Incorrectly associated out of all hits in clusters:  17.742061451698014 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203362
# Identified correctly: 5106722
# Identified incorrectly: 1096640
# Total #hits in frames/#hits in clusters =  1.0000045136814522
# Total number of clusters: 3291451 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 167872
# Number of clusters where tid already exists: 1398272 , Hits: 2659927
# Number of clusters where tid already exists, that are accounted for: 1398272
# Correctly associated out of all hits:  82.32147261416742 %
# Correctly associated out of all hits in clusters:  82.32184418707146 %
# Incorrectly associated out of all hits:  17.6780760197247 %
# Incorrectly associated out of all hits in clusters:  17.678155812928537 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197072
# Identified correctly: 5098351
# Identified incorrectly: 1098721
# Total #hits in frames/#hits in clusters =  1.000005002362406
# Total number of clusters: 3289079 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 167738
# Number of clusters where tid already exists: 1394930 , Hits: 2645941
# Number of clusters where tid already exists, that are accounted for: 1394930
# Correctly associated out of all hits:  82.26990902039228 %
# Correctly associated out of all hits in clusters:  82.27032056429229 %
# Incorrectly associated out of all hits:  17.72959074586948 %
# Incorrectly associated out of all hits in clusters:  17.729679435707702 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_iterativespatial_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221325
# Identified correctly: 5116784
# Identified incorrectly: 1104541
# Total #hits in frames/#hits in clusters =  1.000004018436587
# Total number of clusters: 3299568 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 168570
# Number of clusters where tid already exists: 1403252 , Hits: 2665503
# Number of clusters where tid already exists, that are accounted for: 1403252
# Correctly associated out of all hits:  82.24555763620437 %
# Correctly associated out of all hits in clusters:  82.2458881347623 %
# Incorrectly associated out of all hits:  17.75404052175171 %
# Incorrectly associated out of all hits in clusters:  17.75411186523771 %

# %% [markdown]
# ### Threshold: 40mm

# %%
current_threshold = threshold_cluster_width_used[4] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_iterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_158_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6204978
# Identified correctly: 5033137
# Identified incorrectly: 1171841
# Total #hits in frames/#hits in clusters =  1.000003545540371
# Total number of clusters: 3292825 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 168266
# Number of clusters where tid already exists: 1398004 , Hits: 2653009
# Number of clusters where tid already exists, that are accounted for: 1398004
# Correctly associated out of all hits:  81.11421434327156 %
# Correctly associated out of all hits in clusters:  81.11450193699316 %
# Incorrectly associated out of all hits:  18.885431103948427 %
# Incorrectly associated out of all hits in clusters:  18.885498063006832 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209283
# Identified correctly: 5038396
# Identified incorrectly: 1170887
# Total #hits in frames/#hits in clusters =  1.0000035430821883
# Total number of clusters: 3293370 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 168211
# Number of clusters where tid already exists: 1398610 , Hits: 2658319
# Number of clusters where tid already exists, that are accounted for: 1398610
# Correctly associated out of all hits:  81.14267216701386 %
# Correctly associated out of all hits in clusters:  81.14295966217033 %
# Incorrectly associated out of all hits:  18.85697352602264 %
# Incorrectly associated out of all hits in clusters:  18.857040337829666 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215423
# Identified correctly: 5041836
# Identified incorrectly: 1173587
# Total #hits in frames/#hits in clusters =  1.0000048267028647
# Total number of clusters: 3297152 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 168343
# Number of clusters where tid already exists: 1406848 , Hits: 2673495
# Number of clusters where tid already exists, that are accounted for: 1406848
# Correctly associated out of all hits:  81.11775601874875 %
# Correctly associated out of all hits in clusters:  81.11814755005412 %
# Incorrectly associated out of all hits:  18.88176131329446 %
# Incorrectly associated out of all hits in clusters:  18.881852449945885 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206045
# Identified correctly: 5035362
# Identified incorrectly: 1170683
# Total #hits in frames/#hits in clusters =  1.000003706064007
# Total number of clusters: 3293755 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 168141
# Number of clusters where tid already exists: 1397456 , Hits: 2653446
# Number of clusters where tid already exists, that are accounted for: 1397456
# Correctly associated out of all hits:  81.136107435497 %
# Correctly associated out of all hits in clusters:  81.13640813110443 %
# Incorrectly associated out of all hits:  18.86352195947579 %
# Incorrectly associated out of all hits in clusters:  18.86359186889557 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211875
# Identified correctly: 5038395
# Identified incorrectly: 1173480
# Total #hits in frames/#hits in clusters =  1.000005795351645
# Total number of clusters: 3295597 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 168174
# Number of clusters where tid already exists: 1402074 , Hits: 2662308
# Number of clusters where tid already exists, that are accounted for: 1402074
# Correctly associated out of all hits:  81.10861536812102 %
# Correctly associated out of all hits in clusters:  81.10908542106851 %
# Incorrectly associated out of all hits:  18.89080510007307 %
# Incorrectly associated out of all hits in clusters:  18.890914578931483 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197072
# Identified correctly: 5024993
# Identified incorrectly: 1172079
# Total #hits in frames/#hits in clusters =  1.000005002362406
# Total number of clusters: 3289079 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 167738
# Number of clusters where tid already exists: 1394930 , Hits: 2645941
# Number of clusters where tid already exists, that are accounted for: 1394930
# Correctly associated out of all hits:  81.08616235683029 %
# Correctly associated out of all hits in clusters:  81.0865679792005 %
# Incorrectly associated out of all hits:  18.91333740943147 %
# Incorrectly associated out of all hits in clusters:  18.9134320207995 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207940
# Identified correctly: 5037123
# Identified incorrectly: 1170817
# Total #hits in frames/#hits in clusters =  1.0000059601091504
# Total number of clusters: 3292619 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 168391
# Number of clusters where tid already exists: 1397762 , Hits: 2660635
# Number of clusters where tid already exists, that are accounted for: 1397762
# Correctly associated out of all hits:  81.13952419604648 %
# Correctly associated out of all hits in clusters:  81.1400077964671 %
# Incorrectly associated out of all hits:  18.859879796590743 %
# Incorrectly associated out of all hits in clusters:  18.859992203532894 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6200986
# Identified correctly: 5030428
# Identified incorrectly: 1170558
# Total #hits in frames/#hits in clusters =  1.0000066118517281
# Total number of clusters: 3291392 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 167799
# Number of clusters where tid already exists: 1397614 , Hits: 2655174
# Number of clusters where tid already exists, that are accounted for: 1397614
# Correctly associated out of all hits:  81.12249793461632 %
# Correctly associated out of all hits in clusters:  81.12303430454448 %
# Incorrectly associated out of all hits:  18.876840884582506 %
# Incorrectly associated out of all hits in clusters:  18.876965695455528 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208784
# Identified correctly: 5035976
# Identified incorrectly: 1172808
# Total #hits in frames/#hits in clusters =  1.0000046708018833
# Total number of clusters: 3292499 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 168422
# Number of clusters where tid already exists: 1399700 , Hits: 2659833
# Number of clusters where tid already exists, that are accounted for: 1399700
# Correctly associated out of all hits:  81.1101252364985 %
# Correctly associated out of all hits in clusters:  81.11050408582422 %
# Incorrectly associated out of all hits:  18.889407685494795 %
# Incorrectly associated out of all hits in clusters:  18.88949591417579 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211690
# Identified correctly: 5040269
# Identified incorrectly: 1171421
# Total #hits in frames/#hits in clusters =  1.0000066004581685
# Total number of clusters: 3295657 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 167744
# Number of clusters where tid already exists: 1398008 , Hits: 2660278
# Number of clusters where tid already exists, that are accounted for: 1398008
# Correctly associated out of all hits:  81.1411344116479 %
# Correctly associated out of all hits in clusters:  81.14166998031132 %
# Incorrectly associated out of all hits:  18.858205546891842 %
# Incorrectly associated out of all hits in clusters:  18.858330019688683 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6209983
# Identified correctly: 5035760
# Identified incorrectly: 1174223
# Total #hits in frames/#hits in clusters =  1.0000033816517695
# Total number of clusters: 3293180 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 168593
# Number of clusters where tid already exists: 1398394 , Hits: 2658187
# Number of clusters where tid already exists, that are accounted for: 1398394
# Correctly associated out of all hits:  81.09109108464342 %
# Correctly associated out of all hits in clusters:  81.09136530647507 %
# Incorrectly associated out of all hits:  18.908570751323186 %
# Incorrectly associated out of all hits in clusters:  18.908634693524924 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217555
# Identified correctly: 5040602
# Identified incorrectly: 1176953
# Total #hits in frames/#hits in clusters =  1.000005950892272
# Total number of clusters: 3296930 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 168405
# Number of clusters where tid already exists: 1407466 , Hits: 2680026
# Number of clusters where tid already exists, that are accounted for: 1407466
# Correctly associated out of all hits:  81.07000266341053 %
# Correctly associated out of all hits in clusters:  81.07048510226286 %
# Incorrectly associated out of all hits:  18.929402250903564 %
# Incorrectly associated out of all hits in clusters:  18.929514897737132 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205108
# Identified correctly: 5033081
# Identified incorrectly: 1172027
# Total #hits in frames/#hits in clusters =  1.0000061239868832
# Total number of clusters: 3292066 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 168629
# Number of clusters where tid already exists: 1399912 , Hits: 2661967
# Number of clusters where tid already exists, that are accounted for: 1399912
# Correctly associated out of all hits:  81.11140334167803 %
# Correctly associated out of all hits in clusters:  81.11190006684815 %
# Incorrectly associated out of all hits:  18.887984263383974 %
# Incorrectly associated out of all hits in clusters:  18.88809993315185 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203396
# Identified correctly: 5031624
# Identified incorrectly: 1171772
# Total #hits in frames/#hits in clusters =  1.0000032240405095
# Total number of clusters: 3293416 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 167983
# Number of clusters where tid already exists: 1400670 , Hits: 2659624
# Number of clusters where tid already exists, that are accounted for: 1400670
# Correctly associated out of all hits:  81.1105365172995 %
# Correctly associated out of all hits in clusters:  81.11079802095497 %
# Incorrectly associated out of all hits:  18.889141079688997 %
# Incorrectly associated out of all hits in clusters:  18.889201979045026 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212430
# Identified correctly: 5038043
# Identified incorrectly: 1174387
# Total #hits in frames/#hits in clusters =  1.000006921607165
# Total number of clusters: 3294403 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 168492
# Number of clusters where tid already exists: 1399866 , Hits: 2662309
# Number of clusters where tid already exists, that are accounted for: 1399866
# Correctly associated out of all hits:  81.0956120050743 %
# Correctly associated out of all hits in clusters:  81.09617331704341 %
# Incorrectly associated out of all hits:  18.903695839000022 %
# Incorrectly associated out of all hits in clusters:  18.903826682956588 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195156
# Identified correctly: 5023936
# Identified incorrectly: 1171220
# Total #hits in frames/#hits in clusters =  1.0000054881588132
# Total number of clusters: 3287357 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 168151
# Number of clusters where tid already exists: 1395260 , Hits: 2653484
# Number of clusters where tid already exists, that are accounted for: 1395260
# Correctly associated out of all hits:  81.09413916280211 %
# Correctly associated out of all hits in clusters:  81.09458422031665 %
# Incorrectly associated out of all hits:  18.905312024328552 %
# Incorrectly associated out of all hits in clusters:  18.905415779683352 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200620
# Identified correctly: 5031878
# Identified incorrectly: 1168742
# Total #hits in frames/#hits in clusters =  1.0000066122420017
# Total number of clusters: 3290465 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 167426
# Number of clusters where tid already exists: 1398172 , Hits: 2656606
# Number of clusters where tid already exists, that are accounted for: 1398172
# Correctly associated out of all hits:  81.15067087202478 %
# Correctly associated out of all hits in clusters:  81.15120745989917 %
# Incorrectly associated out of all hits:  18.848667908147213 %
# Incorrectly associated out of all hits in clusters:  18.84879254010083 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199929
# Identified correctly: 5025772
# Identified incorrectly: 1174157
# Total #hits in frames/#hits in clusters =  1.0000061291024462
# Total number of clusters: 3288345 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 168706
# Number of clusters where tid already exists: 1397006 , Hits: 2656445
# Number of clusters where tid already exists, that are accounted for: 1397006
# Correctly associated out of all hits:  81.06127016482507 %
# Correctly associated out of all hits in clusters:  81.06176699765433 %
# Incorrectly associated out of all hits:  18.938116928686878 %
# Incorrectly associated out of all hits in clusters:  18.938233002345672 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211271
# Identified correctly: 5037690
# Identified incorrectly: 1173581
# Total #hits in frames/#hits in clusters =  1.000006600903422
# Total number of clusters: 3293223 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 168818
# Number of clusters where tid already exists: 1397400 , Hits: 2659748
# Number of clusters where tid already exists, that are accounted for: 1397400
# Correctly associated out of all hits:  81.1050869767933 %
# Correctly associated out of all hits in clusters:  81.1056223436395 %
# Incorrectly associated out of all hits:  18.894252937221637 %
# Incorrectly associated out of all hits in clusters:  18.89437765636051 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204459
# Identified correctly: 5032132
# Identified incorrectly: 1172327
# Total #hits in frames/#hits in clusters =  1.0000051575810236
# Total number of clusters: 3292016 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 168398
# Number of clusters where tid already exists: 1397188 , Hits: 2653421
# Number of clusters where tid already exists, that are accounted for: 1397188
# Correctly associated out of all hits:  81.10467079410704 %
# Correctly associated out of all hits in clusters:  81.10508909801806 %
# Incorrectly associated out of all hits:  18.89481345045065 %
# Incorrectly associated out of all hits in clusters:  18.894910901981948 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203009
# Identified correctly: 5032095
# Identified incorrectly: 1170914
# Total #hits in frames/#hits in clusters =  1.0000041915141507
# Total number of clusters: 3290643 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 167854
# Number of clusters where tid already exists: 1400708 , Hits: 2661698
# Number of clusters where tid already exists, that are accounted for: 1400708
# Correctly associated out of all hits:  81.12311150912416 %
# Correctly associated out of all hits in clusters:  81.123451537794 %
# Incorrectly associated out of all hits:  18.876469341217646 %
# Incorrectly associated out of all hits in clusters:  18.876548462206003 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205622
# Identified correctly: 5030073
# Identified incorrectly: 1175549
# Total #hits in frames/#hits in clusters =  1.00000547890284
# Total number of clusters: 3292144 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 168399
# Number of clusters where tid already exists: 1400386 , Hits: 2658853
# Number of clusters where tid already exists, that are accounted for: 1400386
# Correctly associated out of all hits:  81.05626544558706 %
# Correctly associated out of all hits in clusters:  81.05670954499001 %
# Incorrectly associated out of all hits:  18.94318666713076 %
# Incorrectly associated out of all hits in clusters:  18.94329045500999 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207383
# Identified correctly: 5035450
# Identified incorrectly: 1171933
# Total #hits in frames/#hits in clusters =  1.0000070883333605
# Total number of clusters: 3292708 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 168534
# Number of clusters where tid already exists: 1397556 , Hits: 2658135
# Number of clusters where tid already exists, that are accounted for: 1397556
# Correctly associated out of all hits:  81.11976185946287 %
# Correctly associated out of all hits in clusters:  81.12033686337705 %
# Incorrectly associated out of all hits:  18.8795293122255 %
# Incorrectly associated out of all hits in clusters:  18.879663136622952 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221325
# Identified correctly: 5042739
# Identified incorrectly: 1178586
# Total #hits in frames/#hits in clusters =  1.000004018436587
# Total number of clusters: 3299568 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 168570
# Number of clusters where tid already exists: 1403252 , Hits: 2665503
# Number of clusters where tid already exists, that are accounted for: 1403252
# Correctly associated out of all hits:  81.05538187049434 %
# Correctly associated out of all hits in clusters:  81.05570758640643 %
# Incorrectly associated out of all hits:  18.944216287461725 %
# Incorrectly associated out of all hits in clusters:  18.944292413593566 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201661
# Identified correctly: 5030072
# Identified incorrectly: 1171589
# Total #hits in frames/#hits in clusters =  1.0000051599079667
# Total number of clusters: 3291672 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 168486
# Number of clusters where tid already exists: 1400700 , Hits: 2661462
# Number of clusters where tid already exists, that are accounted for: 1400700
# Correctly associated out of all hits:  81.10804581910133 %
# Correctly associated out of all hits in clusters:  81.10846432915311 %
# Incorrectly associated out of all hits:  18.89143819276446 %
# Incorrectly associated out of all hits in clusters:  18.891535670846892 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210264
# Identified correctly: 5034234
# Identified incorrectly: 1176030
# Total #hits in frames/#hits in clusters =  1.0000051527600116
# Total number of clusters: 3293758 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 168300
# Number of clusters where tid already exists: 1398956 , Hits: 2657985
# Number of clusters where tid already exists, that are accounted for: 1398956
# Correctly associated out of all hits:  81.06270618984989 %
# Correctly associated out of all hits in clusters:  81.06312388652077 %
# Incorrectly associated out of all hits:  18.93677853680404 %
# Incorrectly associated out of all hits in clusters:  18.936876113479233 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205447
# Identified correctly: 5033644
# Identified incorrectly: 1171803
# Total #hits in frames/#hits in clusters =  1.0000046733136227
# Total number of clusters: 3291159 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 167651
# Number of clusters where tid already exists: 1396400 , Hits: 2652089
# Number of clusters where tid already exists, that are accounted for: 1396400
# Correctly associated out of all hits:  81.11616256351648 %
# Correctly associated out of all hits in clusters:  81.11654164478401 %
# Incorrectly associated out of all hits:  18.883370107305225 %
# Incorrectly associated out of all hits in clusters:  18.88345835521599 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207806
# Identified correctly: 5035476
# Identified incorrectly: 1172330
# Total #hits in frames/#hits in clusters =  1.0000056380627873
# Total number of clusters: 3292286 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 168205
# Number of clusters where tid already exists: 1397286 , Hits: 2653095
# Number of clusters where tid already exists, that are accounted for: 1397286
# Correctly associated out of all hits:  81.11477081967789 %
# Correctly associated out of all hits in clusters:  81.11522814984876 %
# Incorrectly associated out of all hits:  18.884665377222127 %
# Incorrectly associated out of all hits in clusters:  18.884771850151246 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_iterativespatial_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203362
# Identified correctly: 5034584
# Identified incorrectly: 1168778
# Total #hits in frames/#hits in clusters =  1.0000045136814522
# Total number of clusters: 3291451 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 167872
# Number of clusters where tid already exists: 1398272 , Hits: 2659927
# Number of clusters where tid already exists, that are accounted for: 1398272
# Correctly associated out of all hits:  81.15859231807124 %
# Correctly associated out of all hits in clusters:  81.15895864210407 %
# Incorrectly associated out of all hits:  18.840956315820865 %
# Incorrectly associated out of all hits in clusters:  18.84104135789593 %

# %% [markdown]
# ### No Threshold

# %%
current_threshold = threshold_cluster_width_used[5] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_iterativespatial_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_iterativespatial_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_152_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207806
# Identified correctly: 2825578
# Identified incorrectly: 3382228
# Total #hits in frames/#hits in clusters =  1.0000056380627873
# Total number of clusters: 3292286 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 168205
# Number of clusters where tid already exists: 1397286 , Hits: 2653095
# Number of clusters where tid already exists, that are accounted for: 1397286
# Correctly associated out of all hits:  45.5162753040872 %
# Correctly associated out of all hits in clusters:  45.516531927705216 %
# Incorrectly associated out of all hits:  54.48316089281281 %
# Incorrectly associated out of all hits in clusters:  54.483468072294784 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203009
# Identified correctly: 2813168
# Identified incorrectly: 3389841
# Total #hits in frames/#hits in clusters =  1.0000041915141507
# Total number of clusters: 3290643 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 167854
# Number of clusters where tid already exists: 1400708 , Hits: 2661698
# Number of clusters where tid already exists, that are accounted for: 1400708
# Correctly associated out of all hits:  45.35147713981946 %
# Correctly associated out of all hits in clusters:  45.35166723117764 %
# Incorrectly associated out of all hits:  54.64810371052235 %
# Incorrectly associated out of all hits in clusters:  54.64833276882236 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210264
# Identified correctly: 2825547
# Identified incorrectly: 3384717
# Total #hits in frames/#hits in clusters =  1.0000051527600116
# Total number of clusters: 3293758 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 168300
# Number of clusters where tid already exists: 1398956 , Hits: 2657985
# Number of clusters where tid already exists, that are accounted for: 1398956
# Correctly associated out of all hits:  45.49778303642854 %
# Correctly associated out of all hits in clusters:  45.49801747558558 %
# Incorrectly associated out of all hits:  54.501701690225396 %
# Incorrectly associated out of all hits in clusters:  54.50198252441442 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211690
# Identified correctly: 2824467
# Identified incorrectly: 3387223
# Total #hits in frames/#hits in clusters =  1.0000066004581685
# Total number of clusters: 3295657 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 167744
# Number of clusters where tid already exists: 1398008 , Hits: 2660278
# Number of clusters where tid already exists, that are accounted for: 1398008
# Correctly associated out of all hits:  45.469885930346955 %
# Correctly associated out of all hits in clusters:  45.47018605242695 %
# Incorrectly associated out of all hits:  54.52945402819279 %
# Incorrectly associated out of all hits in clusters:  54.52981394757304 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200620
# Identified correctly: 2815947
# Identified incorrectly: 3384673
# Total #hits in frames/#hits in clusters =  1.0000066122420017
# Total number of clusters: 3290465 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 167426
# Number of clusters where tid already exists: 1398172 , Hits: 2656606
# Number of clusters where tid already exists, that are accounted for: 1398172
# Correctly associated out of all hits:  45.41365831804061 %
# Correctly associated out of all hits in clusters:  45.41395860413959 %
# Incorrectly associated out of all hits:  54.58568046213138 %
# Incorrectly associated out of all hits in clusters:  54.58604139586042 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212430
# Identified correctly: 2822480
# Identified incorrectly: 3389950
# Total #hits in frames/#hits in clusters =  1.000006921607165
# Total number of clusters: 3294403 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 168492
# Number of clusters where tid already exists: 1399866 , Hits: 2662309
# Number of clusters where tid already exists, that are accounted for: 1399866
# Correctly associated out of all hits:  45.432471094844196 %
# Correctly associated out of all hits in clusters:  45.43278556056165 %
# Incorrectly associated out of all hits:  54.566836749230134 %
# Incorrectly associated out of all hits in clusters:  54.56721443943835 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208784
# Identified correctly: 2821935
# Identified incorrectly: 3386849
# Total #hits in frames/#hits in clusters =  1.0000046708018833
# Total number of clusters: 3292499 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 168422
# Number of clusters where tid already exists: 1399700 , Hits: 2659833
# Number of clusters where tid already exists, that are accounted for: 1399700
# Correctly associated out of all hits:  45.450474994173604 %
# Correctly associated out of all hits in clusters:  45.4506872843378 %
# Incorrectly associated out of all hits:  54.5490579278197 %
# Incorrectly associated out of all hits in clusters:  54.549312715662204 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201661
# Identified correctly: 2814278
# Identified incorrectly: 3387383
# Total #hits in frames/#hits in clusters =  1.0000051599079667
# Total number of clusters: 3291672 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 168486
# Number of clusters where tid already exists: 1400700 , Hits: 2661462
# Number of clusters where tid already exists, that are accounted for: 1400700
# Correctly associated out of all hits:  45.379189198820384 %
# Correctly associated out of all hits in clusters:  45.37942335126025 %
# Incorrectly associated out of all hits:  54.620294813045405 %
# Incorrectly associated out of all hits in clusters:  54.62057664873975 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205447
# Identified correctly: 2824235
# Identified incorrectly: 3381212
# Total #hits in frames/#hits in clusters =  1.0000046733136227
# Total number of clusters: 3291159 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 167651
# Number of clusters where tid already exists: 1396400 , Hits: 2652089
# Number of clusters where tid already exists, that are accounted for: 1396400
# Correctly associated out of all hits:  45.51198006405955 %
# Correctly associated out of all hits in clusters:  45.51219275581598 %
# Incorrectly associated out of all hits:  54.48755260676216 %
# Incorrectly associated out of all hits in clusters:  54.48780724418402 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203362
# Identified correctly: 2819370
# Identified incorrectly: 3383992
# Total #hits in frames/#hits in clusters =  1.0000045136814522
# Total number of clusters: 3291451 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 167872
# Number of clusters where tid already exists: 1398272 , Hits: 2659927
# Number of clusters where tid already exists, that are accounted for: 1398272
# Correctly associated out of all hits:  45.448859413965586 %
# Correctly associated out of all hits in clusters:  45.449064555639346 %
# Incorrectly associated out of all hits:  54.550689219926525 %
# Incorrectly associated out of all hits in clusters:  54.550935444360654 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204459
# Identified correctly: 2823148
# Identified incorrectly: 3381311
# Total #hits in frames/#hits in clusters =  1.0000051575810236
# Total number of clusters: 3292016 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 168398
# Number of clusters where tid already exists: 1397188 , Hits: 2653421
# Number of clusters where tid already exists, that are accounted for: 1397188
# Correctly associated out of all hits:  45.501685795015256 %
# Correctly associated out of all hits in clusters:  45.50192047364646 %
# Incorrectly associated out of all hits:  54.49779844954244 %
# Incorrectly associated out of all hits in clusters:  54.49807952635355 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6200986
# Identified correctly: 2819520
# Identified incorrectly: 3381466
# Total #hits in frames/#hits in clusters =  1.0000066118517281
# Total number of clusters: 3291392 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 167799
# Number of clusters where tid already exists: 1397614 , Hits: 2655174
# Number of clusters where tid already exists, that are accounted for: 1397614
# Correctly associated out of all hits:  45.46859737911156 %
# Correctly associated out of all hits in clusters:  45.468898010735714 %
# Incorrectly associated out of all hits:  54.53074144008727 %
# Incorrectly associated out of all hits in clusters:  54.531101989264286 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207940
# Identified correctly: 2822270
# Identified incorrectly: 3385670
# Total #hits in frames/#hits in clusters =  1.0000059601091504
# Total number of clusters: 3292619 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 168391
# Number of clusters where tid already exists: 1397762 , Hits: 2660635
# Number of clusters where tid already exists, that are accounted for: 1397762
# Correctly associated out of all hits:  45.461991885601385 %
# Correctly associated out of all hits in clusters:  45.462262844035216 %
# Incorrectly associated out of all hits:  54.537412107035834 %
# Incorrectly associated out of all hits in clusters:  54.53773715596478 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203396
# Identified correctly: 2816959
# Identified incorrectly: 3386437
# Total #hits in frames/#hits in clusters =  1.0000032240405095
# Total number of clusters: 3293416 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 167983
# Number of clusters where tid already exists: 1400670 , Hits: 2659624
# Number of clusters where tid already exists, that are accounted for: 1400670
# Correctly associated out of all hits:  45.40980324389014 %
# Correctly associated out of all hits in clusters:  45.409949646935324 %
# Incorrectly associated out of all hits:  54.58987435309835 %
# Incorrectly associated out of all hits in clusters:  54.590050353064676 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199929
# Identified correctly: 2816407
# Identified incorrectly: 3383522
# Total #hits in frames/#hits in clusters =  1.0000061291024462
# Total number of clusters: 3288345 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 168706
# Number of clusters where tid already exists: 1397006 , Hits: 2656445
# Number of clusters where tid already exists, that are accounted for: 1397006
# Correctly associated out of all hits:  45.426161139244776 %
# Correctly associated out of all hits in clusters:  45.42643956084013 %
# Incorrectly associated out of all hits:  54.57322595426718 %
# Incorrectly associated out of all hits in clusters:  54.57356043915987 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209283
# Identified correctly: 2823611
# Identified incorrectly: 3385672
# Total #hits in frames/#hits in clusters =  1.0000035430821883
# Total number of clusters: 3293370 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 168211
# Number of clusters where tid already exists: 1398610 , Hits: 2658319
# Number of clusters where tid already exists, that are accounted for: 1398610
# Correctly associated out of all hits:  45.473865432604775 %
# Correctly associated out of all hits in clusters:  45.47402655024743 %
# Incorrectly associated out of all hits:  54.52578026043172 %
# Incorrectly associated out of all hits in clusters:  54.52597344975257 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6209983
# Identified correctly: 2823617
# Identified incorrectly: 3386366
# Total #hits in frames/#hits in clusters =  1.0000033816517695
# Total number of clusters: 3293180 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 168593
# Number of clusters where tid already exists: 1398394 , Hits: 2658187
# Number of clusters where tid already exists, that are accounted for: 1398394
# Correctly associated out of all hits:  45.46884349832947 %
# Correctly associated out of all hits in clusters:  45.46899725812454 %
# Incorrectly associated out of all hits:  54.53081833763714 %
# Incorrectly associated out of all hits in clusters:  54.53100274187546 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221325
# Identified correctly: 2825816
# Identified incorrectly: 3395509
# Total #hits in frames/#hits in clusters =  1.000004018436587
# Total number of clusters: 3299568 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 168570
# Number of clusters where tid already exists: 1403252 , Hits: 2665503
# Number of clusters where tid already exists, that are accounted for: 1403252
# Correctly associated out of all hits:  45.42126708833292 %
# Correctly associated out of all hits in clusters:  45.42144961081441 %
# Incorrectly associated out of all hits:  54.578331069623154 %
# Incorrectly associated out of all hits in clusters:  54.57855038918559 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215423
# Identified correctly: 2814511
# Identified incorrectly: 3400912
# Total #hits in frames/#hits in clusters =  1.0000048267028647
# Total number of clusters: 3297152 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 168343
# Number of clusters where tid already exists: 1406848 , Hits: 2673495
# Number of clusters where tid already exists, that are accounted for: 1406848
# Correctly associated out of all hits:  45.282475790581955 %
# Correctly associated out of all hits in clusters:  45.28269435563758 %
# Incorrectly associated out of all hits:  54.717041541461256 %
# Incorrectly associated out of all hits in clusters:  54.71730564436242 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211271
# Identified correctly: 2823618
# Identified incorrectly: 3387653
# Total #hits in frames/#hits in clusters =  1.000006600903422
# Total number of clusters: 3293223 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 168818
# Number of clusters where tid already exists: 1397400 , Hits: 2659748
# Number of clusters where tid already exists, that are accounted for: 1397400
# Correctly associated out of all hits:  45.45928460846919 %
# Correctly associated out of all hits in clusters:  45.45958468081653 %
# Incorrectly associated out of all hits:  54.54005530554575 %
# Incorrectly associated out of all hits in clusters:  54.54041531918347 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6204978
# Identified correctly: 2825720
# Identified incorrectly: 3379258
# Total #hits in frames/#hits in clusters =  1.000003545540371
# Total number of clusters: 3292825 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 168266
# Number of clusters where tid already exists: 1398004 , Hits: 2653009
# Number of clusters where tid already exists, that are accounted for: 1398004
# Correctly associated out of all hits:  45.539403706688155 %
# Correctly associated out of all hits in clusters:  45.53956516848247 %
# Incorrectly associated out of all hits:  54.46024174053183 %
# Incorrectly associated out of all hits in clusters:  54.46043483151753 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205622
# Identified correctly: 2819081
# Identified incorrectly: 3386541
# Total #hits in frames/#hits in clusters =  1.00000547890284
# Total number of clusters: 3292144 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 168399
# Number of clusters where tid already exists: 1400386 , Hits: 2658853
# Number of clusters where tid already exists, that are accounted for: 1400386
# Correctly associated out of all hits:  45.42760668654531 %
# Correctly associated out of all hits in clusters:  45.427855579988595 %
# Incorrectly associated out of all hits:  54.571845426172516 %
# Incorrectly associated out of all hits in clusters:  54.572144420011405 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195156
# Identified correctly: 2817001
# Identified incorrectly: 3378155
# Total #hits in frames/#hits in clusters =  1.0000054881588132
# Total number of clusters: 3287357 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 168151
# Number of clusters where tid already exists: 1395260 , Hits: 2653484
# Number of clusters where tid already exists, that are accounted for: 1395260
# Correctly associated out of all hits:  45.470776521785446 %
# Correctly associated out of all hits in clusters:  45.471026072628355 %
# Incorrectly associated out of all hits:  54.52867466534521 %
# Incorrectly associated out of all hits in clusters:  54.528973927371645 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197072
# Identified correctly: 2823421
# Identified incorrectly: 3373651
# Total #hits in frames/#hits in clusters =  1.000005002362406
# Total number of clusters: 3289079 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 167738
# Number of clusters where tid already exists: 1394930 , Hits: 2645941
# Number of clusters where tid already exists, that are accounted for: 1394930
# Correctly associated out of all hits:  45.56033682189888 %
# Correctly associated out of all hits in clusters:  45.560564731214996 %
# Incorrectly associated out of all hits:  54.43916294436288 %
# Incorrectly associated out of all hits in clusters:  54.439435268785 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207383
# Identified correctly: 2822744
# Identified incorrectly: 3384639
# Total #hits in frames/#hits in clusters =  1.0000070883333605
# Total number of clusters: 3292708 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 168534
# Number of clusters where tid already exists: 1397556 , Hits: 2658135
# Number of clusters where tid already exists, that are accounted for: 1397556
# Correctly associated out of all hits:  45.47365599305478 %
# Correctly associated out of all hits in clusters:  45.473978325487565 %
# Incorrectly associated out of all hits:  54.5256351786336 %
# Incorrectly associated out of all hits in clusters:  54.52602167451243 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217555
# Identified correctly: 2807449
# Identified incorrectly: 3410106
# Total #hits in frames/#hits in clusters =  1.000005950892272
# Total number of clusters: 3296930 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 168405
# Number of clusters where tid already exists: 1407466 , Hits: 2680026
# Number of clusters where tid already exists, that are accounted for: 1407466
# Correctly associated out of all hits:  45.15331658944492 %
# Correctly associated out of all hits in clusters:  45.15358529196766 %
# Incorrectly associated out of all hits:  54.84608832486918 %
# Incorrectly associated out of all hits in clusters:  54.846414708032334 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206045
# Identified correctly: 2824793
# Identified incorrectly: 3381252
# Total #hits in frames/#hits in clusters =  1.000003706064007
# Total number of clusters: 3293755 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 168141
# Number of clusters where tid already exists: 1397456 , Hits: 2653446
# Number of clusters where tid already exists, that are accounted for: 1397456
# Correctly associated out of all hits:  45.516629853233965 %
# Correctly associated out of all hits in clusters:  45.516798540777586 %
# Incorrectly associated out of all hits:  54.48299954173883 %
# Incorrectly associated out of all hits in clusters:  54.48320145922242 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211875
# Identified correctly: 2822849
# Identified incorrectly: 3389026
# Total #hits in frames/#hits in clusters =  1.000005795351645
# Total number of clusters: 3295597 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 168174
# Number of clusters where tid already exists: 1402074 , Hits: 2662308
# Number of clusters where tid already exists, that are accounted for: 1402074
# Correctly associated out of all hits:  45.44252163303692 %
# Correctly associated out of all hits in clusters:  45.442784988429416 %
# Incorrectly associated out of all hits:  54.55689883515717 %
# Incorrectly associated out of all hits in clusters:  54.557215011570584 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_iterativespatial_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205108
# Identified correctly: 2817484
# Identified incorrectly: 3387624
# Total #hits in frames/#hits in clusters =  1.0000061239868832
# Total number of clusters: 3292066 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 168629
# Number of clusters where tid already exists: 1399912 , Hits: 2661967
# Number of clusters where tid already exists, that are accounted for: 1399912
# Correctly associated out of all hits:  45.40560367153327 %
# Correctly associated out of all hits in clusters:  45.405881734854574 %
# Incorrectly associated out of all hits:  54.59378393352872 %
# Incorrectly associated out of all hits in clusters:  54.594118265145426 %

# %% [markdown]
# # Pure time clustering

# %%
time_threshold_used = 0.4
threshold_cluster_width_used = [20,25,30,35,40,999999]

function_str = "mt_compare_to_tid"
src = "./testdata/sorted/root_files_fixed/mu3e_sorted_000*.root"

for threshold in threshold_cluster_width_used:
    args = (time_threshold_used, threshold, "big", None, "time")

    clump.multithreading.run_mt(function_str, src, args)
# Out:
# -----------------------
# Available threads =  12
# Used threads =  10
# -----------------------
# read file  3
# read file  1
# read file  2
# read file  5
# started thread  3
# read file  4
# started thread  2
# read file  6
# started thread  1
# read file  7
# started thread  5
# read file  8
# started thread  4
# started thread  6
# started thread  7
# read file  10
# read file  9
# started thread  8
# started thread  9
# started thread  10
# read file  11
# started thread  11
# read file  12
# started thread  12
# read file  13
# started thread  13
# read file  14
# started thread  14
# read file  15
# started thread  15
# read file  16
# started thread  16
# read file  17
# started thread  17
# read file  18
# started thread  18
# read file  19
# started thread  19
# read file  20
# started thread  20
# read file  21
# started thread  21
# read file  22
# started thread  22
# read file  23
# started thread  23
# read file  24
# started thread  24
# read file  25
# started thread  25
# read file  26
# started thread  26
# read file  27
# started thread  27
# read file  28
# started thread  28
# read file  29
# started thread  29
# -----------------------
# Available threads =  12
# Used threads =  10
# -----------------------
# read file  9
# read file  1
# read file  3
# read file  2
# read file  7
# read file  4
# read file  10
# read file  6
# read file  8
# read file  5
# started thread  1
# started thread  9
# started thread  7
# started thread  2
# started thread  3
# started thread  8
# started thread  6
# started thread  4
# started thread  10
# started thread  5
# read file  11
# started thread  11
# read file  12
# started thread  12
# read file  13
# started thread  13
# read file  14
# started thread  14
# read file  15
# started thread  15
# read file  16
# started thread  16
# read file  17
# started thread  17
# read file  18
# started thread  18
# read file  19
# started thread  19
# read file  20
# started thread  20
# read file  21
# started thread  21
# read file  22
# started thread  22
# read file  23
# started thread  23
# read file  24
# started thread  24
# read file  25
# started thread  25
# read file  26
# started thread  26
# read file  27
# started thread  27
# read file  28
# started thread  28
# read file  29
# started thread  29
# -----------------------
# Available threads =  12
# Used threads =  10
# -----------------------
# read file  3
# read file  2
# read file  4
# read file  1
# read file  5
# read file  7
# read file  6
# read file  10
# read file  9
# started thread  3
# started thread  2
# started thread  1
# started thread  5
# started thread  7
# started thread  9
# started thread  6
# started thread  10
# started thread  4
# read file  8
# started thread  8
# read file  11
# started thread  11
# read file  12
# started thread  12
# read file  13
# started thread  13
# read file  14
# started thread  14
# read file  15
# started thread  15
# read file  16
# started thread  16
# read file  17
# started thread  17
# read file  18
# started thread  18
# read file  19
# started thread  19
# read file  20
# started thread  20
# read file  21
# started thread  21
# read file  22
# started thread  22
# read file  23
# started thread  23
# read file  24
# started thread  24
# read file  25
# started thread  25
# read file  26
# started thread  26
# read file  27
# started thread  27
# read file  28
# started thread  28
# read file  29
# started thread  29
# -----------------------
# Available threads =  12
# Used threads =  10
# -----------------------
# read file  1
# read file  4
# read file  2
# read file  5
# read file  3
# read file  6
# read file  8
# read file  7
# read file  10
# read file  9
# started thread  1
# started thread  4
# started thread  5
# started thread  3
# started thread  6
# started thread  8
# started thread  7
# started thread  10
# started thread  9
# started thread  2
# read file  11
# started thread  11
# read file  12
# started thread  12
# read file  13
# started thread  13
# read file  14
# started thread  14
# read file  15
# started thread  15
# read file  16
# started thread  16
# read file  17
# started thread  17
# read file  18
# started thread  18
# read file  19
# started thread  19
# read file  20
# started thread  20
# read file  21
# started thread  21
# read file  22
# started thread  22
# read file  23
# started thread  23
# read file  24
# started thread  24
# read file  25
# started thread  25
# read file  26
# started thread  26
# read file  27
# started thread  27
# read file  28
# started thread  28
# read file  29
# started thread  29
# -----------------------
# Available threads =  12
# Used threads =  10
# -----------------------
# read file  2
# read file  4
# read file  1
# read file  7
# read file  3
# read file  8
# read file  5
# read file  6
# read file  9
# started thread  2
# read file  10
# started thread  4
# started thread  3
# started thread  1
# started thread  6
# started thread  7
# started thread  5
# started thread  9
# started thread  8
# started thread  10
# read file  11
# started thread  11
# read file  12
# started thread  12
# read file  13
# started thread  13
# read file  14
# started thread  14
# read file  15
# started thread  15
# read file  16
# started thread  16
# read file  17
# started thread  17
# read file  18
# started thread  18
# read file  19
# started thread  19
# read file  20
# started thread  20
# read file  21
# started thread  21
# read file  22
# started thread  22
# read file  23
# started thread  23
# read file  24
# started thread  24
# read file  25
# started thread  25
# read file  26
# started thread  26
# read file  27
# started thread  27
# read file  28
# started thread  28
# read file  29
# started thread  29
# -----------------------
# Available threads =  12
# Used threads =  10
# -----------------------
# read file  2
# read file  1
# read file  3
# read file  7
# read file  6
# read file  10
# read file  8
# read file  9
# read file  5
# read file  4
# started thread  2
# started thread  1
# started thread  7
# started thread  8
# started thread  10
# started thread  6
# started thread  3
# started thread  5
# started thread  4
# started thread  9
# read file  11
# started thread  11
# read file  12
# started thread  12
# read file  13
# started thread  13
# read file  14
# started thread  14
# read file  15
# started thread  15
# read file  16
# started thread  16
# read file  17
# started thread  17
# read file  18
# started thread  18
# read file  19
# started thread  19
# read file  20
# started thread  20
# read file  21
# started thread  21
# read file  22
# started thread  22
# read file  23
# started thread  23
# read file  24
# started thread  24
# read file  25
# started thread  25
# read file  26
# started thread  26
# read file  27
# started thread  27
# read file  28
# started thread  28
# read file  29
# started thread  29

# %% [markdown]
# ## Efficiency statistics

# %% [markdown]
# ### Threshold: 20mm

# %%
current_threshold = threshold_cluster_width_used[0] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_time_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_time_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_164_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 4921389
# Identified incorrectly: 1282027
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852932 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776948 , Hits: 1770756
# Number of clusters where tid already exists, that are accounted for: 776948
# Correctly associated out of all hits:  79.33353171865308 %
# Correctly associated out of all hits in clusters:  79.33353171865308 %
# Incorrectly associated out of all hits:  20.666468281346923 %
# Incorrectly associated out of all hits in clusters:  20.666468281346923 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 4917712
# Identified incorrectly: 1277478
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849276 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1770795
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  79.37951862654737 %
# Correctly associated out of all hits in clusters:  79.37951862654737 %
# Incorrectly associated out of all hits:  20.62048137345263 %
# Incorrectly associated out of all hits in clusters:  20.62048137345263 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 4923256
# Identified incorrectly: 1282812
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853897 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1769685
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  79.32971407983284 %
# Correctly associated out of all hits in clusters:  79.32971407983284 %
# Incorrectly associated out of all hits:  20.670285920167164 %
# Incorrectly associated out of all hits in clusters:  20.670285920167164 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 4917452
# Identified incorrectly: 1282515
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850023 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774764 , Hits: 1768161
# Number of clusters where tid already exists, that are accounted for: 774764
# Correctly associated out of all hits:  79.31416409151855 %
# Correctly associated out of all hits in clusters:  79.31416409151855 %
# Incorrectly associated out of all hits:  20.685835908481447 %
# Incorrectly associated out of all hits in clusters:  20.685835908481447 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 4919669
# Identified incorrectly: 1281358
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851057 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775822 , Hits: 1769624
# Number of clusters where tid already exists, that are accounted for: 775822
# Correctly associated out of all hits:  79.33635831613054 %
# Correctly associated out of all hits in clusters:  79.33635831613054 %
# Incorrectly associated out of all hits:  20.663641683869464 %
# Incorrectly associated out of all hits in clusters:  20.663641683869464 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 4921499
# Identified incorrectly: 1284157
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852341 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775738 , Hits: 1770392
# Number of clusters where tid already exists, that are accounted for: 775738
# Correctly associated out of all hits:  79.30666798159615 %
# Correctly associated out of all hits in clusters:  79.30666798159615 %
# Incorrectly associated out of all hits:  20.693332018403858 %
# Incorrectly associated out of all hits in clusters:  20.693332018403858 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 4927374
# Identified incorrectly: 1281439
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853286 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776572 , Hits: 1772828
# Number of clusters where tid already exists, that are accounted for: 776572
# Correctly associated out of all hits:  79.36096641982937 %
# Correctly associated out of all hits in clusters:  79.36096641982937 %
# Incorrectly associated out of all hits:  20.63903358017064 %
# Incorrectly associated out of all hits in clusters:  20.63903358017064 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 4923624
# Identified incorrectly: 1284217
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852724 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778818 , Hits: 1773877
# Number of clusters where tid already exists, that are accounted for: 778818
# Correctly associated out of all hits:  79.31298498141302 %
# Correctly associated out of all hits in clusters:  79.31298498141302 %
# Incorrectly associated out of all hits:  20.687015018586976 %
# Incorrectly associated out of all hits in clusters:  20.687015018586976 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 4925582
# Identified incorrectly: 1286329
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853370 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777968 , Hits: 1774985
# Number of clusters where tid already exists, that are accounted for: 777968
# Correctly associated out of all hits:  79.29253976755301 %
# Correctly associated out of all hits in clusters:  79.29253976755301 %
# Incorrectly associated out of all hits:  20.707460232446987 %
# Incorrectly associated out of all hits in clusters:  20.707460232446987 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 4927157
# Identified incorrectly: 1284155
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854136 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777484 , Hits: 1778667
# Number of clusters where tid already exists, that are accounted for: 777484
# Correctly associated out of all hits:  79.32554346006125 %
# Correctly associated out of all hits in clusters:  79.32554346006125 %
# Incorrectly associated out of all hits:  20.674456539938742 %
# Incorrectly associated out of all hits in clusters:  20.674456539938742 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 4932808
# Identified incorrectly: 1288542
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2858288 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780384 , Hits: 1780066
# Number of clusters where tid already exists, that are accounted for: 780384
# Correctly associated out of all hits:  79.28838596124635 %
# Correctly associated out of all hits in clusters:  79.28838596124635 %
# Incorrectly associated out of all hits:  20.71161403875365 %
# Incorrectly associated out of all hits in clusters:  20.71161403875365 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 4914801
# Identified incorrectly: 1282302
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849479 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774668 , Hits: 1765073
# Number of clusters where tid already exists, that are accounted for: 774668
# Correctly associated out of all hits:  79.30804119279605 %
# Correctly associated out of all hits in clusters:  79.30804119279605 %
# Incorrectly associated out of all hits:  20.691958807203946 %
# Incorrectly associated out of all hits in clusters:  20.691958807203946 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 4926660
# Identified incorrectly: 1280767
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853451 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776620 , Hits: 1771891
# Number of clusters where tid already exists, that are accounted for: 776620
# Correctly associated out of all hits:  79.36718385894832 %
# Correctly associated out of all hits in clusters:  79.36718385894832 %
# Incorrectly associated out of all hits:  20.63281614105168 %
# Incorrectly associated out of all hits in clusters:  20.63281614105168 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 4922433
# Identified incorrectly: 1283043
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851549 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774790 , Hits: 1767180
# Number of clusters where tid already exists, that are accounted for: 774790
# Correctly associated out of all hits:  79.32401962395794 %
# Correctly associated out of all hits in clusters:  79.32401962395794 %
# Incorrectly associated out of all hits:  20.675980376042062 %
# Incorrectly associated out of all hits in clusters:  20.675980376042062 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 4924109
# Identified incorrectly: 1285895
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853339 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777218 , Hits: 1773266
# Number of clusters where tid already exists, that are accounted for: 777218
# Correctly associated out of all hits:  79.29316953741092 %
# Correctly associated out of all hits in clusters:  79.29316953741092 %
# Incorrectly associated out of all hits:  20.706830462589075 %
# Incorrectly associated out of all hits in clusters:  20.706830462589075 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 4923661
# Identified incorrectly: 1281485
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852758 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779448 , Hits: 1779911
# Number of clusters where tid already exists, that are accounted for: 779448
# Correctly associated out of all hits:  79.34802823334053 %
# Correctly associated out of all hits in clusters:  79.34802823334053 %
# Incorrectly associated out of all hits:  20.65197176665948 %
# Incorrectly associated out of all hits in clusters:  20.65197176665948 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 4933078
# Identified incorrectly: 1284514
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854944 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780552 , Hits: 1786781
# Number of clusters where tid already exists, that are accounted for: 780552
# Correctly associated out of all hits:  79.34065149337557 %
# Correctly associated out of all hits in clusters:  79.34065149337557 %
# Incorrectly associated out of all hits:  20.65934850662443 %
# Incorrectly associated out of all hits in clusters:  20.65934850662443 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 4921133
# Identified incorrectly: 1281902
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851068 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777698 , Hits: 1774621
# Number of clusters where tid already exists, that are accounted for: 777698
# Correctly associated out of all hits:  79.33427749480698 %
# Correctly associated out of all hits in clusters:  79.33427749480698 %
# Incorrectly associated out of all hits:  20.665722505193024 %
# Incorrectly associated out of all hits in clusters:  20.665722505193024 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 4926148
# Identified incorrectly: 1284148
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853312 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776614 , Hits: 1772046
# Number of clusters where tid already exists, that are accounted for: 776614
# Correctly associated out of all hits:  79.32227384974887 %
# Correctly associated out of all hits in clusters:  79.32227384974887 %
# Incorrectly associated out of all hits:  20.677726150251132 %
# Incorrectly associated out of all hits in clusters:  20.677726150251132 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 4925281
# Identified incorrectly: 1282696
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852275 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775636 , Hits: 1773201
# Number of clusters where tid already exists, that are accounted for: 775636
# Correctly associated out of all hits:  79.33793891311132 %
# Correctly associated out of all hits in clusters:  79.33793891311132 %
# Incorrectly associated out of all hits:  20.66206108688869 %
# Incorrectly associated out of all hits in clusters:  20.66206108688869 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 4920057
# Identified incorrectly: 1280604
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850481 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776280 , Hits: 1770358
# Number of clusters where tid already exists, that are accounted for: 776280
# Correctly associated out of all hits:  79.34729861864727 %
# Correctly associated out of all hits in clusters:  79.34729861864727 %
# Incorrectly associated out of all hits:  20.65270138135273 %
# Incorrectly associated out of all hits in clusters:  20.65270138135273 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 4925780
# Identified incorrectly: 1283525
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853971 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777876 , Hits: 1773299
# Number of clusters where tid already exists, that are accounted for: 777876
# Correctly associated out of all hits:  79.32900703057749 %
# Correctly associated out of all hits in clusters:  79.32900703057749 %
# Incorrectly associated out of all hits:  20.670992969422503 %
# Incorrectly associated out of all hits in clusters:  20.670992969422503 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 4930645
# Identified incorrectly: 1284808
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2855862 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780070 , Hits: 1779507
# Number of clusters where tid already exists, that are accounted for: 780070
# Correctly associated out of all hits:  79.32881159265463 %
# Correctly associated out of all hits in clusters:  79.32881159265463 %
# Incorrectly associated out of all hits:  20.67118840734537 %
# Incorrectly associated out of all hits in clusters:  20.67118840734537 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 4926225
# Identified incorrectly: 1285506
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854687 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775510 , Hits: 1771260
# Number of clusters where tid already exists, that are accounted for: 775510
# Correctly associated out of all hits:  79.30518884349628 %
# Correctly associated out of all hits in clusters:  79.30518884349628 %
# Incorrectly associated out of all hits:  20.694811156503718 %
# Incorrectly associated out of all hits in clusters:  20.694811156503718 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 4919659
# Identified incorrectly: 1282034
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851134 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776610 , Hits: 1772230
# Number of clusters where tid already exists, that are accounted for: 776610
# Correctly associated out of all hits:  79.32767713590466 %
# Correctly associated out of all hits in clusters:  79.32767713590466 %
# Incorrectly associated out of all hits:  20.672322864095335 %
# Incorrectly associated out of all hits in clusters:  20.672322864095335 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 4922470
# Identified incorrectly: 1280920
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852490 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779800 , Hits: 1778665
# Number of clusters where tid already exists, that are accounted for: 779800
# Correctly associated out of all hits:  79.35129018165874 %
# Correctly associated out of all hits in clusters:  79.35129018165874 %
# Incorrectly associated out of all hits:  20.64870981834126 %
# Incorrectly associated out of all hits in clusters:  20.64870981834126 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 4927730
# Identified incorrectly: 1284743
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854313 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778104 , Hits: 1775849
# Number of clusters where tid already exists, that are accounted for: 778104
# Correctly associated out of all hits:  79.31994231604709 %
# Correctly associated out of all hits in clusters:  79.31994231604709 %
# Incorrectly associated out of all hits:  20.68005768395291 %
# Incorrectly associated out of all hits in clusters:  20.68005768395291 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 4922022
# Identified incorrectly: 1282469
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853253 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777476 , Hits: 1769731
# Number of clusters where tid already exists, that are accounted for: 777476
# Correctly associated out of all hits:  79.32998855184091 %
# Correctly associated out of all hits in clusters:  79.32998855184091 %
# Incorrectly associated out of all hits:  20.670011448159084 %
# Incorrectly associated out of all hits in clusters:  20.670011448159084 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_time_20.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 4921335
# Identified incorrectly: 1283665
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852292 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775582 , Hits: 1765975
# Number of clusters where tid already exists, that are accounted for: 775582
# Correctly associated out of all hits:  79.31240934730056 %
# Correctly associated out of all hits in clusters:  79.31240934730056 %
# Incorrectly associated out of all hits:  20.687590652699434 %
# Incorrectly associated out of all hits in clusters:  20.687590652699434 %

# %% [markdown]
# ### Threshold: 25mm

# %%
current_threshold = threshold_cluster_width_used[1] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_time_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_time_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_155_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 4909888
# Identified incorrectly: 1295768
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852341 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775738 , Hits: 1770392
# Number of clusters where tid already exists, that are accounted for: 775738
# Correctly associated out of all hits:  79.1195644747308 %
# Correctly associated out of all hits in clusters:  79.1195644747308 %
# Incorrectly associated out of all hits:  20.880435525269206 %
# Incorrectly associated out of all hits in clusters:  20.880435525269206 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 4905919
# Identified incorrectly: 1289271
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849276 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1770795
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  79.18916126866165 %
# Correctly associated out of all hits in clusters:  79.18916126866165 %
# Incorrectly associated out of all hits:  20.810838731338343 %
# Incorrectly associated out of all hits in clusters:  20.810838731338343 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 4912003
# Identified incorrectly: 1295838
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852724 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778818 , Hits: 1773877
# Number of clusters where tid already exists, that are accounted for: 778818
# Correctly associated out of all hits:  79.12578624355875 %
# Correctly associated out of all hits in clusters:  79.12578624355875 %
# Incorrectly associated out of all hits:  20.874213756441247 %
# Incorrectly associated out of all hits in clusters:  20.874213756441247 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 4918886
# Identified incorrectly: 1296567
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2855862 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780070 , Hits: 1779507
# Number of clusters where tid already exists, that are accounted for: 780070
# Correctly associated out of all hits:  79.139621842527 %
# Correctly associated out of all hits in clusters:  79.139621842527 %
# Incorrectly associated out of all hits:  20.860378157472997 %
# Incorrectly associated out of all hits in clusters:  20.860378157472997 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 4914421
# Identified incorrectly: 1295875
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853312 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776614 , Hits: 1772046
# Number of clusters where tid already exists, that are accounted for: 776614
# Correctly associated out of all hits:  79.13344227070658 %
# Correctly associated out of all hits in clusters:  79.13344227070658 %
# Incorrectly associated out of all hits:  20.86655772929342 %
# Incorrectly associated out of all hits in clusters:  20.86655772929342 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 4909705
# Identified incorrectly: 1295295
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852292 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775582 , Hits: 1765975
# Number of clusters where tid already exists, that are accounted for: 775582
# Correctly associated out of all hits:  79.12497985495568 %
# Correctly associated out of all hits in clusters:  79.12497985495568 %
# Incorrectly associated out of all hits:  20.87502014504432 %
# Incorrectly associated out of all hits in clusters:  20.87502014504432 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 4907983
# Identified incorrectly: 1293710
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851134 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776610 , Hits: 1772230
# Number of clusters where tid already exists, that are accounted for: 776610
# Correctly associated out of all hits:  79.13940596543557 %
# Correctly associated out of all hits in clusters:  79.13940596543557 %
# Incorrectly associated out of all hits:  20.860594034564432 %
# Incorrectly associated out of all hits in clusters:  20.860594034564432 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 4913414
# Identified incorrectly: 1298497
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853370 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777968 , Hits: 1774985
# Number of clusters where tid already exists, that are accounted for: 777968
# Correctly associated out of all hits:  79.09665801715447 %
# Correctly associated out of all hits in clusters:  79.09665801715447 %
# Incorrectly associated out of all hits:  20.903341982845536 %
# Incorrectly associated out of all hits in clusters:  20.903341982845536 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 4907916
# Identified incorrectly: 1293111
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851057 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775822 , Hits: 1769624
# Number of clusters where tid already exists, that are accounted for: 775822
# Correctly associated out of all hits:  79.14682519524588 %
# Correctly associated out of all hits in clusters:  79.14682519524588 %
# Incorrectly associated out of all hits:  20.85317480475412 %
# Incorrectly associated out of all hits in clusters:  20.85317480475412 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 4905874
# Identified incorrectly: 1294093
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850023 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774764 , Hits: 1768161
# Number of clusters where tid already exists, that are accounted for: 774764
# Correctly associated out of all hits:  79.12742116208038 %
# Correctly associated out of all hits in clusters:  79.12742116208038 %
# Incorrectly associated out of all hits:  20.872578837919622 %
# Incorrectly associated out of all hits in clusters:  20.872578837919622 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 4915610
# Identified incorrectly: 1295702
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854136 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777484 , Hits: 1778667
# Number of clusters where tid already exists, that are accounted for: 777484
# Correctly associated out of all hits:  79.1396407071485 %
# Correctly associated out of all hits in clusters:  79.1396407071485 %
# Incorrectly associated out of all hits:  20.860359292851495 %
# Incorrectly associated out of all hits in clusters:  20.860359292851495 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 4911654
# Identified incorrectly: 1293492
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852758 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779448 , Hits: 1779911
# Number of clusters where tid already exists, that are accounted for: 779448
# Correctly associated out of all hits:  79.15452754858629 %
# Correctly associated out of all hits in clusters:  79.15452754858629 %
# Incorrectly associated out of all hits:  20.845472451413713 %
# Incorrectly associated out of all hits in clusters:  20.845472451413713 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 4915033
# Identified incorrectly: 1296698
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854687 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775510 , Hits: 1771260
# Number of clusters where tid already exists, that are accounted for: 775510
# Correctly associated out of all hits:  79.12501362341673 %
# Correctly associated out of all hits in clusters:  79.12501362341673 %
# Incorrectly associated out of all hits:  20.874986376583276 %
# Incorrectly associated out of all hits in clusters:  20.874986376583276 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 4915098
# Identified incorrectly: 1293715
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853286 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776572 , Hits: 1772828
# Number of clusters where tid already exists, that are accounted for: 776572
# Correctly associated out of all hits:  79.1632474677527 %
# Correctly associated out of all hits in clusters:  79.1632474677527 %
# Incorrectly associated out of all hits:  20.836752532247306 %
# Incorrectly associated out of all hits in clusters:  20.836752532247306 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 4911001
# Identified incorrectly: 1292389
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852490 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779800 , Hits: 1778665
# Number of clusters where tid already exists, that are accounted for: 779800
# Correctly associated out of all hits:  79.16640739982493 %
# Correctly associated out of all hits in clusters:  79.16640739982493 %
# Incorrectly associated out of all hits:  20.833592600175066 %
# Incorrectly associated out of all hits in clusters:  20.833592600175066 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 4920686
# Identified incorrectly: 1300664
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2858288 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780384 , Hits: 1780066
# Number of clusters where tid already exists, that are accounted for: 780384
# Correctly associated out of all hits:  79.09354079098588 %
# Correctly associated out of all hits in clusters:  79.09354079098588 %
# Incorrectly associated out of all hits:  20.90645920901412 %
# Incorrectly associated out of all hits in clusters:  20.90645920901412 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 4909561
# Identified incorrectly: 1293855
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852932 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776948 , Hits: 1770756
# Number of clusters where tid already exists, that are accounted for: 776948
# Correctly associated out of all hits:  79.14286257765076 %
# Correctly associated out of all hits in clusters:  79.14286257765076 %
# Incorrectly associated out of all hits:  20.857137422349233 %
# Incorrectly associated out of all hits in clusters:  20.857137422349233 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 4915034
# Identified incorrectly: 1292393
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853451 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776620 , Hits: 1771891
# Number of clusters where tid already exists, that are accounted for: 776620
# Correctly associated out of all hits:  79.17989208733346 %
# Correctly associated out of all hits in clusters:  79.17989208733346 %
# Incorrectly associated out of all hits:  20.820107912666554 %
# Incorrectly associated out of all hits in clusters:  20.820107912666554 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 4911919
# Identified incorrectly: 1294149
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853897 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1769685
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  79.14703802794297 %
# Correctly associated out of all hits in clusters:  79.14703802794297 %
# Incorrectly associated out of all hits:  20.852961972057024 %
# Incorrectly associated out of all hits in clusters:  20.852961972057024 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 4910669
# Identified incorrectly: 1294807
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851549 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774790 , Hits: 1767180
# Number of clusters where tid already exists, that are accounted for: 774790
# Correctly associated out of all hits:  79.13444512556329 %
# Correctly associated out of all hits in clusters:  79.13444512556329 %
# Incorrectly associated out of all hits:  20.865554874436707 %
# Incorrectly associated out of all hits in clusters:  20.865554874436707 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 4908607
# Identified incorrectly: 1292054
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850481 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776280 , Hits: 1770358
# Number of clusters where tid already exists, that are accounted for: 776280
# Correctly associated out of all hits:  79.1626408861894 %
# Correctly associated out of all hits in clusters:  79.1626408861894 %
# Incorrectly associated out of all hits:  20.837359113810606 %
# Incorrectly associated out of all hits in clusters:  20.837359113810606 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 4911763
# Identified incorrectly: 1298241
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853339 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777218 , Hits: 1773266
# Number of clusters where tid already exists, that are accounted for: 777218
# Correctly associated out of all hits:  79.09436129187678 %
# Correctly associated out of all hits in clusters:  79.09436129187678 %
# Incorrectly associated out of all hits:  20.905638708123217 %
# Incorrectly associated out of all hits in clusters:  20.905638708123217 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 4915901
# Identified incorrectly: 1296572
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854313 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778104 , Hits: 1775849
# Number of clusters where tid already exists, that are accounted for: 778104
# Correctly associated out of all hits:  79.12953504989076 %
# Correctly associated out of all hits in clusters:  79.12953504989076 %
# Incorrectly associated out of all hits:  20.870464950109238 %
# Incorrectly associated out of all hits in clusters:  20.870464950109238 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 4914042
# Identified incorrectly: 1295263
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853971 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777876 , Hits: 1773299
# Number of clusters where tid already exists, that are accounted for: 777876
# Correctly associated out of all hits:  79.13996816068787 %
# Correctly associated out of all hits in clusters:  79.13996816068787 %
# Incorrectly associated out of all hits:  20.86003183931213 %
# Incorrectly associated out of all hits in clusters:  20.86003183931213 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 4910084
# Identified incorrectly: 1294407
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853253 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777476 , Hits: 1769731
# Number of clusters where tid already exists, that are accounted for: 777476
# Correctly associated out of all hits:  79.13757953714494 %
# Correctly associated out of all hits in clusters:  79.13757953714494 %
# Incorrectly associated out of all hits:  20.86242046285505 %
# Incorrectly associated out of all hits in clusters:  20.86242046285505 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 4909909
# Identified incorrectly: 1293126
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851068 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777698 , Hits: 1774621
# Number of clusters where tid already exists, that are accounted for: 777698
# Correctly associated out of all hits:  79.15333381159384 %
# Correctly associated out of all hits in clusters:  79.15333381159384 %
# Incorrectly associated out of all hits:  20.84666618840616 %
# Incorrectly associated out of all hits in clusters:  20.84666618840616 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 4921853
# Identified incorrectly: 1295739
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854944 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780552 , Hits: 1786781
# Number of clusters where tid already exists, that are accounted for: 780552
# Correctly associated out of all hits:  79.1601153629894 %
# Correctly associated out of all hits in clusters:  79.1601153629894 %
# Incorrectly associated out of all hits:  20.8398846370106 %
# Incorrectly associated out of all hits in clusters:  20.8398846370106 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 4903633
# Identified incorrectly: 1293470
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849479 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774668 , Hits: 1765073
# Number of clusters where tid already exists, that are accounted for: 774668
# Correctly associated out of all hits:  79.12782795444905 %
# Correctly associated out of all hits in clusters:  79.12782795444905 %
# Incorrectly associated out of all hits:  20.87217204555096 %
# Incorrectly associated out of all hits in clusters:  20.87217204555096 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_time_25.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 4913938
# Identified incorrectly: 1294039
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852275 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775636 , Hits: 1773201
# Number of clusters where tid already exists, that are accounted for: 775636
# Correctly associated out of all hits:  79.15522238564995 %
# Correctly associated out of all hits in clusters:  79.15522238564995 %
# Incorrectly associated out of all hits:  20.844777614350054 %
# Incorrectly associated out of all hits in clusters:  20.844777614350054 %

# %% [markdown]
# ### Threshold: 30mm

# %%
current_threshold = threshold_cluster_width_used[2] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_time_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_time_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_127_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 4906835
# Identified incorrectly: 1310757
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854944 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780552 , Hits: 1786781
# Number of clusters where tid already exists, that are accounted for: 780552
# Correctly associated out of all hits:  78.91857490809947 %
# Correctly associated out of all hits in clusters:  78.91857490809947 %
# Incorrectly associated out of all hits:  21.08142509190053 %
# Incorrectly associated out of all hits in clusters:  21.08142509190053 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 4895269
# Identified incorrectly: 1309222
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853253 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777476 , Hits: 1769731
# Number of clusters where tid already exists, that are accounted for: 777476
# Correctly associated out of all hits:  78.89880088471399 %
# Correctly associated out of all hits in clusters:  78.89880088471399 %
# Incorrectly associated out of all hits:  21.101199115286008 %
# Incorrectly associated out of all hits in clusters:  21.101199115286008 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 4900981
# Identified incorrectly: 1310331
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854136 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777484 , Hits: 1778667
# Number of clusters where tid already exists, that are accounted for: 777484
# Correctly associated out of all hits:  78.90411880774947 %
# Correctly associated out of all hits in clusters:  78.90411880774947 %
# Incorrectly associated out of all hits:  21.095881192250527 %
# Incorrectly associated out of all hits in clusters:  21.095881192250527 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 4899995
# Identified incorrectly: 1308818
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853286 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776572 , Hits: 1772828
# Number of clusters where tid already exists, that are accounted for: 776572
# Correctly associated out of all hits:  78.91999646309206 %
# Correctly associated out of all hits in clusters:  78.91999646309206 %
# Incorrectly associated out of all hits:  21.08000353690794 %
# Incorrectly associated out of all hits in clusters:  21.08000353690794 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 4905361
# Identified incorrectly: 1315989
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2858288 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780384 , Hits: 1780066
# Number of clusters where tid already exists, that are accounted for: 780384
# Correctly associated out of all hits:  78.84721161805717 %
# Correctly associated out of all hits in clusters:  78.84721161805717 %
# Incorrectly associated out of all hits:  21.152788381942827 %
# Incorrectly associated out of all hits in clusters:  21.152788381942827 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 4894219
# Identified incorrectly: 1311437
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852341 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775738 , Hits: 1770392
# Number of clusters where tid already exists, that are accounted for: 775738
# Correctly associated out of all hits:  78.86706900930378 %
# Correctly associated out of all hits in clusters:  78.86706900930378 %
# Incorrectly associated out of all hits:  21.13293099069623 %
# Incorrectly associated out of all hits in clusters:  21.13293099069623 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 4899020
# Identified incorrectly: 1311276
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853312 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776614 , Hits: 1772046
# Number of clusters where tid already exists, that are accounted for: 776614
# Correctly associated out of all hits:  78.88545087061873 %
# Correctly associated out of all hits in clusters:  78.88545087061873 %
# Incorrectly associated out of all hits:  21.114549129381274 %
# Incorrectly associated out of all hits in clusters:  21.114549129381274 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 4895307
# Identified incorrectly: 1307728
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851068 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777698 , Hits: 1774621
# Number of clusters where tid already exists, that are accounted for: 777698
# Correctly associated out of all hits:  78.91793291509721 %
# Correctly associated out of all hits in clusters:  78.91793291509721 %
# Incorrectly associated out of all hits:  21.082067084902793 %
# Incorrectly associated out of all hits in clusters:  21.082067084902793 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 4896026
# Identified incorrectly: 1313978
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853339 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777218 , Hits: 1773266
# Number of clusters where tid already exists, that are accounted for: 777218
# Correctly associated out of all hits:  78.84094760647497 %
# Correctly associated out of all hits in clusters:  78.84094760647497 %
# Incorrectly associated out of all hits:  21.159052393525027 %
# Incorrectly associated out of all hits in clusters:  21.159052393525027 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 4895481
# Identified incorrectly: 1309995
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851549 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774790 , Hits: 1767180
# Number of clusters where tid already exists, that are accounted for: 774790
# Correctly associated out of all hits:  78.8896935545315 %
# Correctly associated out of all hits in clusters:  78.8896935545315 %
# Incorrectly associated out of all hits:  21.110306445468485 %
# Incorrectly associated out of all hits in clusters:  21.110306445468485 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 4888577
# Identified incorrectly: 1308526
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849479 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774668 , Hits: 1765073
# Number of clusters where tid already exists, that are accounted for: 774668
# Correctly associated out of all hits:  78.88487572338236 %
# Correctly associated out of all hits in clusters:  78.88487572338236 %
# Incorrectly associated out of all hits:  21.11512427661764 %
# Incorrectly associated out of all hits in clusters:  21.11512427661764 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 4900174
# Identified incorrectly: 1307253
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853451 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776620 , Hits: 1771891
# Number of clusters where tid already exists, that are accounted for: 776620
# Correctly associated out of all hits:  78.9405014348135 %
# Correctly associated out of all hits in clusters:  78.9405014348135 %
# Incorrectly associated out of all hits:  21.059498565186512 %
# Incorrectly associated out of all hits in clusters:  21.059498565186512 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 4904112
# Identified incorrectly: 1311341
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2855862 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780070 , Hits: 1779507
# Number of clusters where tid already exists, that are accounted for: 780070
# Correctly associated out of all hits:  78.90192396274254 %
# Correctly associated out of all hits in clusters:  78.90192396274254 %
# Incorrectly associated out of all hits:  21.09807603725746 %
# Incorrectly associated out of all hits in clusters:  21.09807603725746 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 4896930
# Identified incorrectly: 1308216
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852758 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779448 , Hits: 1779911
# Number of clusters where tid already exists, that are accounted for: 779448
# Correctly associated out of all hits:  78.91724062576449 %
# Correctly associated out of all hits in clusters:  78.91724062576449 %
# Incorrectly associated out of all hits:  21.082759374235515 %
# Incorrectly associated out of all hits in clusters:  21.082759374235515 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 4896857
# Identified incorrectly: 1310984
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852724 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778818 , Hits: 1773877
# Number of clusters where tid already exists, that are accounted for: 778818
# Correctly associated out of all hits:  78.88180447920621 %
# Correctly associated out of all hits in clusters:  78.88180447920621 %
# Incorrectly associated out of all hits:  21.118195520793783 %
# Incorrectly associated out of all hits in clusters:  21.118195520793783 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 4898338
# Identified incorrectly: 1313573
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853370 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777968 , Hits: 1774985
# Number of clusters where tid already exists, that are accounted for: 777968
# Correctly associated out of all hits:  78.85396297532273 %
# Correctly associated out of all hits in clusters:  78.85396297532273 %
# Incorrectly associated out of all hits:  21.14603702467727 %
# Incorrectly associated out of all hits in clusters:  21.14603702467727 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 4890494
# Identified incorrectly: 1309473
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850023 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774764 , Hits: 1768161
# Number of clusters where tid already exists, that are accounted for: 774764
# Correctly associated out of all hits:  78.87935532560093 %
# Correctly associated out of all hits in clusters:  78.87935532560093 %
# Incorrectly associated out of all hits:  21.120644674399074 %
# Incorrectly associated out of all hits in clusters:  21.120644674399074 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 4894641
# Identified incorrectly: 1310359
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852292 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775582 , Hits: 1765975
# Number of clusters where tid already exists, that are accounted for: 775582
# Correctly associated out of all hits:  78.88220789685737 %
# Correctly associated out of all hits in clusters:  78.88220789685737 %
# Incorrectly associated out of all hits:  21.117792103142627 %
# Incorrectly associated out of all hits in clusters:  21.117792103142627 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 4898998
# Identified incorrectly: 1308979
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852275 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775636 , Hits: 1773201
# Number of clusters where tid already exists, that are accounted for: 775636
# Correctly associated out of all hits:  78.91456427754163 %
# Correctly associated out of all hits in clusters:  78.91456427754163 %
# Incorrectly associated out of all hits:  21.08543572245838 %
# Incorrectly associated out of all hits in clusters:  21.08543572245838 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 4900533
# Identified incorrectly: 1311940
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854313 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778104 , Hits: 1775849
# Number of clusters where tid already exists, that are accounted for: 778104
# Correctly associated out of all hits:  78.88216174138704 %
# Correctly associated out of all hits in clusters:  78.88216174138704 %
# Incorrectly associated out of all hits:  21.117838258612952 %
# Incorrectly associated out of all hits in clusters:  21.117838258612952 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 4891189
# Identified incorrectly: 1304001
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849276 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1770795
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  78.95139616379804 %
# Correctly associated out of all hits in clusters:  78.95139616379804 %
# Incorrectly associated out of all hits:  21.048603836201956 %
# Incorrectly associated out of all hits in clusters:  21.048603836201956 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 4900389
# Identified incorrectly: 1311342
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854687 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775510 , Hits: 1771260
# Number of clusters where tid already exists, that are accounted for: 775510
# Correctly associated out of all hits:  78.88926613209748 %
# Correctly associated out of all hits in clusters:  78.88926613209748 %
# Incorrectly associated out of all hits:  21.11073386790252 %
# Incorrectly associated out of all hits in clusters:  21.11073386790252 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 4897123
# Identified incorrectly: 1308945
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853897 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1769685
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  78.90862620261332 %
# Correctly associated out of all hits in clusters:  78.90862620261332 %
# Incorrectly associated out of all hits:  21.091373797386687 %
# Incorrectly associated out of all hits in clusters:  21.091373797386687 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 4894649
# Identified incorrectly: 1308767
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852932 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776948 , Hits: 1770756
# Number of clusters where tid already exists, that are accounted for: 776948
# Correctly associated out of all hits:  78.90247889227483 %
# Correctly associated out of all hits in clusters:  78.90247889227483 %
# Incorrectly associated out of all hits:  21.09752110772516 %
# Incorrectly associated out of all hits in clusters:  21.09752110772516 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 4893014
# Identified incorrectly: 1308013
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851057 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775822 , Hits: 1769624
# Number of clusters where tid already exists, that are accounted for: 775822
# Correctly associated out of all hits:  78.9065101635584 %
# Correctly associated out of all hits in clusters:  78.9065101635584 %
# Incorrectly associated out of all hits:  21.09348983644161 %
# Incorrectly associated out of all hits in clusters:  21.09348983644161 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 4893203
# Identified incorrectly: 1307458
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850481 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776280 , Hits: 1770358
# Number of clusters where tid already exists, that are accounted for: 776280
# Correctly associated out of all hits:  78.91421575861025 %
# Correctly associated out of all hits in clusters:  78.91421575861025 %
# Incorrectly associated out of all hits:  21.08578424138975 %
# Incorrectly associated out of all hits in clusters:  21.08578424138975 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 4898618
# Identified incorrectly: 1310687
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853971 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777876 , Hits: 1773299
# Number of clusters where tid already exists, that are accounted for: 777876
# Correctly associated out of all hits:  78.89156676954988 %
# Correctly associated out of all hits in clusters:  78.89156676954988 %
# Incorrectly associated out of all hits:  21.108433230450107 %
# Incorrectly associated out of all hits in clusters:  21.108433230450107 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 4896089
# Identified incorrectly: 1307301
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852490 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779800 , Hits: 1778665
# Number of clusters where tid already exists, that are accounted for: 779800
# Correctly associated out of all hits:  78.92602270693926 %
# Correctly associated out of all hits in clusters:  78.92602270693926 %
# Incorrectly associated out of all hits:  21.07397729306073 %
# Incorrectly associated out of all hits in clusters:  21.07397729306073 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_time_30.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 4892895
# Identified incorrectly: 1308798
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851134 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776610 , Hits: 1772230
# Number of clusters where tid already exists, that are accounted for: 776610
# Correctly associated out of all hits:  78.89611756015655 %
# Correctly associated out of all hits in clusters:  78.89611756015655 %
# Incorrectly associated out of all hits:  21.103882439843442 %
# Incorrectly associated out of all hits in clusters:  21.103882439843442 %

# %% [markdown]
# ### Threshold: 35mm

# %%
current_threshold = threshold_cluster_width_used[3] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_time_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_time_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_153_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 4877633
# Identified incorrectly: 1317557
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849276 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1770795
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  78.73258124448161 %
# Correctly associated out of all hits in clusters:  78.73258124448161 %
# Incorrectly associated out of all hits:  21.267418755518392 %
# Incorrectly associated out of all hits in clusters:  21.267418755518392 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 4891871
# Identified incorrectly: 1329479
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2858288 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780384 , Hits: 1780066
# Number of clusters where tid already exists, that are accounted for: 780384
# Correctly associated out of all hits:  78.63037765115288 %
# Correctly associated out of all hits in clusters:  78.63037765115288 %
# Incorrectly associated out of all hits:  21.369622348847116 %
# Incorrectly associated out of all hits in clusters:  21.369622348847116 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 4883091
# Identified incorrectly: 1322055
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852758 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779448 , Hits: 1779911
# Number of clusters where tid already exists, that are accounted for: 779448
# Correctly associated out of all hits:  78.69421605873576 %
# Correctly associated out of all hits in clusters:  78.69421605873576 %
# Incorrectly associated out of all hits:  21.305783941264234 %
# Incorrectly associated out of all hits in clusters:  21.305783941264234 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 4885192
# Identified incorrectly: 1325104
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853312 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776614 , Hits: 1772046
# Number of clusters where tid already exists, that are accounted for: 776614
# Correctly associated out of all hits:  78.6627883759486 %
# Correctly associated out of all hits in clusters:  78.6627883759486 %
# Incorrectly associated out of all hits:  21.337211624051413 %
# Incorrectly associated out of all hits in clusters:  21.337211624051413 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 4893282
# Identified incorrectly: 1324310
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854944 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780552 , Hits: 1786781
# Number of clusters where tid already exists, that are accounted for: 780552
# Correctly associated out of all hits:  78.70059662969201 %
# Correctly associated out of all hits in clusters:  78.70059662969201 %
# Incorrectly associated out of all hits:  21.299403370307992 %
# Incorrectly associated out of all hits in clusters:  21.299403370307992 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 4880941
# Identified incorrectly: 1322475
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852932 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776948 , Hits: 1770756
# Number of clusters where tid already exists, that are accounted for: 776948
# Correctly associated out of all hits:  78.68150386819133 %
# Correctly associated out of all hits in clusters:  78.68150386819133 %
# Incorrectly associated out of all hits:  21.31849613180867 %
# Incorrectly associated out of all hits in clusters:  21.31849613180867 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 4882269
# Identified incorrectly: 1321121
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852490 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779800 , Hits: 1778665
# Number of clusters where tid already exists, that are accounted for: 779800
# Correctly associated out of all hits:  78.70324129226117 %
# Correctly associated out of all hits in clusters:  78.70324129226117 %
# Incorrectly associated out of all hits:  21.29675870773883 %
# Incorrectly associated out of all hits in clusters:  21.29675870773883 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 4884346
# Identified incorrectly: 1327565
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853370 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777968 , Hits: 1774985
# Number of clusters where tid already exists, that are accounted for: 777968
# Correctly associated out of all hits:  78.62871828009126 %
# Correctly associated out of all hits in clusters:  78.62871828009126 %
# Incorrectly associated out of all hits:  21.371281719908737 %
# Incorrectly associated out of all hits in clusters:  21.371281719908737 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 4876928
# Identified incorrectly: 1323039
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850023 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774764 , Hits: 1768161
# Number of clusters where tid already exists, that are accounted for: 774764
# Correctly associated out of all hits:  78.66054770936684 %
# Correctly associated out of all hits in clusters:  78.66054770936684 %
# Incorrectly associated out of all hits:  21.33945229063316 %
# Incorrectly associated out of all hits in clusters:  21.33945229063316 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 4882176
# Identified incorrectly: 1327828
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853339 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777218 , Hits: 1773266
# Number of clusters where tid already exists, that are accounted for: 777218
# Correctly associated out of all hits:  78.61792037493052 %
# Correctly associated out of all hits in clusters:  78.61792037493052 %
# Incorrectly associated out of all hits:  21.382079625069483 %
# Incorrectly associated out of all hits in clusters:  21.382079625069483 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 4881045
# Identified incorrectly: 1324611
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852341 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775738 , Hits: 1770392
# Number of clusters where tid already exists, that are accounted for: 775738
# Correctly associated out of all hits:  78.65477880178986 %
# Correctly associated out of all hits in clusters:  78.65477880178986 %
# Incorrectly associated out of all hits:  21.34522119821015 %
# Incorrectly associated out of all hits in clusters:  21.34522119821015 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 4881558
# Identified incorrectly: 1323918
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851549 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774790 , Hits: 1767180
# Number of clusters where tid already exists, that are accounted for: 774790
# Correctly associated out of all hits:  78.66532720455288 %
# Correctly associated out of all hits in clusters:  78.66532720455288 %
# Incorrectly associated out of all hits:  21.334672795447116 %
# Incorrectly associated out of all hits in clusters:  21.334672795447116 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 4879799
# Identified incorrectly: 1321228
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851057 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775822 , Hits: 1769624
# Number of clusters where tid already exists, that are accounted for: 775822
# Correctly associated out of all hits:  78.69340030288532 %
# Correctly associated out of all hits in clusters:  78.69340030288532 %
# Incorrectly associated out of all hits:  21.306599697114688 %
# Incorrectly associated out of all hits in clusters:  21.306599697114688 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 4890149
# Identified incorrectly: 1325304
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2855862 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780070 , Hits: 1779507
# Number of clusters where tid already exists, that are accounted for: 780070
# Correctly associated out of all hits:  78.67727420672315 %
# Correctly associated out of all hits in clusters:  78.67727420672315 %
# Incorrectly associated out of all hits:  21.322725793276852 %
# Incorrectly associated out of all hits in clusters:  21.322725793276852 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 4886807
# Identified incorrectly: 1324924
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854687 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775510 , Hits: 1771260
# Number of clusters where tid already exists, that are accounted for: 775510
# Correctly associated out of all hits:  78.67061532445626 %
# Correctly associated out of all hits in clusters:  78.67061532445626 %
# Incorrectly associated out of all hits:  21.329384675543743 %
# Incorrectly associated out of all hits in clusters:  21.329384675543743 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 4887504
# Identified incorrectly: 1323808
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854136 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777484 , Hits: 1778667
# Number of clusters where tid already exists, that are accounted for: 777484
# Correctly associated out of all hits:  78.68714371456466 %
# Correctly associated out of all hits in clusters:  78.68714371456466 %
# Incorrectly associated out of all hits:  21.31285628543535 %
# Incorrectly associated out of all hits in clusters:  21.31285628543535 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 4881313
# Identified incorrectly: 1323687
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852292 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775582 , Hits: 1765975
# Number of clusters where tid already exists, that are accounted for: 775582
# Correctly associated out of all hits:  78.66741337630943 %
# Correctly associated out of all hits in clusters:  78.66741337630943 %
# Incorrectly associated out of all hits:  21.33258662369057 %
# Incorrectly associated out of all hits in clusters:  21.33258662369057 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 4875223
# Identified incorrectly: 1321880
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849479 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774668 , Hits: 1765073
# Number of clusters where tid already exists, that are accounted for: 774668
# Correctly associated out of all hits:  78.66938793820275 %
# Correctly associated out of all hits in clusters:  78.66938793820275 %
# Incorrectly associated out of all hits:  21.33061206179726 %
# Incorrectly associated out of all hits in clusters:  21.33061206179726 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 4881515
# Identified incorrectly: 1321520
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851068 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777698 , Hits: 1774621
# Number of clusters where tid already exists, that are accounted for: 777698
# Correctly associated out of all hits:  78.69559014256731 %
# Correctly associated out of all hits in clusters:  78.69559014256731 %
# Incorrectly associated out of all hits:  21.30440985743269 %
# Incorrectly associated out of all hits in clusters:  21.30440985743269 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 4885308
# Identified incorrectly: 1323997
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853971 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777876 , Hits: 1773299
# Number of clusters where tid already exists, that are accounted for: 777876
# Correctly associated out of all hits:  78.67721105663193 %
# Correctly associated out of all hits in clusters:  78.67721105663193 %
# Incorrectly associated out of all hits:  21.322788943368057 %
# Incorrectly associated out of all hits in clusters:  21.322788943368057 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 4886157
# Identified incorrectly: 1322656
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853286 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776572 , Hits: 1772828
# Number of clusters where tid already exists, that are accounted for: 776572
# Correctly associated out of all hits:  78.69711972320636 %
# Correctly associated out of all hits in clusters:  78.69711972320636 %
# Incorrectly associated out of all hits:  21.302880276793648 %
# Incorrectly associated out of all hits in clusters:  21.302880276793648 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 4879456
# Identified incorrectly: 1322237
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851134 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776610 , Hits: 1772230
# Number of clusters where tid already exists, that are accounted for: 776610
# Correctly associated out of all hits:  78.67941866841845 %
# Correctly associated out of all hits in clusters:  78.67941866841845 %
# Incorrectly associated out of all hits:  21.320581331581554 %
# Incorrectly associated out of all hits in clusters:  21.320581331581554 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 4885182
# Identified incorrectly: 1322795
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852275 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775636 , Hits: 1773201
# Number of clusters where tid already exists, that are accounted for: 775636
# Correctly associated out of all hits:  78.69201190661629 %
# Correctly associated out of all hits in clusters:  78.69201190661629 %
# Incorrectly associated out of all hits:  21.307988093383724 %
# Incorrectly associated out of all hits in clusters:  21.307988093383724 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 4881292
# Identified incorrectly: 1323199
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853253 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777476 , Hits: 1769731
# Number of clusters where tid already exists, that are accounted for: 777476
# Correctly associated out of all hits:  78.67352857792847 %
# Correctly associated out of all hits in clusters:  78.67352857792847 %
# Incorrectly associated out of all hits:  21.326471422071528 %
# Incorrectly associated out of all hits in clusters:  21.326471422071528 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 4879600
# Identified incorrectly: 1321061
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850481 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776280 , Hits: 1770358
# Number of clusters where tid already exists, that are accounted for: 776280
# Correctly associated out of all hits:  78.69483592152514 %
# Correctly associated out of all hits in clusters:  78.69483592152514 %
# Incorrectly associated out of all hits:  21.30516407847486 %
# Incorrectly associated out of all hits in clusters:  21.30516407847486 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 4887209
# Identified incorrectly: 1325264
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854313 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778104 , Hits: 1775849
# Number of clusters where tid already exists, that are accounted for: 778104
# Correctly associated out of all hits:  78.66768998432669 %
# Correctly associated out of all hits in clusters:  78.66768998432669 %
# Incorrectly associated out of all hits:  21.332310015673308 %
# Incorrectly associated out of all hits in clusters:  21.332310015673308 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 4883493
# Identified incorrectly: 1322575
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853897 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1769685
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  78.68900244083693 %
# Correctly associated out of all hits in clusters:  78.68900244083693 %
# Incorrectly associated out of all hits:  21.310997559163063 %
# Incorrectly associated out of all hits in clusters:  21.310997559163063 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 4883105
# Identified incorrectly: 1324736
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852724 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778818 , Hits: 1773877
# Number of clusters where tid already exists, that are accounted for: 778818
# Correctly associated out of all hits:  78.660278186893 %
# Correctly associated out of all hits in clusters:  78.660278186893 %
# Incorrectly associated out of all hits:  21.339721813107005 %
# Incorrectly associated out of all hits in clusters:  21.339721813107005 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_time_35.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 4886117
# Identified incorrectly: 1321310
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853451 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776620 , Hits: 1771891
# Number of clusters where tid already exists, that are accounted for: 776620
# Correctly associated out of all hits:  78.71404689898085 %
# Correctly associated out of all hits in clusters:  78.71404689898085 %
# Incorrectly associated out of all hits:  21.28595310101915 %
# Incorrectly associated out of all hits in clusters:  21.28595310101915 %

# %% [markdown]
# ### Threshold: 40mm

# %%
current_threshold = threshold_cluster_width_used[4] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_time_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_time_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_164_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 4865853
# Identified incorrectly: 1337563
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852932 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776948 , Hits: 1770756
# Number of clusters where tid already exists, that are accounted for: 776948
# Correctly associated out of all hits:  78.43828303631417 %
# Correctly associated out of all hits in clusters:  78.43828303631417 %
# Incorrectly associated out of all hits:  21.561716963685814 %
# Incorrectly associated out of all hits in clusters:  21.561716963685814 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 4876614
# Identified incorrectly: 1344736
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2858288 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780384 , Hits: 1780066
# Number of clusters where tid already exists, that are accounted for: 780384
# Correctly associated out of all hits:  78.38514148858367 %
# Correctly associated out of all hits in clusters:  78.38514148858367 %
# Incorrectly associated out of all hits:  21.614858511416333 %
# Incorrectly associated out of all hits in clusters:  21.614858511416333 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 4866327
# Identified incorrectly: 1336708
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851068 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777698 , Hits: 1774621
# Number of clusters where tid already exists, that are accounted for: 777698
# Correctly associated out of all hits:  78.45074225762066 %
# Correctly associated out of all hits in clusters:  78.45074225762066 %
# Incorrectly associated out of all hits:  21.549257742379336 %
# Incorrectly associated out of all hits in clusters:  21.549257742379336 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 4870848
# Identified incorrectly: 1336579
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853451 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776620 , Hits: 1771891
# Number of clusters where tid already exists, that are accounted for: 776620
# Correctly associated out of all hits:  78.46806736510958 %
# Correctly associated out of all hits in clusters:  78.46806736510958 %
# Incorrectly associated out of all hits:  21.53193263489043 %
# Incorrectly associated out of all hits in clusters:  21.53193263489043 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 4869522
# Identified incorrectly: 1340774
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853312 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776614 , Hits: 1772046
# Number of clusters where tid already exists, that are accounted for: 776614
# Correctly associated out of all hits:  78.41046545929534 %
# Correctly associated out of all hits in clusters:  78.41046545929534 %
# Incorrectly associated out of all hits:  21.589534540704662 %
# Incorrectly associated out of all hits in clusters:  21.589534540704662 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 4865700
# Identified incorrectly: 1339300
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852292 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775582 , Hits: 1765975
# Number of clusters where tid already exists, that are accounted for: 775582
# Correctly associated out of all hits:  78.41579371474617 %
# Correctly associated out of all hits in clusters:  78.41579371474617 %
# Incorrectly associated out of all hits:  21.584206285253828 %
# Incorrectly associated out of all hits in clusters:  21.584206285253828 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 4871667
# Identified incorrectly: 1340064
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854687 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775510 , Hits: 1771260
# Number of clusters where tid already exists, that are accounted for: 775510
# Correctly associated out of all hits:  78.42688294132505 %
# Correctly associated out of all hits in clusters:  78.42688294132505 %
# Incorrectly associated out of all hits:  21.57311705867495 %
# Incorrectly associated out of all hits in clusters:  21.57311705867495 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_135_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 4868237
# Identified incorrectly: 1337831
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853897 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1769685
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  78.4431785149631 %
# Correctly associated out of all hits in clusters:  78.4431785149631 %
# Incorrectly associated out of all hits:  21.556821485036902 %
# Incorrectly associated out of all hits in clusters:  21.556821485036902 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 4862538
# Identified incorrectly: 1332652
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849276 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1770795
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  78.48892447205009 %
# Correctly associated out of all hits in clusters:  78.48892447205009 %
# Incorrectly associated out of all hits:  21.51107552794991 %
# Incorrectly associated out of all hits in clusters:  21.51107552794991 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 4866034
# Identified incorrectly: 1339622
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852341 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775738 , Hits: 1770392
# Number of clusters where tid already exists, that are accounted for: 775738
# Correctly associated out of all hits:  78.41288656670625 %
# Correctly associated out of all hits in clusters:  78.41288656670625 %
# Incorrectly associated out of all hits:  21.58711343329376 %
# Incorrectly associated out of all hits in clusters:  21.58711343329376 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 4867634
# Identified incorrectly: 1337512
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852758 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779448 , Hits: 1779911
# Number of clusters where tid already exists, that are accounted for: 779448
# Correctly associated out of all hits:  78.44511635987291 %
# Correctly associated out of all hits in clusters:  78.44511635987291 %
# Incorrectly associated out of all hits:  21.55488364012708 %
# Incorrectly associated out of all hits in clusters:  21.55488364012708 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 4870659
# Identified incorrectly: 1338646
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853971 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777876 , Hits: 1773299
# Number of clusters where tid already exists, that are accounted for: 777876
# Correctly associated out of all hits:  78.44129093352637 %
# Correctly associated out of all hits in clusters:  78.44129093352637 %
# Incorrectly associated out of all hits:  21.55870906647362 %
# Incorrectly associated out of all hits in clusters:  21.55870906647362 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 4870824
# Identified incorrectly: 1337989
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853286 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776572 , Hits: 1772828
# Number of clusters where tid already exists, that are accounted for: 776572
# Correctly associated out of all hits:  78.45016430676846 %
# Correctly associated out of all hits in clusters:  78.45016430676846 %
# Incorrectly associated out of all hits:  21.54983569323154 %
# Incorrectly associated out of all hits in clusters:  21.54983569323154 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 4878044
# Identified incorrectly: 1339548
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854944 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780552 , Hits: 1786781
# Number of clusters where tid already exists, that are accounted for: 780552
# Correctly associated out of all hits:  78.45551782748048 %
# Correctly associated out of all hits in clusters:  78.45551782748048 %
# Incorrectly associated out of all hits:  21.544482172519523 %
# Incorrectly associated out of all hits in clusters:  21.544482172519523 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 4872179
# Identified incorrectly: 1339133
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854136 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777484 , Hits: 1778667
# Number of clusters where tid already exists, that are accounted for: 777484
# Correctly associated out of all hits:  78.44041645307786 %
# Correctly associated out of all hits in clusters:  78.44041645307786 %
# Incorrectly associated out of all hits:  21.55958354692213 %
# Incorrectly associated out of all hits in clusters:  21.55958354692213 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 4868199
# Identified incorrectly: 1339642
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852724 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778818 , Hits: 1773877
# Number of clusters where tid already exists, that are accounted for: 778818
# Correctly associated out of all hits:  78.42016250094034 %
# Correctly associated out of all hits in clusters:  78.42016250094034 %
# Incorrectly associated out of all hits:  21.579837499059657 %
# Incorrectly associated out of all hits in clusters:  21.579837499059657 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 4866587
# Identified incorrectly: 1338889
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851549 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774790 , Hits: 1767180
# Number of clusters where tid already exists, that are accounted for: 774790
# Correctly associated out of all hits:  78.42407254495868 %
# Correctly associated out of all hits in clusters:  78.42407254495868 %
# Incorrectly associated out of all hits:  21.57592745504132 %
# Incorrectly associated out of all hits in clusters:  21.57592745504132 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 4864679
# Identified incorrectly: 1336348
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851057 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775822 , Hits: 1769624
# Number of clusters where tid already exists, that are accounted for: 775822
# Correctly associated out of all hits:  78.44956972449887 %
# Correctly associated out of all hits in clusters:  78.44956972449887 %
# Incorrectly associated out of all hits:  21.55043027550114 %
# Incorrectly associated out of all hits in clusters:  21.55043027550114 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 4861478
# Identified incorrectly: 1338489
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850023 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774764 , Hits: 1768161
# Number of clusters where tid already exists, that are accounted for: 774764
# Correctly associated out of all hits:  78.41135283461993 %
# Correctly associated out of all hits in clusters:  78.41135283461993 %
# Incorrectly associated out of all hits:  21.588647165380074 %
# Incorrectly associated out of all hits in clusters:  21.588647165380074 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 4874850
# Identified incorrectly: 1340603
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2855862 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780070 , Hits: 1779507
# Number of clusters where tid already exists, that are accounted for: 780070
# Correctly associated out of all hits:  78.43112963769495 %
# Correctly associated out of all hits in clusters:  78.43112963769495 %
# Incorrectly associated out of all hits:  21.56887036230505 %
# Incorrectly associated out of all hits in clusters:  21.56887036230505 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 4867308
# Identified incorrectly: 1336082
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852490 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779800 , Hits: 1778665
# Number of clusters where tid already exists, that are accounted for: 779800
# Correctly associated out of all hits:  78.4620667086867 %
# Correctly associated out of all hits in clusters:  78.4620667086867 %
# Incorrectly associated out of all hits:  21.537933291313298 %
# Incorrectly associated out of all hits in clusters:  21.537933291313298 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 4870116
# Identified incorrectly: 1337861
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852275 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775636 , Hits: 1773201
# Number of clusters where tid already exists, that are accounted for: 775636
# Correctly associated out of all hits:  78.44932415181307 %
# Correctly associated out of all hits in clusters:  78.44932415181307 %
# Incorrectly associated out of all hits:  21.550675848186938 %
# Incorrectly associated out of all hits in clusters:  21.550675848186938 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 4869027
# Identified incorrectly: 1342884
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853370 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777968 , Hits: 1774985
# Number of clusters where tid already exists, that are accounted for: 777968
# Correctly associated out of all hits:  78.38211139856962 %
# Correctly associated out of all hits in clusters:  78.38211139856962 %
# Incorrectly associated out of all hits:  21.61788860143038 %
# Incorrectly associated out of all hits in clusters:  21.61788860143038 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 4864672
# Identified incorrectly: 1335989
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850481 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776280 , Hits: 1770358
# Number of clusters where tid already exists, that are accounted for: 776280
# Correctly associated out of all hits:  78.45408739487613 %
# Correctly associated out of all hits in clusters:  78.45408739487613 %
# Incorrectly associated out of all hits:  21.545912605123874 %
# Incorrectly associated out of all hits in clusters:  21.545912605123874 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 4867217
# Identified incorrectly: 1342787
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853339 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777218 , Hits: 1773266
# Number of clusters where tid already exists, that are accounted for: 777218
# Correctly associated out of all hits:  78.37703486181329 %
# Correctly associated out of all hits in clusters:  78.37703486181329 %
# Incorrectly associated out of all hits:  21.622965138186707 %
# Incorrectly associated out of all hits in clusters:  21.622965138186707 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 4871902
# Identified incorrectly: 1340571
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854313 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778104 , Hits: 1775849
# Number of clusters where tid already exists, that are accounted for: 778104
# Correctly associated out of all hits:  78.42129857143846 %
# Correctly associated out of all hits in clusters:  78.42129857143846 %
# Incorrectly associated out of all hits:  21.57870142856154 %
# Incorrectly associated out of all hits in clusters:  21.57870142856154 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 4866002
# Identified incorrectly: 1338489
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853253 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777476 , Hits: 1769731
# Number of clusters where tid already exists, that are accounted for: 777476
# Correctly associated out of all hits:  78.42709418065076 %
# Correctly associated out of all hits in clusters:  78.42709418065076 %
# Incorrectly associated out of all hits:  21.57290581934924 %
# Incorrectly associated out of all hits in clusters:  21.57290581934924 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 4863989
# Identified incorrectly: 1337704
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851134 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776610 , Hits: 1772230
# Number of clusters where tid already exists, that are accounted for: 776610
# Correctly associated out of all hits:  78.4300190286749 %
# Correctly associated out of all hits in clusters:  78.4300190286749 %
# Incorrectly associated out of all hits:  21.569980971325087 %
# Incorrectly associated out of all hits in clusters:  21.569980971325087 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_time_40.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 4859525
# Identified incorrectly: 1337578
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849479 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774668 , Hits: 1765073
# Number of clusters where tid already exists, that are accounted for: 774668
# Correctly associated out of all hits:  78.41607602778267 %
# Correctly associated out of all hits in clusters:  78.41607602778267 %
# Incorrectly associated out of all hits:  21.58392397221734 %
# Incorrectly associated out of all hits in clusters:  21.58392397221734 %

# %% [markdown]
# ### No Threshold

# %%
current_threshold = threshold_cluster_width_used[5] 
src_res = "./melp/clustering/results"

src_frac_corr_frame          = src_res + "/frac_corr_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_corr_clusters_frame = src_res + "/frac_corr_clusters_frame_tid_*_time_{}.txt".format(current_threshold)
src_frac_uncorr_frame        = src_res + "/frac_uncorr_frame_tid_*_time_{}.txt".format(current_threshold)
src_efficiency_stats         = src_res + "/efficiency_stats_tid_*_time_{}.txt".format(current_threshold)

fnames_frac_corr_frame           = glob(src_frac_corr_frame)
fnames_frac_corr_clusters_frame  = glob(src_frac_corr_clusters_frame)
fnames_frac_uncorr_frame         = glob(src_frac_uncorr_frame)
fnames_efficiency_stats          = glob(src_efficiency_stats)

array_frac_corr_frame          = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_frame])
array_frac_corr_clusters_frame = np.concatenate([np.loadtxt(f) for f in fnames_frac_corr_clusters_frame])
array_frac_uncorr_frame        = np.concatenate([np.loadtxt(f) for f in fnames_frac_uncorr_frame])

# %%
print_eff_stats(fnames_efficiency_stats)
# Out:
# File: ./melp/clustering/results/efficiency_stats_tid_135_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6206068 , Identified correctly + identified incorrectly = 6206068
# Identified correctly: 3480932
# Identified incorrectly: 2725136
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853897 , Hits: 6206068
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1769685
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  56.089169503137896 %
# Correctly associated out of all hits in clusters:  56.089169503137896 %
# Incorrectly associated out of all hits:  43.910830496862104 %
# Incorrectly associated out of all hits in clusters:  43.910830496862104 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_148_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6197103 , Identified correctly + identified incorrectly = 6197103
# Identified correctly: 3480341
# Identified incorrectly: 2716762
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849479 , Hits: 6197103
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774668 , Hits: 1765073
# Number of clusters where tid already exists, that are accounted for: 774668
# Correctly associated out of all hits:  56.16077383254724 %
# Correctly associated out of all hits in clusters:  56.16077383254724 %
# Incorrectly associated out of all hits:  43.83922616745276 %
# Incorrectly associated out of all hits in clusters:  43.83922616745276 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_157_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201027 , Identified correctly + identified incorrectly = 6201027
# Identified correctly: 3479573
# Identified incorrectly: 2721454
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851057 , Hits: 6201027
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775822 , Hits: 1769624
# Number of clusters where tid already exists, that are accounted for: 775822
# Correctly associated out of all hits:  56.11285033914544 %
# Correctly associated out of all hits in clusters:  56.11285033914544 %
# Incorrectly associated out of all hits:  43.88714966085457 %
# Incorrectly associated out of all hits in clusters:  43.88714966085457 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_156_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6221350 , Identified correctly + identified incorrectly = 6221350
# Identified correctly: 3482740
# Identified incorrectly: 2738610
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2858288 , Hits: 6221350
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780384 , Hits: 1780066
# Number of clusters where tid already exists, that are accounted for: 780384
# Correctly associated out of all hits:  55.98045440298328 %
# Correctly associated out of all hits in clusters:  55.98045440298328 %
# Incorrectly associated out of all hits:  44.01954559701672 %
# Incorrectly associated out of all hits in clusters:  44.01954559701672 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_147_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6211731 , Identified correctly + identified incorrectly = 6211731
# Identified correctly: 3484498
# Identified incorrectly: 2727233
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854687 , Hits: 6211731
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775510 , Hits: 1771260
# Number of clusters where tid already exists, that are accounted for: 775510
# Correctly associated out of all hits:  56.095442639096895 %
# Correctly associated out of all hits in clusters:  56.095442639096895 %
# Incorrectly associated out of all hits:  43.904557360903105 %
# Incorrectly associated out of all hits in clusters:  43.904557360903105 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_160_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6210004 , Identified correctly + identified incorrectly = 6210004
# Identified correctly: 3480368
# Identified incorrectly: 2729636
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853339 , Hits: 6210004
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777218 , Hits: 1773266
# Number of clusters where tid already exists, that are accounted for: 777218
# Correctly associated out of all hits:  56.04453716938024 %
# Correctly associated out of all hits in clusters:  56.04453716938024 %
# Incorrectly associated out of all hits:  43.95546283061975 %
# Incorrectly associated out of all hits in clusters:  43.95546283061975 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_141_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6200661 , Identified correctly + identified incorrectly = 6200661
# Identified correctly: 3477304
# Identified incorrectly: 2723357
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850481 , Hits: 6200661
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776280 , Hits: 1770358
# Number of clusters where tid already exists, that are accounted for: 776280
# Correctly associated out of all hits:  56.07956958137205 %
# Correctly associated out of all hits in clusters:  56.07956958137205 %
# Incorrectly associated out of all hits:  43.92043041862795 %
# Incorrectly associated out of all hits in clusters:  43.92043041862795 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_131_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6199967 , Identified correctly + identified incorrectly = 6199967
# Identified correctly: 3479230
# Identified incorrectly: 2720737
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2850023 , Hits: 6199967
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774764 , Hits: 1768161
# Number of clusters where tid already exists, that are accounted for: 774764
# Correctly associated out of all hits:  56.1169115900133 %
# Correctly associated out of all hits in clusters:  56.1169115900133 %
# Incorrectly associated out of all hits:  43.8830884099867 %
# Incorrectly associated out of all hits in clusters:  43.8830884099867 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_155_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205656 , Identified correctly + identified incorrectly = 6205656
# Identified correctly: 3482408
# Identified incorrectly: 2723248
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852341 , Hits: 6205656
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775738 , Hits: 1770392
# Number of clusters where tid already exists, that are accounted for: 775738
# Correctly associated out of all hits:  56.116678075613606 %
# Correctly associated out of all hits in clusters:  56.116678075613606 %
# Incorrectly associated out of all hits:  43.8833219243864 %
# Incorrectly associated out of all hits in clusters:  43.8833219243864 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_127_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6217592 , Identified correctly + identified incorrectly = 6217592
# Identified correctly: 3476914
# Identified incorrectly: 2740678
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854944 , Hits: 6217592
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780552 , Hits: 1786781
# Number of clusters where tid already exists, that are accounted for: 780552
# Correctly associated out of all hits:  55.92058790605753 %
# Correctly associated out of all hits in clusters:  55.92058790605753 %
# Incorrectly associated out of all hits:  44.07941209394248 %
# Incorrectly associated out of all hits in clusters:  44.07941209394248 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_144_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6210296 , Identified correctly + identified incorrectly = 6210296
# Identified correctly: 3485548
# Identified incorrectly: 2724748
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853312 , Hits: 6210296
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776614 , Hits: 1772046
# Number of clusters where tid already exists, that are accounted for: 776614
# Correctly associated out of all hits:  56.125311901397296 %
# Correctly associated out of all hits in clusters:  56.125311901397296 %
# Incorrectly associated out of all hits:  43.87468809860271 %
# Incorrectly associated out of all hits in clusters:  43.87468809860271 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_161_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6201693 , Identified correctly + identified incorrectly = 6201693
# Identified correctly: 3477705
# Identified incorrectly: 2723988
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851134 , Hits: 6201693
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776610 , Hits: 1772230
# Number of clusters where tid already exists, that are accounted for: 776610
# Correctly associated out of all hits:  56.076703571105504 %
# Correctly associated out of all hits in clusters:  56.076703571105504 %
# Incorrectly associated out of all hits:  43.923296428894496 %
# Incorrectly associated out of all hits in clusters:  43.923296428894496 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_132_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6207427 , Identified correctly + identified incorrectly = 6207427
# Identified correctly: 3482713
# Identified incorrectly: 2724714
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853451 , Hits: 6207427
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776620 , Hits: 1771891
# Number of clusters where tid already exists, that are accounted for: 776620
# Correctly associated out of all hits:  56.1055812657966 %
# Correctly associated out of all hits in clusters:  56.1055812657966 %
# Incorrectly associated out of all hits:  43.8944187342034 %
# Incorrectly associated out of all hits in clusters:  43.8944187342034 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_152_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6207841 , Identified correctly + identified incorrectly = 6207841
# Identified correctly: 3480270
# Identified incorrectly: 2727571
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852724 , Hits: 6207841
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778818 , Hits: 1773877
# Number of clusters where tid already exists, that are accounted for: 778818
# Correctly associated out of all hits:  56.06248613648449 %
# Correctly associated out of all hits in clusters:  56.06248613648449 %
# Incorrectly associated out of all hits:  43.93751386351551 %
# Incorrectly associated out of all hits in clusters:  43.93751386351551 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_138_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211911 , Identified correctly + identified incorrectly = 6211911
# Identified correctly: 3480232
# Identified incorrectly: 2731679
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853370 , Hits: 6211911
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777968 , Hits: 1774985
# Number of clusters where tid already exists, that are accounted for: 777968
# Correctly associated out of all hits:  56.025142665437414 %
# Correctly associated out of all hits in clusters:  56.025142665437414 %
# Incorrectly associated out of all hits:  43.974857334562586 %
# Incorrectly associated out of all hits in clusters:  43.974857334562586 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_162_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6204491 , Identified correctly + identified incorrectly = 6204491
# Identified correctly: 3482259
# Identified incorrectly: 2722232
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853253 , Hits: 6204491
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777476 , Hits: 1769731
# Number of clusters where tid already exists, that are accounted for: 777476
# Correctly associated out of all hits:  56.1248134617328 %
# Correctly associated out of all hits in clusters:  56.1248134617328 %
# Incorrectly associated out of all hits:  43.8751865382672 %
# Incorrectly associated out of all hits in clusters:  43.8751865382672 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_133_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205146 , Identified correctly + identified incorrectly = 6205146
# Identified correctly: 3478289
# Identified incorrectly: 2726857
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852758 , Hits: 6205146
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779448 , Hits: 1779911
# Number of clusters where tid already exists, that are accounted for: 779448
# Correctly associated out of all hits:  56.05490990864679 %
# Correctly associated out of all hits in clusters:  56.05490990864679 %
# Incorrectly associated out of all hits:  43.94509009135321 %
# Incorrectly associated out of all hits in clusters:  43.94509009135321 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_129_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199837
# Total number of hits = 6203035 , Identified correctly + identified incorrectly = 6203035
# Identified correctly: 3474706
# Identified incorrectly: 2728329
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851068 , Hits: 6203035
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777698 , Hits: 1774621
# Number of clusters where tid already exists, that are accounted for: 777698
# Correctly associated out of all hits:  56.016224316000155 %
# Correctly associated out of all hits in clusters:  56.016224316000155 %
# Incorrectly associated out of all hits:  43.98377568399985 %
# Incorrectly associated out of all hits in clusters:  43.98377568399985 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_159_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6211312 , Identified correctly + identified incorrectly = 6211312
# Identified correctly: 3481252
# Identified incorrectly: 2730060
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854136 , Hits: 6211312
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777484 , Hits: 1778667
# Number of clusters where tid already exists, that are accounted for: 777484
# Correctly associated out of all hits:  56.046967210792175 %
# Correctly associated out of all hits in clusters:  56.046967210792175 %
# Incorrectly associated out of all hits:  43.95303278920782 %
# Incorrectly associated out of all hits in clusters:  43.95303278920782 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_151_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6208813 , Identified correctly + identified incorrectly = 6208813
# Identified correctly: 3481892
# Identified incorrectly: 2726921
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853286 , Hits: 6208813
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776572 , Hits: 1772828
# Number of clusters where tid already exists, that are accounted for: 776572
# Correctly associated out of all hits:  56.079833617150335 %
# Correctly associated out of all hits in clusters:  56.079833617150335 %
# Incorrectly associated out of all hits:  43.92016638284967 %
# Incorrectly associated out of all hits in clusters:  43.92016638284967 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_128_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199838
# Total number of hits = 6205476 , Identified correctly + identified incorrectly = 6205476
# Identified correctly: 3483644
# Identified incorrectly: 2721832
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2851549 , Hits: 6205476
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 774790 , Hits: 1767180
# Number of clusters where tid already exists, that are accounted for: 774790
# Correctly associated out of all hits:  56.13822372369178 %
# Correctly associated out of all hits in clusters:  56.13822372369178 %
# Incorrectly associated out of all hits:  43.86177627630821 %
# Incorrectly associated out of all hits in clusters:  43.86177627630821 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_146_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6212473 , Identified correctly + identified incorrectly = 6212473
# Identified correctly: 3484922
# Identified incorrectly: 2727551
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2854313 , Hits: 6212473
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 778104 , Hits: 1775849
# Number of clusters where tid already exists, that are accounted for: 778104
# Correctly associated out of all hits:  56.09556773928836 %
# Correctly associated out of all hits in clusters:  56.09556773928836 %
# Incorrectly associated out of all hits:  43.90443226071164 %
# Incorrectly associated out of all hits in clusters:  43.90443226071164 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_134_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199841
# Total number of hits = 6207977 , Identified correctly + identified incorrectly = 6207977
# Identified correctly: 3481065
# Identified incorrectly: 2726912
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852275 , Hits: 6207977
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775636 , Hits: 1773201
# Number of clusters where tid already exists, that are accounted for: 775636
# Correctly associated out of all hits:  56.07406406305952 %
# Correctly associated out of all hits in clusters:  56.07406406305952 %
# Incorrectly associated out of all hits:  43.92593593694049 %
# Incorrectly associated out of all hits in clusters:  43.92593593694049 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_164_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6203416 , Identified correctly + identified incorrectly = 6203416
# Identified correctly: 3480328
# Identified incorrectly: 2723088
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852932 , Hits: 6203416
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776948 , Hits: 1770756
# Number of clusters where tid already exists, that are accounted for: 776948
# Correctly associated out of all hits:  56.1034114107453 %
# Correctly associated out of all hits in clusters:  56.1034114107453 %
# Incorrectly associated out of all hits:  43.89658858925469 %
# Incorrectly associated out of all hits in clusters:  43.89658858925469 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_158_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6205000 , Identified correctly + identified incorrectly = 6205000
# Identified correctly: 3485208
# Identified incorrectly: 2719792
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852292 , Hits: 6205000
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 775582 , Hits: 1765975
# Number of clusters where tid already exists, that are accounted for: 775582
# Correctly associated out of all hits:  56.167735697018536 %
# Correctly associated out of all hits in clusters:  56.167735697018536 %
# Incorrectly associated out of all hits:  43.832264302981464 %
# Incorrectly associated out of all hits in clusters:  43.832264302981464 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_149_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6203390 , Identified correctly + identified incorrectly = 6203390
# Identified correctly: 3474352
# Identified incorrectly: 2729038
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2852490 , Hits: 6203390
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 779800 , Hits: 1778665
# Number of clusters where tid already exists, that are accounted for: 779800
# Correctly associated out of all hits:  56.00731213094775 %
# Correctly associated out of all hits in clusters:  56.00731213094775 %
# Incorrectly associated out of all hits:  43.99268786905224 %
# Incorrectly associated out of all hits in clusters:  43.99268786905224 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_130_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199839
# Total number of hits = 6215453 , Identified correctly + identified incorrectly = 6215453
# Identified correctly: 3482177
# Identified incorrectly: 2733276
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2855862 , Hits: 6215453
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 780070 , Hits: 1779507
# Number of clusters where tid already exists, that are accounted for: 780070
# Correctly associated out of all hits:  56.024508591730964 %
# Correctly associated out of all hits in clusters:  56.024508591730964 %
# Incorrectly associated out of all hits:  43.975491408269036 %
# Incorrectly associated out of all hits in clusters:  43.975491408269036 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_153_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6195190 , Identified correctly + identified incorrectly = 6195190
# Identified correctly: 3475639
# Identified incorrectly: 2719551
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2849276 , Hits: 6195190
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 776404 , Hits: 1770795
# Number of clusters where tid already exists, that are accounted for: 776404
# Correctly associated out of all hits:  56.10221801106988 %
# Correctly associated out of all hits in clusters:  56.10221801106988 %
# Incorrectly associated out of all hits:  43.89778198893012 %
# Incorrectly associated out of all hits in clusters:  43.89778198893012 %
#
#
# File: ./melp/clustering/results/efficiency_stats_tid_145_time_999999.txt
# Number of analyzed frames:  199841 Number of correct counter fractions:  199840
# Total number of hits = 6209305 , Identified correctly + identified incorrectly = 6209305
# Identified correctly: 3482989
# Identified incorrectly: 2726316
# Total #hits in frames/#hits in clusters =  1.0
# Total number of clusters: 2853971 , Hits: 6209305
# Number of clusters with hits that are far apart in time: 0
# Number of clusters where tid already exists: 777876 , Hits: 1773299
# Number of clusters where tid already exists, that are accounted for: 777876
# Correctly associated out of all hits:  56.09305711347727 %
# Correctly associated out of all hits in clusters:  56.09305711347727 %
# Incorrectly associated out of all hits:  43.90694288652273 %
# Incorrectly associated out of all hits in clusters:  43.90694288652273 %
