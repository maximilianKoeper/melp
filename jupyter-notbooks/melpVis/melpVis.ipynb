# %%
# %cd ../..
# Out:
# /home/maximilian/Github/melp

# %%
from melp.vis import Visualizer
import matplotlib
# Out:
# Welcome to JupyROOT 6.26/00

# %%
vis = Visualizer("run42_20000_sorted_test.root")
# Out:
# ------------------------------
# Detector information
#
# Stats:
#   - Tiles:  5824
#     -> misal:  True
#   - Pixel Modules:  2844
#   - Loaded Runs (Tiles):  []
#   - Loaded Runs (Pixel):  []
# ------------------------------
#
#  -> Fetching Trajectories for new Frame ... done | #TRAJ:  39

# %%
vis.set_frame_id(1199)
# Out:
#  -> Fetching Trajectories for new Frame ... done | #TRAJ:  66

# %%
#vis.trajectories
#vis.select_only_particle_types([1,2])
# 0: photon
# 1: e+
# 2: e-
# 3: mu+
# 4: mu-

# %%
#vis.set_trajectories([36,39, 60])
#vis.set_trajectories([31,36])
#vis.set_trajectories([861858])
options = {
    "xlim": (-300,300),
    "ylim": (-300,300),
    "zlim": (-300,300),
    "fontsize": 25
}

#vis.set_plt_options_2d(**options)

# %%
vis.show()

# %%
#%matplotlib  
# remove hashtag to get interactive 3d representation
vis.show_3d()

# %%
# 1199 : 36, 39
#vis.list_traj_info()

# %%
vis.reset_frame()
# Out:
#  -> Fetching Trajectories for new Frame ... done | #TRAJ:  66

# %%
from melp.vis import ToyEventGenerator

# %%
TEG = ToyEventGenerator(pt=20, pz=15, particle_type=2)

# %%
for i in range(1):
    vis.add_toy_event(TEG.new_event())

# %%
vis.add_toy_event(TEG.new_event())

# %%
vis.select_all_toy_trajectories()

# %%
vis.show()

# %%
#%matplotlib
vis.show_3d()

# %%
vis.list_traj_info()
# Out:
#  | Traj_ID: 892758 | p_z: 26.75 | p_t: 1.35 | particle: 3 | mother: 0
#
#  | Traj_ID: 892769 | p_z: 27.82 | p_t: 2.23 | particle: 3 | mother: 0
#
#  | Traj_ID: 892778 | p_z: 28.34 | p_t: 2.61 | particle: 3 | mother: 0
#
#  | Traj_ID: 892782 | p_z: 28.39 | p_t: 3.75 | particle: 3 | mother: 0
#
#  | Traj_ID: 892786 | p_z: 27.36 | p_t: 1.54 | particle: 3 | mother: 0
#
#  | Traj_ID: 892793 | p_z: 26.51 | p_t: 2.54 | particle: 3 | mother: 0
#
#  | Traj_ID: 892797 | p_z: 27.36 | p_t: 0.49 | particle: 3 | mother: 0
#
#  | Traj_ID: 892801 | p_z: 27.64 | p_t: 2.35 | particle: 3 | mother: 0
#
#  | Traj_ID: 892820 | p_z: 27.62 | p_t: 1.25 | particle: 3 | mother: 0
#
#  | Traj_ID: 892824 | p_z: 28.93 | p_t: 5.71 | particle: 3 | mother: 0
#
#  | Traj_ID: 892828 | p_z: 27.72 | p_t: 1.33 | particle: 3 | mother: 0
#
#  | Traj_ID: 892832 | p_z: 26.93 | p_t: 3.43 | particle: 3 | mother: 0
#
#  | Traj_ID: 892833 | p_z: 28.5 | p_t: 0.95 | particle: 3 | mother: 0
#
# ...
