# %%
# %cd ../..
# Out:
# /home/maximilian/Github/melp

# %%
from melp.vis import Visualizer
import matplotlib
# Out:
# Welcome to JupyROOT 6.26/00

# %%
vis1 = Visualizer("run42_20000_sorted_test.root")
# Out:
# ------------------------------
# Detector information
#
# Stats:
#   - Tiles:  5824
#     -> misal:  True
#   - Pixel Modules:  2844
#   - Loaded Runs (Tiles):  []
#   - Loaded Runs (Pixel):  []
# ------------------------------
#
#  -> Fetching Trajectories for new Frame ... done | #TRAJ:  39

# %%
vis1.set_frame_id(1199)
# Out:
#  -> Fetching Trajectories for new Frame ... done | #TRAJ:  66

# %%
vis1.set_trajectories([36,39])

# %%
vis1.show()

# %%
# %matplotlib
vis1.show_3d()
# Out:
# Using matplotlib backend: <object object at 0x7fb26526eda0>

# %%
# 1199 : 36, 39
